# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# # Data preparation

# %%
#import uproot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


import ROOT;
#import lumiere as lm
#lm.loadstyle(True);

from sklearn.metrics import roc_auc_score, roc_curve

def ams_score(x, y, w, cut):
# Calculate Average Mean Significane as defined in ATLAS paper
#    -  approximative formula for large statistics with regularisation
# x: array of truth values (1 if signal)
# y: array of classifier result
# w: array of event weights
# cut
    t = y > cut 
    s = np.sum((x[t] == 1)*w[t])
    b = np.sum((x[t] == 0)*w[t])
    return s/np.sqrt(b+10.0)

def find_best_ams_score(x, y, w):
# find best value of AMS by scanning cut values; 
# x: array of truth values (1 if signal)
# y: array of classifier results
# w: array of event weights
#  returns 
#   ntuple of best value of AMS and the corresponding cut value
#   list with corresponding pairs (ams, cut) 
# ----------------------------------------------------------
    ymin=min(y) # classifiers may not be in range [0.,1.]
    ymax=max(y)
    nprobe=200    # number of (equally spaced) scan points to probe classifier 
    amsvec= [(ams_score(x, y, w, cut), cut) for cut in np.linspace(ymin, ymax, nprobe)] 
    maxams=sorted(amsvec, key=lambda lst: lst[0] )[-1]
    return maxams, amsvec




def printScore(model):

    try:
        pred_clf = model.predict_proba(x_val)[:, 1]
    except:
        pred_clf = model.predict(x_val)
        pred_clf = pred_clf.reshape((pred_clf.shape[0],))

    auc = roc_auc_score(y_val, pred_clf, sample_weight=w_val)
    print('AUC:', auc)
    bs = find_best_ams_score(y_val, pred_clf, w_val)
    print('AMS:', bs[0][0])
    print('AMS total:', bs[0][0]*np.sqrt(50))



def plotLossAccuracy(history):
    # Get training and validation loss/accuracy values from history
    loss_training = history.history['loss']
    loss_validation = history.history['val_loss']
    accuracy_training = history.history['accuracy']
    accuracy_validation = history.history['val_accuracy']


    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 8))
    
    ax1.plot(loss_training, 'o--', label='training')
    ax1.plot(loss_validation, 'o--', label='validation')
    ax1.legend(title='loss')
    ax1.set_xlabel('epoch')
    
    ax2.plot(accuracy_training, 'o--', label='training')
    ax2.plot(accuracy_validation, 'o--', label='validation')
    ax2.legend(title='accuracy')
    ax2.set_xlabel('epoch')

    plt.show()
# Out:
# Welcome to JupyROOT 6.28/10

# %% [markdown]
# ## Read-in & to Pandas

# %%
input_columns = ['DER_deltaeta_jet_jet', 'DER_deltar_tau_lep', 'DER_lep_eta_centrality', 'DER_mass_MMC', 'DER_mass_jet_jet', 
                 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_met_phi_centrality', 'DER_prodeta_jet_jet', 'DER_pt_h', 
                 'DER_pt_ratio_lep_tau', 'DER_pt_tot', 'DER_sum_pt', 'PRI_jet_all_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 
                 'PRI_jet_leading_pt', 'PRI_jet_num', 'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_subleading_pt', 
                 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_lep_pt', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_tau_eta', 'PRI_tau_phi', 
                 'PRI_tau_pt', 'transverse_lepton_jet_mass']


'''

input_columns = [ 'transverse_lepton_jet_mass',
                'DER_mass_MMC', 
                'DER_mass_vis', 
                'DER_mass_transverse_met_lep',
                'DER_pt_ratio_lep_tau', 
                'DER_sum_pt',
                'DER_deltar_tau_lep', 
                'DER_pt_h',
                'DER_sum_pt',  
                'PRI_met_sumet', 
                'PRI_tau_pt',
                ]

'''
print(len(input_columns))
# Out:
# 31

# %%
RDF = ROOT.ROOT.RDataFrame

signal_tree_name = 'signal'
background_tree_name = 'background'
test_tree_name = 'validation'
file_name = 'atlas-higgs-challenge-2014-v2_part.root'

rdf_signal = RDF(signal_tree_name, file_name)
rdf_bkg = RDF(background_tree_name, file_name)
rdf_test = RDF(test_tree_name, file_name)

reconstruct_transverse_lepton_jet_mass = '''

float lep_px = PRI_lep_pt * TMath::Cos(PRI_lep_phi);
float lep_py = PRI_lep_pt * TMath::Sin(PRI_lep_phi);
float jet_px = PRI_jet_leading_pt * TMath::Cos(PRI_jet_leading_phi);
float jet_py = PRI_jet_leading_pt * TMath::Sin(PRI_jet_leading_phi);

//calculate angle between jet and lepton
float cos_theta = (lep_px*jet_px + lep_py*jet_py) / PRI_lep_pt / PRI_jet_leading_pt;

return PRI_lep_pt * PRI_jet_leading_pt * (1 - cos_theta);
'''

#insertion
rdf_signal = rdf_signal.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)
rdf_bkg = rdf_bkg.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)
rdf_test = rdf_test.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)

# label classification to int values
rdf_test = rdf_test.Define('IntLabel', '''
const char ch = Label[0];
const char s = 's';
if(ch == s){
    return 1;
}
else{
    return 0;
}
''')


df_signal = pd.DataFrame(rdf_signal.AsNumpy())
df_bg = pd.DataFrame(rdf_bkg.AsNumpy())
df_test = pd.DataFrame(rdf_test.AsNumpy())

# %% [markdown]
# ## concatination, shuffle and split

# %%
from sklearn.utils import shuffle;
from sklearn.model_selection import train_test_split;

#input feature arrays
vars_signal = df_signal[input_columns].to_numpy()
vars_bg = df_bg[input_columns].to_numpy()
vars_test = df_test[input_columns].to_numpy()

inputs = np.concatenate([vars_signal, vars_bg])

#weights
weight_signal = df_signal['Weight'].to_numpy()
weight_bg = df_bg['Weight'].to_numpy()
weights = np.concatenate([weight_signal, weight_bg])
weights = weights.reshape((weights.shape[0],))

weights_test = df_test['Weight'].to_numpy()


# target classifictionation (1:signal / 0: background)
y_signal = np.ones((vars_signal.shape[0], ))
y_bg = np.zeros((vars_bg.shape[0], ))

targets = np.concatenate([y_signal, y_bg])

# for test dataset there is already a classification; convert to int
truths_test = df_test.IntLabel.to_numpy()


# shuffle 
inputs, targets, weights = shuffle(inputs, targets, weights)


# not for gridcv

# training and validation split  (80, 20)
x_train, x_val, y_train, y_val, w_train, w_val = train_test_split(inputs, targets, weights, test_size=0.2)
#x_train, y_train = inputs, targets

# %% [markdown]
# ## StandardScaling

# %%
from sklearn.preprocessing import StandardScaler;
 
scaler = StandardScaler()
scaler.fit(x_train) #set up only on train data
 
# tranformation applied to all
x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(vars_test)

# %% [markdown]
# ### SMOTE

# %%
#%pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE


# Apply SMOTE to the training data
smote = SMOTE()
x_train, y_train = smote.fit_resample(x_train, y_train)

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

#x_train_pre = x_train

#pca = PCA(n_components=22)
#pca.fit(x_train)

#x_train = pca.transform(x_train)
#x_val = pca.transform(x_val)
#x_test = pca.transform(x_test)

# %% [markdown]
# ## DNN

# %% [markdown]
# #### training function

# %%
from tensorflow.keras.metrics import Metric
from tensorflow.keras.metrics import AUC

class AMSMetric(Metric):
    def __init__(self, name='AMS', **kwargs):
        super(AMSMetric, self).__init__(name=name, **kwargs)
        self.ams_score = self.add_weight(name='ams', initializer='zeros')
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        score = AMS_scorer(y_true, y_pred, sample_weight)
        self.ams_score.assign(score)
    
    def result(self):
        return self.ams_score
    
    def reset_states(self):
        self.ams_score.assign(0.0)

# Custom AMS scorer function
def AMS_scorer(y_true, y_pred, weights):
    score = find_best_ams_score(y_true, y_pred, weights)
    return score[0][0]
# Out:
# 2024-07-25 17:30:53.546520: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-25 17:30:53.547731: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-25 17:30:53.552550: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-25 17:30:53.597639: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-25 17:30:54.448952: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Training function
def train(model, epochs=10, batch_size=128, learning_rate=1e-3, verbose="auto"):
    '''
    - x: features
    - y: labels
    - w: sample weights
    '''
    
    # Define loss function, optimizer algorithm and validation metrics
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy', AUC])
    
    # Print summary of the model
    model.summary()
    
    # Train model
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                         verbose=verbose,  validation_split=0.2)
    #history = model.fit(x_train, y_train, sample_weight=w_train, batch_size=batch_size, epochs=epochs,
    #                     verbose=verbose,  validation_split=0.2)
        
    
    return history

# %% [markdown]
# ### model

# %%
import tensorflow as tf;
from tensorflow.keras import layers, models, optimizers;
from tensorflow.keras.optimizers import Adam

# Define the DNN model
def buildModel():
    model = models.Sequential()
    
    # input
    model.add(layers.Input(shape=(x_train.shape[1],)))
    
    # hidden
    model.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(2*128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(32, activation='relu', kernel_initializer='glorot_normal'))
    
    # output
    model.add(layers.Dense(1, activation='sigmoid', kernel_initializer='glorot_normal'))
    
    return model

# %%
model = buildModel()

history = train(model, epochs=400, batch_size=4*1024, learning_rate=2e-4)

printScore(model)
plotLossAccuracy(history)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 128)            │         2,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,537 (349.75 KB)
#  Trainable params: 89,537 (349.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5389 - auc_1: 0.5228 - loss: 0.6953 - val_accuracy: 0.0215 - val_auc_1: 0.0000e+00 - val_loss: 0.8458
# Epoch 2/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6288 - auc_1: 0.6145 - loss: 0.6433 - val_accuracy: 0.3403 - val_auc_1: 0.0000e+00 - val_loss: 0.8161
# Epoch 3/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.6404 - auc_1: 0.6775 - loss: 0.6164 - val_accuracy: 0.4569 - val_auc_1: 0.0000e+00 - val_loss: 0.8040
# Epoch 4/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.6545 - auc_1: 0.7078 - loss: 0.5994 - val_accuracy: 0.5559 - val_auc_1: 0.0000e+00 - val_loss: 0.7830
# Epoch 5/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.6761 - auc_1: 0.7326 - loss: 0.5823 - val_accuracy: 0.6701 - val_auc_1: 0.0000e+00 - val_loss: 0.7459
# Epoch 6/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.6890 - auc_1: 0.7494 - loss: 0.5746 - val_accuracy: 0.6937 - val_auc_1: 0.0000e+00 - val_loss: 0.7433
# Epoch 7/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7018 - auc_1: 0.7620 - loss: 0.5642 - val_accuracy: 0.7293 - val_auc_1: 0.0000e+00 - val_loss: 0.7116
# Epoch 8/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7107 - auc_1: 0.7701 - loss: 0.5552 - val_accuracy: 0.7205 - val_auc_1: 0.0000e+00 - val_loss: 0.7091
# Epoch 9/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7185 - auc_1: 0.7808 - loss: 0.5467 - val_accuracy: 0.7353 - val_auc_1: 0.0000e+00 - val_loss: 0.6817
# Epoch 10/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7245 - auc_1: 0.7879 - loss: 0.5366 - val_accuracy: 0.7427 - val_auc_1: 0.0000e+00 - val_loss: 0.6612
# Epoch 11/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7267 - auc_1: 0.7887 - loss: 0.5387 - val_accuracy: 0.7244 - val_auc_1: 0.0000e+00 - val_loss: 0.6690
# Epoch 12/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7336 - auc_1: 0.8009 - loss: 0.5260 - val_accuracy: 0.7388 - val_auc_1: 0.0000e+00 - val_loss: 0.6342
# Epoch 13/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7384 - auc_1: 0.8029 - loss: 0.5203 - val_accuracy: 0.7417 - val_auc_1: 0.0000e+00 - val_loss: 0.6198
# Epoch 14/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7424 - auc_1: 0.8081 - loss: 0.5155 - val_accuracy: 0.7350 - val_auc_1: 0.0000e+00 - val_loss: 0.6171
# Epoch 15/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7471 - auc_1: 0.8090 - loss: 0.5160 - val_accuracy: 0.7425 - val_auc_1: 0.0000e+00 - val_loss: 0.5961
# Epoch 16/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7485 - auc_1: 0.8127 - loss: 0.5098 - val_accuracy: 0.7440 - val_auc_1: 0.0000e+00 - val_loss: 0.5904
# Epoch 17/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7545 - auc_1: 0.8217 - loss: 0.4996 - val_accuracy: 0.7423 - val_auc_1: 0.0000e+00 - val_loss: 0.5911
# Epoch 18/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7531 - auc_1: 0.8223 - loss: 0.4985 - val_accuracy: 0.7524 - val_auc_1: 0.0000e+00 - val_loss: 0.5773
# Epoch 19/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7569 - auc_1: 0.8239 - loss: 0.4984 - val_accuracy: 0.7576 - val_auc_1: 0.0000e+00 - val_loss: 0.5617
# Epoch 20/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7598 - auc_1: 0.8277 - loss: 0.4904 - val_accuracy: 0.7621 - val_auc_1: 0.0000e+00 - val_loss: 0.5467
# Epoch 21/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7638 - auc_1: 0.8319 - loss: 0.4870 - val_accuracy: 0.7540 - val_auc_1: 0.0000e+00 - val_loss: 0.5543
# Epoch 22/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7621 - auc_1: 0.8319 - loss: 0.4874 - val_accuracy: 0.7609 - val_auc_1: 0.0000e+00 - val_loss: 0.5474
# Epoch 23/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7666 - auc_1: 0.8356 - loss: 0.4835 - val_accuracy: 0.7583 - val_auc_1: 0.0000e+00 - val_loss: 0.5439
# Epoch 24/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7678 - auc_1: 0.8366 - loss: 0.4838 - val_accuracy: 0.7563 - val_auc_1: 0.0000e+00 - val_loss: 0.5428
# Epoch 25/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7658 - auc_1: 0.8379 - loss: 0.4822 - val_accuracy: 0.7590 - val_auc_1: 0.0000e+00 - val_loss: 0.5363
# Epoch 26/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7708 - auc_1: 0.8394 - loss: 0.4795 - val_accuracy: 0.7626 - val_auc_1: 0.0000e+00 - val_loss: 0.5281
# Epoch 27/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7759 - auc_1: 0.8455 - loss: 0.4701 - val_accuracy: 0.7655 - val_auc_1: 0.0000e+00 - val_loss: 0.5196
# Epoch 28/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7744 - auc_1: 0.8451 - loss: 0.4709 - val_accuracy: 0.7609 - val_auc_1: 0.0000e+00 - val_loss: 0.5278
# Epoch 29/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7808 - auc_1: 0.8494 - loss: 0.4655 - val_accuracy: 0.7677 - val_auc_1: 0.0000e+00 - val_loss: 0.5120
# Epoch 30/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7807 - auc_1: 0.8492 - loss: 0.4660 - val_accuracy: 0.7646 - val_auc_1: 0.0000e+00 - val_loss: 0.5137
# Epoch 31/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7789 - auc_1: 0.8495 - loss: 0.4662 - val_accuracy: 0.7682 - val_auc_1: 0.0000e+00 - val_loss: 0.5055
# Epoch 32/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7769 - auc_1: 0.8485 - loss: 0.4674 - val_accuracy: 0.7666 - val_auc_1: 0.0000e+00 - val_loss: 0.5112
# Epoch 33/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7846 - auc_1: 0.8553 - loss: 0.4586 - val_accuracy: 0.7733 - val_auc_1: 0.0000e+00 - val_loss: 0.4992
# Epoch 34/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7844 - auc_1: 0.8533 - loss: 0.4598 - val_accuracy: 0.7736 - val_auc_1: 0.0000e+00 - val_loss: 0.4958
# Epoch 35/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7837 - auc_1: 0.8530 - loss: 0.4623 - val_accuracy: 0.7715 - val_auc_1: 0.0000e+00 - val_loss: 0.5001
# Epoch 36/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7842 - auc_1: 0.8561 - loss: 0.4564 - val_accuracy: 0.7719 - val_auc_1: 0.0000e+00 - val_loss: 0.4931
# Epoch 37/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7843 - auc_1: 0.8550 - loss: 0.4577 - val_accuracy: 0.7704 - val_auc_1: 0.0000e+00 - val_loss: 0.4907
# Epoch 38/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7877 - auc_1: 0.8578 - loss: 0.4544 - val_accuracy: 0.7688 - val_auc_1: 0.0000e+00 - val_loss: 0.4911
# Epoch 39/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7877 - auc_1: 0.8586 - loss: 0.4553 - val_accuracy: 0.7698 - val_auc_1: 0.0000e+00 - val_loss: 0.4874
# Epoch 40/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7873 - auc_1: 0.8576 - loss: 0.4551 - val_accuracy: 0.7659 - val_auc_1: 0.0000e+00 - val_loss: 0.4910
# Epoch 41/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7875 - auc_1: 0.8601 - loss: 0.4497 - val_accuracy: 0.7778 - val_auc_1: 0.0000e+00 - val_loss: 0.4764
# Epoch 42/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7899 - auc_1: 0.8615 - loss: 0.4500 - val_accuracy: 0.7745 - val_auc_1: 0.0000e+00 - val_loss: 0.4803
# Epoch 43/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7925 - auc_1: 0.8661 - loss: 0.4433 - val_accuracy: 0.7672 - val_auc_1: 0.0000e+00 - val_loss: 0.4825
# Epoch 44/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7888 - auc_1: 0.8619 - loss: 0.4482 - val_accuracy: 0.7696 - val_auc_1: 0.0000e+00 - val_loss: 0.4742
# Epoch 45/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7937 - auc_1: 0.8647 - loss: 0.4465 - val_accuracy: 0.7747 - val_auc_1: 0.0000e+00 - val_loss: 0.4716
# Epoch 46/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7934 - auc_1: 0.8653 - loss: 0.4447 - val_accuracy: 0.7693 - val_auc_1: 0.0000e+00 - val_loss: 0.4766
# Epoch 47/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7920 - auc_1: 0.8664 - loss: 0.4422 - val_accuracy: 0.7714 - val_auc_1: 0.0000e+00 - val_loss: 0.4700
# Epoch 48/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7972 - auc_1: 0.8675 - loss: 0.4407 - val_accuracy: 0.7711 - val_auc_1: 0.0000e+00 - val_loss: 0.4696
# Epoch 49/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7977 - auc_1: 0.8683 - loss: 0.4395 - val_accuracy: 0.7754 - val_auc_1: 0.0000e+00 - val_loss: 0.4641
# Epoch 50/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8009 - auc_1: 0.8715 - loss: 0.4362 - val_accuracy: 0.7707 - val_auc_1: 0.0000e+00 - val_loss: 0.4726
# Epoch 51/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7983 - auc_1: 0.8682 - loss: 0.4405 - val_accuracy: 0.7788 - val_auc_1: 0.0000e+00 - val_loss: 0.4562
# Epoch 52/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8018 - auc_1: 0.8732 - loss: 0.4336 - val_accuracy: 0.7746 - val_auc_1: 0.0000e+00 - val_loss: 0.4641
# Epoch 53/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7982 - auc_1: 0.8697 - loss: 0.4391 - val_accuracy: 0.7759 - val_auc_1: 0.0000e+00 - val_loss: 0.4626
# Epoch 54/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8013 - auc_1: 0.8726 - loss: 0.4332 - val_accuracy: 0.7723 - val_auc_1: 0.0000e+00 - val_loss: 0.4632
# Epoch 55/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8031 - auc_1: 0.8742 - loss: 0.4305 - val_accuracy: 0.7803 - val_auc_1: 0.0000e+00 - val_loss: 0.4536
# Epoch 56/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8040 - auc_1: 0.8738 - loss: 0.4310 - val_accuracy: 0.7797 - val_auc_1: 0.0000e+00 - val_loss: 0.4499
# Epoch 57/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8011 - auc_1: 0.8722 - loss: 0.4345 - val_accuracy: 0.7725 - val_auc_1: 0.0000e+00 - val_loss: 0.4550
# Epoch 58/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8022 - auc_1: 0.8713 - loss: 0.4354 - val_accuracy: 0.7749 - val_auc_1: 0.0000e+00 - val_loss: 0.4533
# Epoch 59/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8048 - auc_1: 0.8761 - loss: 0.4273 - val_accuracy: 0.7786 - val_auc_1: 0.0000e+00 - val_loss: 0.4492
# Epoch 60/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8006 - auc_1: 0.8742 - loss: 0.4309 - val_accuracy: 0.7793 - val_auc_1: 0.0000e+00 - val_loss: 0.4430
# Epoch 61/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8019 - auc_1: 0.8760 - loss: 0.4277 - val_accuracy: 0.7780 - val_auc_1: 0.0000e+00 - val_loss: 0.4517
# Epoch 62/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8006 - auc_1: 0.8714 - loss: 0.4342 - val_accuracy: 0.7835 - val_auc_1: 0.0000e+00 - val_loss: 0.4456
# Epoch 63/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8053 - auc_1: 0.8756 - loss: 0.4294 - val_accuracy: 0.7827 - val_auc_1: 0.0000e+00 - val_loss: 0.4468
# Epoch 64/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8064 - auc_1: 0.8771 - loss: 0.4255 - val_accuracy: 0.7824 - val_auc_1: 0.0000e+00 - val_loss: 0.4414
# Epoch 65/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8050 - auc_1: 0.8776 - loss: 0.4254 - val_accuracy: 0.7826 - val_auc_1: 0.0000e+00 - val_loss: 0.4454
# Epoch 66/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8064 - auc_1: 0.8782 - loss: 0.4244 - val_accuracy: 0.7845 - val_auc_1: 0.0000e+00 - val_loss: 0.4405
# Epoch 67/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8059 - auc_1: 0.8794 - loss: 0.4220 - val_accuracy: 0.7873 - val_auc_1: 0.0000e+00 - val_loss: 0.4409
# Epoch 68/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8101 - auc_1: 0.8806 - loss: 0.4196 - val_accuracy: 0.7847 - val_auc_1: 0.0000e+00 - val_loss: 0.4368
# Epoch 69/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8054 - auc_1: 0.8801 - loss: 0.4216 - val_accuracy: 0.7791 - val_auc_1: 0.0000e+00 - val_loss: 0.4487
# Epoch 70/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8079 - auc_1: 0.8786 - loss: 0.4230 - val_accuracy: 0.7882 - val_auc_1: 0.0000e+00 - val_loss: 0.4392
# Epoch 71/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8091 - auc_1: 0.8797 - loss: 0.4216 - val_accuracy: 0.7882 - val_auc_1: 0.0000e+00 - val_loss: 0.4408
# Epoch 72/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8055 - auc_1: 0.8815 - loss: 0.4198 - val_accuracy: 0.7868 - val_auc_1: 0.0000e+00 - val_loss: 0.4421
# Epoch 73/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8094 - auc_1: 0.8823 - loss: 0.4171 - val_accuracy: 0.7906 - val_auc_1: 0.0000e+00 - val_loss: 0.4369
# Epoch 74/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8084 - auc_1: 0.8822 - loss: 0.4176 - val_accuracy: 0.7945 - val_auc_1: 0.0000e+00 - val_loss: 0.4315
# Epoch 75/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8071 - auc_1: 0.8813 - loss: 0.4185 - val_accuracy: 0.7888 - val_auc_1: 0.0000e+00 - val_loss: 0.4424
# Epoch 76/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8106 - auc_1: 0.8834 - loss: 0.4162 - val_accuracy: 0.7957 - val_auc_1: 0.0000e+00 - val_loss: 0.4330
# Epoch 77/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8096 - auc_1: 0.8807 - loss: 0.4194 - val_accuracy: 0.7927 - val_auc_1: 0.0000e+00 - val_loss: 0.4364
# Epoch 78/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8112 - auc_1: 0.8840 - loss: 0.4149 - val_accuracy: 0.7953 - val_auc_1: 0.0000e+00 - val_loss: 0.4297
# Epoch 79/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8110 - auc_1: 0.8822 - loss: 0.4176 - val_accuracy: 0.7944 - val_auc_1: 0.0000e+00 - val_loss: 0.4307
# Epoch 80/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8141 - auc_1: 0.8856 - loss: 0.4126 - val_accuracy: 0.7957 - val_auc_1: 0.0000e+00 - val_loss: 0.4333
# Epoch 81/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8108 - auc_1: 0.8846 - loss: 0.4146 - val_accuracy: 0.7976 - val_auc_1: 0.0000e+00 - val_loss: 0.4304
# Epoch 82/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8107 - auc_1: 0.8844 - loss: 0.4158 - val_accuracy: 0.7971 - val_auc_1: 0.0000e+00 - val_loss: 0.4322
# Epoch 83/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8132 - auc_1: 0.8855 - loss: 0.4118 - val_accuracy: 0.8002 - val_auc_1: 0.0000e+00 - val_loss: 0.4240
# Epoch 84/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8132 - auc_1: 0.8872 - loss: 0.4113 - val_accuracy: 0.7994 - val_auc_1: 0.0000e+00 - val_loss: 0.4251
# Epoch 85/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8163 - auc_1: 0.8872 - loss: 0.4101 - val_accuracy: 0.8035 - val_auc_1: 0.0000e+00 - val_loss: 0.4229
# Epoch 86/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8149 - auc_1: 0.8847 - loss: 0.4129 - val_accuracy: 0.8028 - val_auc_1: 0.0000e+00 - val_loss: 0.4233
# Epoch 87/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8156 - auc_1: 0.8884 - loss: 0.4071 - val_accuracy: 0.7996 - val_auc_1: 0.0000e+00 - val_loss: 0.4292
# Epoch 88/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8140 - auc_1: 0.8862 - loss: 0.4110 - val_accuracy: 0.8043 - val_auc_1: 0.0000e+00 - val_loss: 0.4200
# Epoch 89/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8106 - auc_1: 0.8850 - loss: 0.4128 - val_accuracy: 0.8013 - val_auc_1: 0.0000e+00 - val_loss: 0.4253
# Epoch 90/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8139 - auc_1: 0.8862 - loss: 0.4119 - val_accuracy: 0.8017 - val_auc_1: 0.0000e+00 - val_loss: 0.4237
# Epoch 91/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8124 - auc_1: 0.8849 - loss: 0.4139 - val_accuracy: 0.8056 - val_auc_1: 0.0000e+00 - val_loss: 0.4188
# Epoch 92/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8166 - auc_1: 0.8894 - loss: 0.4064 - val_accuracy: 0.8057 - val_auc_1: 0.0000e+00 - val_loss: 0.4233
# Epoch 93/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8157 - auc_1: 0.8877 - loss: 0.4078 - val_accuracy: 0.8123 - val_auc_1: 0.0000e+00 - val_loss: 0.4118
# Epoch 94/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8179 - auc_1: 0.8896 - loss: 0.4046 - val_accuracy: 0.8035 - val_auc_1: 0.0000e+00 - val_loss: 0.4227
# Epoch 95/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8176 - auc_1: 0.8905 - loss: 0.4043 - val_accuracy: 0.8089 - val_auc_1: 0.0000e+00 - val_loss: 0.4208
# Epoch 96/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8153 - auc_1: 0.8862 - loss: 0.4107 - val_accuracy: 0.8121 - val_auc_1: 0.0000e+00 - val_loss: 0.4160
# Epoch 97/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8184 - auc_1: 0.8920 - loss: 0.4013 - val_accuracy: 0.8095 - val_auc_1: 0.0000e+00 - val_loss: 0.4160
# Epoch 98/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8174 - auc_1: 0.8906 - loss: 0.4033 - val_accuracy: 0.8109 - val_auc_1: 0.0000e+00 - val_loss: 0.4189
# Epoch 99/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8200 - auc_1: 0.8907 - loss: 0.4023 - val_accuracy: 0.8120 - val_auc_1: 0.0000e+00 - val_loss: 0.4116
# Epoch 100/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8169 - auc_1: 0.8895 - loss: 0.4057 - val_accuracy: 0.8100 - val_auc_1: 0.0000e+00 - val_loss: 0.4247
# Epoch 101/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8167 - auc_1: 0.8905 - loss: 0.4037 - val_accuracy: 0.8161 - val_auc_1: 0.0000e+00 - val_loss: 0.4116
# Epoch 102/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8197 - auc_1: 0.8916 - loss: 0.4002 - val_accuracy: 0.8149 - val_auc_1: 0.0000e+00 - val_loss: 0.4108
# Epoch 103/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8166 - auc_1: 0.8898 - loss: 0.4053 - val_accuracy: 0.8149 - val_auc_1: 0.0000e+00 - val_loss: 0.4154
# Epoch 104/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8169 - auc_1: 0.8906 - loss: 0.4033 - val_accuracy: 0.8170 - val_auc_1: 0.0000e+00 - val_loss: 0.4104
# Epoch 105/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8191 - auc_1: 0.8920 - loss: 0.4013 - val_accuracy: 0.8147 - val_auc_1: 0.0000e+00 - val_loss: 0.4169
# Epoch 106/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8191 - auc_1: 0.8905 - loss: 0.4022 - val_accuracy: 0.8185 - val_auc_1: 0.0000e+00 - val_loss: 0.4061
# Epoch 107/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8165 - auc_1: 0.8895 - loss: 0.4055 - val_accuracy: 0.8122 - val_auc_1: 0.0000e+00 - val_loss: 0.4196
# Epoch 108/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8175 - auc_1: 0.8887 - loss: 0.4074 - val_accuracy: 0.8218 - val_auc_1: 0.0000e+00 - val_loss: 0.4043
# Epoch 109/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8241 - auc_1: 0.8955 - loss: 0.3960 - val_accuracy: 0.8190 - val_auc_1: 0.0000e+00 - val_loss: 0.4093
# Epoch 110/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8193 - auc_1: 0.8897 - loss: 0.4035 - val_accuracy: 0.8204 - val_auc_1: 0.0000e+00 - val_loss: 0.4119
# Epoch 111/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8182 - auc_1: 0.8911 - loss: 0.4021 - val_accuracy: 0.8218 - val_auc_1: 0.0000e+00 - val_loss: 0.4088
# Epoch 112/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8226 - auc_1: 0.8924 - loss: 0.4003 - val_accuracy: 0.8182 - val_auc_1: 0.0000e+00 - val_loss: 0.4113
# Epoch 113/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8195 - auc_1: 0.8925 - loss: 0.3998 - val_accuracy: 0.8200 - val_auc_1: 0.0000e+00 - val_loss: 0.4084
# Epoch 114/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8199 - auc_1: 0.8936 - loss: 0.3984 - val_accuracy: 0.8189 - val_auc_1: 0.0000e+00 - val_loss: 0.4122
# Epoch 115/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8210 - auc_1: 0.8930 - loss: 0.3979 - val_accuracy: 0.8237 - val_auc_1: 0.0000e+00 - val_loss: 0.4025
# Epoch 116/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8237 - auc_1: 0.8942 - loss: 0.3971 - val_accuracy: 0.8196 - val_auc_1: 0.0000e+00 - val_loss: 0.4159
# Epoch 117/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8192 - auc_1: 0.8903 - loss: 0.4038 - val_accuracy: 0.8244 - val_auc_1: 0.0000e+00 - val_loss: 0.4063
# Epoch 118/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8200 - auc_1: 0.8934 - loss: 0.3990 - val_accuracy: 0.8226 - val_auc_1: 0.0000e+00 - val_loss: 0.4109
# Epoch 119/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8174 - auc_1: 0.8923 - loss: 0.3994 - val_accuracy: 0.8264 - val_auc_1: 0.0000e+00 - val_loss: 0.4041
# Epoch 120/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8199 - auc_1: 0.8937 - loss: 0.3985 - val_accuracy: 0.8236 - val_auc_1: 0.0000e+00 - val_loss: 0.4092
# Epoch 121/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8236 - auc_1: 0.8963 - loss: 0.3917 - val_accuracy: 0.8252 - val_auc_1: 0.0000e+00 - val_loss: 0.4043
# Epoch 122/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8186 - auc_1: 0.8915 - loss: 0.4012 - val_accuracy: 0.8226 - val_auc_1: 0.0000e+00 - val_loss: 0.4104
# Epoch 123/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8223 - auc_1: 0.8926 - loss: 0.3997 - val_accuracy: 0.8289 - val_auc_1: 0.0000e+00 - val_loss: 0.4009
# Epoch 124/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8229 - auc_1: 0.8947 - loss: 0.3961 - val_accuracy: 0.8209 - val_auc_1: 0.0000e+00 - val_loss: 0.4106
# Epoch 125/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8222 - auc_1: 0.8962 - loss: 0.3931 - val_accuracy: 0.8324 - val_auc_1: 0.0000e+00 - val_loss: 0.3994
# Epoch 126/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8248 - auc_1: 0.8961 - loss: 0.3932 - val_accuracy: 0.8332 - val_auc_1: 0.0000e+00 - val_loss: 0.3982
# Epoch 127/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8197 - auc_1: 0.8932 - loss: 0.3996 - val_accuracy: 0.8236 - val_auc_1: 0.0000e+00 - val_loss: 0.4112
# Epoch 128/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8221 - auc_1: 0.8955 - loss: 0.3939 - val_accuracy: 0.8327 - val_auc_1: 0.0000e+00 - val_loss: 0.3987
# Epoch 129/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8228 - auc_1: 0.8932 - loss: 0.3978 - val_accuracy: 0.8261 - val_auc_1: 0.0000e+00 - val_loss: 0.4092
# Epoch 130/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8186 - auc_1: 0.8937 - loss: 0.3980 - val_accuracy: 0.8253 - val_auc_1: 0.0000e+00 - val_loss: 0.4096
# Epoch 131/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8170 - auc_1: 0.8913 - loss: 0.4019 - val_accuracy: 0.8320 - val_auc_1: 0.0000e+00 - val_loss: 0.4006
# Epoch 132/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8257 - auc_1: 0.8972 - loss: 0.3914 - val_accuracy: 0.8269 - val_auc_1: 0.0000e+00 - val_loss: 0.4066
# Epoch 133/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8240 - auc_1: 0.8960 - loss: 0.3935 - val_accuracy: 0.8353 - val_auc_1: 0.0000e+00 - val_loss: 0.4003
# Epoch 134/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8249 - auc_1: 0.8972 - loss: 0.3900 - val_accuracy: 0.8339 - val_auc_1: 0.0000e+00 - val_loss: 0.4015
# Epoch 135/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8190 - auc_1: 0.8931 - loss: 0.3983 - val_accuracy: 0.8292 - val_auc_1: 0.0000e+00 - val_loss: 0.4096
# Epoch 136/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8216 - auc_1: 0.8948 - loss: 0.3952 - val_accuracy: 0.8288 - val_auc_1: 0.0000e+00 - val_loss: 0.4033
# Epoch 137/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8215 - auc_1: 0.8945 - loss: 0.3976 - val_accuracy: 0.8298 - val_auc_1: 0.0000e+00 - val_loss: 0.4066
# Epoch 138/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8224 - auc_1: 0.8943 - loss: 0.3967 - val_accuracy: 0.8348 - val_auc_1: 0.0000e+00 - val_loss: 0.4017
# Epoch 139/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8247 - auc_1: 0.8966 - loss: 0.3922 - val_accuracy: 0.8367 - val_auc_1: 0.0000e+00 - val_loss: 0.3994
# Epoch 140/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8225 - auc_1: 0.8954 - loss: 0.3952 - val_accuracy: 0.8317 - val_auc_1: 0.0000e+00 - val_loss: 0.4085
# Epoch 141/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8237 - auc_1: 0.8954 - loss: 0.3937 - val_accuracy: 0.8354 - val_auc_1: 0.0000e+00 - val_loss: 0.4039
# Epoch 142/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8228 - auc_1: 0.8959 - loss: 0.3937 - val_accuracy: 0.8388 - val_auc_1: 0.0000e+00 - val_loss: 0.3961
# Epoch 143/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8239 - auc_1: 0.8971 - loss: 0.3908 - val_accuracy: 0.8317 - val_auc_1: 0.0000e+00 - val_loss: 0.4050
# Epoch 144/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8220 - auc_1: 0.8953 - loss: 0.3931 - val_accuracy: 0.8388 - val_auc_1: 0.0000e+00 - val_loss: 0.3964
# Epoch 145/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8247 - auc_1: 0.8981 - loss: 0.3879 - val_accuracy: 0.8424 - val_auc_1: 0.0000e+00 - val_loss: 0.3912
# Epoch 146/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8245 - auc_1: 0.8974 - loss: 0.3900 - val_accuracy: 0.8372 - val_auc_1: 0.0000e+00 - val_loss: 0.4008
# Epoch 147/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8233 - auc_1: 0.8983 - loss: 0.3894 - val_accuracy: 0.8409 - val_auc_1: 0.0000e+00 - val_loss: 0.3909
# Epoch 148/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8232 - auc_1: 0.8960 - loss: 0.3927 - val_accuracy: 0.8433 - val_auc_1: 0.0000e+00 - val_loss: 0.3921
# Epoch 149/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8262 - auc_1: 0.8977 - loss: 0.3900 - val_accuracy: 0.8392 - val_auc_1: 0.0000e+00 - val_loss: 0.3987
# Epoch 150/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8244 - auc_1: 0.8976 - loss: 0.3914 - val_accuracy: 0.8435 - val_auc_1: 0.0000e+00 - val_loss: 0.3923
# Epoch 151/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8255 - auc_1: 0.8969 - loss: 0.3929 - val_accuracy: 0.8425 - val_auc_1: 0.0000e+00 - val_loss: 0.3960
# Epoch 152/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8253 - auc_1: 0.8965 - loss: 0.3928 - val_accuracy: 0.8410 - val_auc_1: 0.0000e+00 - val_loss: 0.3965
# Epoch 153/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8235 - auc_1: 0.8965 - loss: 0.3910 - val_accuracy: 0.8442 - val_auc_1: 0.0000e+00 - val_loss: 0.3922
# Epoch 154/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8236 - auc_1: 0.8965 - loss: 0.3933 - val_accuracy: 0.8410 - val_auc_1: 0.0000e+00 - val_loss: 0.3982
# Epoch 155/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8286 - auc_1: 0.8989 - loss: 0.3872 - val_accuracy: 0.8420 - val_auc_1: 0.0000e+00 - val_loss: 0.3899
# Epoch 156/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8232 - auc_1: 0.8972 - loss: 0.3921 - val_accuracy: 0.8384 - val_auc_1: 0.0000e+00 - val_loss: 0.3978
# Epoch 157/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8254 - auc_1: 0.8980 - loss: 0.3908 - val_accuracy: 0.8398 - val_auc_1: 0.0000e+00 - val_loss: 0.3987
# Epoch 158/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8267 - auc_1: 0.8995 - loss: 0.3880 - val_accuracy: 0.8408 - val_auc_1: 0.0000e+00 - val_loss: 0.3941
# Epoch 159/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8254 - auc_1: 0.8967 - loss: 0.3919 - val_accuracy: 0.8425 - val_auc_1: 0.0000e+00 - val_loss: 0.3936
# Epoch 160/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8262 - auc_1: 0.8990 - loss: 0.3886 - val_accuracy: 0.8421 - val_auc_1: 0.0000e+00 - val_loss: 0.3959
# Epoch 161/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8278 - auc_1: 0.8984 - loss: 0.3885 - val_accuracy: 0.8468 - val_auc_1: 0.0000e+00 - val_loss: 0.3883
# Epoch 162/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8266 - auc_1: 0.8996 - loss: 0.3861 - val_accuracy: 0.8397 - val_auc_1: 0.0000e+00 - val_loss: 0.3990
# Epoch 163/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8258 - auc_1: 0.8984 - loss: 0.3889 - val_accuracy: 0.8447 - val_auc_1: 0.0000e+00 - val_loss: 0.3936
# Epoch 164/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8291 - auc_1: 0.9009 - loss: 0.3851 - val_accuracy: 0.8454 - val_auc_1: 0.0000e+00 - val_loss: 0.3936
# Epoch 165/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8271 - auc_1: 0.8996 - loss: 0.3870 - val_accuracy: 0.8411 - val_auc_1: 0.0000e+00 - val_loss: 0.3967
# Epoch 166/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8264 - auc_1: 0.8993 - loss: 0.3863 - val_accuracy: 0.8402 - val_auc_1: 0.0000e+00 - val_loss: 0.3956
# Epoch 167/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8261 - auc_1: 0.8987 - loss: 0.3881 - val_accuracy: 0.8443 - val_auc_1: 0.0000e+00 - val_loss: 0.3920
# Epoch 168/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8256 - auc_1: 0.8995 - loss: 0.3863 - val_accuracy: 0.8452 - val_auc_1: 0.0000e+00 - val_loss: 0.3917
# Epoch 169/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8285 - auc_1: 0.9007 - loss: 0.3840 - val_accuracy: 0.8459 - val_auc_1: 0.0000e+00 - val_loss: 0.3897
# Epoch 170/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8300 - auc_1: 0.9015 - loss: 0.3834 - val_accuracy: 0.8411 - val_auc_1: 0.0000e+00 - val_loss: 0.3967
# Epoch 171/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8278 - auc_1: 0.9002 - loss: 0.3855 - val_accuracy: 0.8471 - val_auc_1: 0.0000e+00 - val_loss: 0.3914
# Epoch 172/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8260 - auc_1: 0.9000 - loss: 0.3855 - val_accuracy: 0.8481 - val_auc_1: 0.0000e+00 - val_loss: 0.3911
# Epoch 173/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8292 - auc_1: 0.9007 - loss: 0.3835 - val_accuracy: 0.8494 - val_auc_1: 0.0000e+00 - val_loss: 0.3842
# Epoch 174/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8264 - auc_1: 0.9004 - loss: 0.3841 - val_accuracy: 0.8510 - val_auc_1: 0.0000e+00 - val_loss: 0.3867
# Epoch 175/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8277 - auc_1: 0.9003 - loss: 0.3836 - val_accuracy: 0.8509 - val_auc_1: 0.0000e+00 - val_loss: 0.3868
# Epoch 176/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8263 - auc_1: 0.8995 - loss: 0.3868 - val_accuracy: 0.8479 - val_auc_1: 0.0000e+00 - val_loss: 0.3978
# Epoch 177/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8302 - auc_1: 0.9018 - loss: 0.3824 - val_accuracy: 0.8526 - val_auc_1: 0.0000e+00 - val_loss: 0.3835
# Epoch 178/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8298 - auc_1: 0.9020 - loss: 0.3825 - val_accuracy: 0.8464 - val_auc_1: 0.0000e+00 - val_loss: 0.3961
# Epoch 179/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8279 - auc_1: 0.9000 - loss: 0.3863 - val_accuracy: 0.8521 - val_auc_1: 0.0000e+00 - val_loss: 0.3900
# Epoch 180/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8247 - auc_1: 0.8997 - loss: 0.3863 - val_accuracy: 0.8521 - val_auc_1: 0.0000e+00 - val_loss: 0.3849
# Epoch 181/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8309 - auc_1: 0.9012 - loss: 0.3832 - val_accuracy: 0.8513 - val_auc_1: 0.0000e+00 - val_loss: 0.3832
# Epoch 182/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8279 - auc_1: 0.9006 - loss: 0.3848 - val_accuracy: 0.8471 - val_auc_1: 0.0000e+00 - val_loss: 0.3890
# Epoch 183/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8270 - auc_1: 0.8988 - loss: 0.3884 - val_accuracy: 0.8494 - val_auc_1: 0.0000e+00 - val_loss: 0.3870
# Epoch 184/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8294 - auc_1: 0.9016 - loss: 0.3824 - val_accuracy: 0.8516 - val_auc_1: 0.0000e+00 - val_loss: 0.3817
# Epoch 185/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8298 - auc_1: 0.9011 - loss: 0.3841 - val_accuracy: 0.8512 - val_auc_1: 0.0000e+00 - val_loss: 0.3874
# Epoch 186/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8278 - auc_1: 0.9009 - loss: 0.3835 - val_accuracy: 0.8500 - val_auc_1: 0.0000e+00 - val_loss: 0.3867
# Epoch 187/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8272 - auc_1: 0.9007 - loss: 0.3833 - val_accuracy: 0.8509 - val_auc_1: 0.0000e+00 - val_loss: 0.3855
# Epoch 188/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8264 - auc_1: 0.9000 - loss: 0.3865 - val_accuracy: 0.8523 - val_auc_1: 0.0000e+00 - val_loss: 0.3846
# Epoch 189/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8312 - auc_1: 0.9024 - loss: 0.3808 - val_accuracy: 0.8492 - val_auc_1: 0.0000e+00 - val_loss: 0.3856
# Epoch 190/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8301 - auc_1: 0.9011 - loss: 0.3830 - val_accuracy: 0.8538 - val_auc_1: 0.0000e+00 - val_loss: 0.3826
# Epoch 191/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8310 - auc_1: 0.9034 - loss: 0.3787 - val_accuracy: 0.8506 - val_auc_1: 0.0000e+00 - val_loss: 0.3848
# Epoch 192/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8260 - auc_1: 0.8993 - loss: 0.3864 - val_accuracy: 0.8486 - val_auc_1: 0.0000e+00 - val_loss: 0.3878
# Epoch 193/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8277 - auc_1: 0.9007 - loss: 0.3838 - val_accuracy: 0.8506 - val_auc_1: 0.0000e+00 - val_loss: 0.3790
# Epoch 194/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8253 - auc_1: 0.9001 - loss: 0.3849 - val_accuracy: 0.8501 - val_auc_1: 0.0000e+00 - val_loss: 0.3845
# Epoch 195/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8278 - auc_1: 0.8996 - loss: 0.3851 - val_accuracy: 0.8535 - val_auc_1: 0.0000e+00 - val_loss: 0.3730
# Epoch 196/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8313 - auc_1: 0.9025 - loss: 0.3812 - val_accuracy: 0.8449 - val_auc_1: 0.0000e+00 - val_loss: 0.3839
# Epoch 197/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8269 - auc_1: 0.9013 - loss: 0.3834 - val_accuracy: 0.8499 - val_auc_1: 0.0000e+00 - val_loss: 0.3837
# Epoch 198/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8280 - auc_1: 0.9016 - loss: 0.3824 - val_accuracy: 0.8496 - val_auc_1: 0.0000e+00 - val_loss: 0.3835
# Epoch 199/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8294 - auc_1: 0.9010 - loss: 0.3833 - val_accuracy: 0.8458 - val_auc_1: 0.0000e+00 - val_loss: 0.3883
# Epoch 200/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8283 - auc_1: 0.9010 - loss: 0.3834 - val_accuracy: 0.8515 - val_auc_1: 0.0000e+00 - val_loss: 0.3788
# Epoch 201/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8315 - auc_1: 0.9039 - loss: 0.3780 - val_accuracy: 0.8480 - val_auc_1: 0.0000e+00 - val_loss: 0.3839
# Epoch 202/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8307 - auc_1: 0.9029 - loss: 0.3805 - val_accuracy: 0.8506 - val_auc_1: 0.0000e+00 - val_loss: 0.3820
# Epoch 203/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8293 - auc_1: 0.9019 - loss: 0.3819 - val_accuracy: 0.8483 - val_auc_1: 0.0000e+00 - val_loss: 0.3838
# Epoch 204/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8284 - auc_1: 0.9013 - loss: 0.3813 - val_accuracy: 0.8515 - val_auc_1: 0.0000e+00 - val_loss: 0.3832
# Epoch 205/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8308 - auc_1: 0.9024 - loss: 0.3812 - val_accuracy: 0.8538 - val_auc_1: 0.0000e+00 - val_loss: 0.3798
# Epoch 206/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8256 - auc_1: 0.9015 - loss: 0.3822 - val_accuracy: 0.8520 - val_auc_1: 0.0000e+00 - val_loss: 0.3802
# Epoch 207/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8274 - auc_1: 0.9011 - loss: 0.3840 - val_accuracy: 0.8498 - val_auc_1: 0.0000e+00 - val_loss: 0.3826
# Epoch 208/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8271 - auc_1: 0.9018 - loss: 0.3815 - val_accuracy: 0.8563 - val_auc_1: 0.0000e+00 - val_loss: 0.3717
# Epoch 209/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8317 - auc_1: 0.9033 - loss: 0.3787 - val_accuracy: 0.8547 - val_auc_1: 0.0000e+00 - val_loss: 0.3758
# Epoch 210/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8276 - auc_1: 0.9019 - loss: 0.3819 - val_accuracy: 0.8544 - val_auc_1: 0.0000e+00 - val_loss: 0.3813
# Epoch 211/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8282 - auc_1: 0.9026 - loss: 0.3796 - val_accuracy: 0.8571 - val_auc_1: 0.0000e+00 - val_loss: 0.3764
# Epoch 212/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8300 - auc_1: 0.9030 - loss: 0.3801 - val_accuracy: 0.8577 - val_auc_1: 0.0000e+00 - val_loss: 0.3723
# Epoch 213/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8329 - auc_1: 0.9042 - loss: 0.3770 - val_accuracy: 0.8519 - val_auc_1: 0.0000e+00 - val_loss: 0.3803
# Epoch 214/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8303 - auc_1: 0.9045 - loss: 0.3779 - val_accuracy: 0.8506 - val_auc_1: 0.0000e+00 - val_loss: 0.3806
# Epoch 215/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8311 - auc_1: 0.9049 - loss: 0.3770 - val_accuracy: 0.8514 - val_auc_1: 0.0000e+00 - val_loss: 0.3805
# Epoch 216/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8291 - auc_1: 0.9028 - loss: 0.3802 - val_accuracy: 0.8518 - val_auc_1: 0.0000e+00 - val_loss: 0.3804
# Epoch 217/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8356 - auc_1: 0.9069 - loss: 0.3728 - val_accuracy: 0.8558 - val_auc_1: 0.0000e+00 - val_loss: 0.3781
# Epoch 218/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8319 - auc_1: 0.9050 - loss: 0.3759 - val_accuracy: 0.8573 - val_auc_1: 0.0000e+00 - val_loss: 0.3742
# Epoch 219/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8266 - auc_1: 0.9004 - loss: 0.3847 - val_accuracy: 0.8473 - val_auc_1: 0.0000e+00 - val_loss: 0.3839
# Epoch 220/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8331 - auc_1: 0.9057 - loss: 0.3751 - val_accuracy: 0.8546 - val_auc_1: 0.0000e+00 - val_loss: 0.3719
# Epoch 221/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8288 - auc_1: 0.9020 - loss: 0.3812 - val_accuracy: 0.8502 - val_auc_1: 0.0000e+00 - val_loss: 0.3795
# Epoch 222/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8275 - auc_1: 0.9021 - loss: 0.3820 - val_accuracy: 0.8496 - val_auc_1: 0.0000e+00 - val_loss: 0.3798
# Epoch 223/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8268 - auc_1: 0.9008 - loss: 0.3839 - val_accuracy: 0.8516 - val_auc_1: 0.0000e+00 - val_loss: 0.3754
# Epoch 224/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8320 - auc_1: 0.9033 - loss: 0.3784 - val_accuracy: 0.8504 - val_auc_1: 0.0000e+00 - val_loss: 0.3772
# Epoch 225/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8337 - auc_1: 0.9046 - loss: 0.3767 - val_accuracy: 0.8455 - val_auc_1: 0.0000e+00 - val_loss: 0.3814
# Epoch 226/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8276 - auc_1: 0.9017 - loss: 0.3830 - val_accuracy: 0.8535 - val_auc_1: 0.0000e+00 - val_loss: 0.3800
# Epoch 227/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8298 - auc_1: 0.9047 - loss: 0.3770 - val_accuracy: 0.8552 - val_auc_1: 0.0000e+00 - val_loss: 0.3763
# Epoch 228/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8329 - auc_1: 0.9035 - loss: 0.3784 - val_accuracy: 0.8510 - val_auc_1: 0.0000e+00 - val_loss: 0.3797
# Epoch 229/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8294 - auc_1: 0.9027 - loss: 0.3802 - val_accuracy: 0.8549 - val_auc_1: 0.0000e+00 - val_loss: 0.3757
# Epoch 230/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8289 - auc_1: 0.9023 - loss: 0.3806 - val_accuracy: 0.8591 - val_auc_1: 0.0000e+00 - val_loss: 0.3701
# Epoch 231/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8305 - auc_1: 0.9030 - loss: 0.3793 - val_accuracy: 0.8598 - val_auc_1: 0.0000e+00 - val_loss: 0.3695
# Epoch 232/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8337 - auc_1: 0.9047 - loss: 0.3768 - val_accuracy: 0.8585 - val_auc_1: 0.0000e+00 - val_loss: 0.3718
# Epoch 233/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8329 - auc_1: 0.9052 - loss: 0.3758 - val_accuracy: 0.8529 - val_auc_1: 0.0000e+00 - val_loss: 0.3777
# Epoch 234/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8308 - auc_1: 0.9031 - loss: 0.3792 - val_accuracy: 0.8559 - val_auc_1: 0.0000e+00 - val_loss: 0.3741
# Epoch 235/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8302 - auc_1: 0.9038 - loss: 0.3778 - val_accuracy: 0.8505 - val_auc_1: 0.0000e+00 - val_loss: 0.3808
# Epoch 236/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8296 - auc_1: 0.9032 - loss: 0.3789 - val_accuracy: 0.8578 - val_auc_1: 0.0000e+00 - val_loss: 0.3715
# Epoch 237/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8317 - auc_1: 0.9055 - loss: 0.3766 - val_accuracy: 0.8535 - val_auc_1: 0.0000e+00 - val_loss: 0.3785
# Epoch 238/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8307 - auc_1: 0.9030 - loss: 0.3791 - val_accuracy: 0.8548 - val_auc_1: 0.0000e+00 - val_loss: 0.3751
# Epoch 239/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8300 - auc_1: 0.9049 - loss: 0.3766 - val_accuracy: 0.8569 - val_auc_1: 0.0000e+00 - val_loss: 0.3724
# Epoch 240/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8303 - auc_1: 0.9038 - loss: 0.3776 - val_accuracy: 0.8613 - val_auc_1: 0.0000e+00 - val_loss: 0.3664
# Epoch 241/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8312 - auc_1: 0.9058 - loss: 0.3742 - val_accuracy: 0.8525 - val_auc_1: 0.0000e+00 - val_loss: 0.3752
# Epoch 242/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8292 - auc_1: 0.9051 - loss: 0.3757 - val_accuracy: 0.8568 - val_auc_1: 0.0000e+00 - val_loss: 0.3688
# Epoch 243/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8299 - auc_1: 0.9045 - loss: 0.3772 - val_accuracy: 0.8528 - val_auc_1: 0.0000e+00 - val_loss: 0.3727
# Epoch 244/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8316 - auc_1: 0.9051 - loss: 0.3761 - val_accuracy: 0.8558 - val_auc_1: 0.0000e+00 - val_loss: 0.3739
# Epoch 245/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8309 - auc_1: 0.9053 - loss: 0.3753 - val_accuracy: 0.8554 - val_auc_1: 0.0000e+00 - val_loss: 0.3741
# Epoch 246/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8297 - auc_1: 0.9033 - loss: 0.3790 - val_accuracy: 0.8573 - val_auc_1: 0.0000e+00 - val_loss: 0.3683
# Epoch 247/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8326 - auc_1: 0.9059 - loss: 0.3756 - val_accuracy: 0.8564 - val_auc_1: 0.0000e+00 - val_loss: 0.3694
# Epoch 248/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8301 - auc_1: 0.9039 - loss: 0.3767 - val_accuracy: 0.8555 - val_auc_1: 0.0000e+00 - val_loss: 0.3682
# Epoch 249/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8320 - auc_1: 0.9052 - loss: 0.3761 - val_accuracy: 0.8548 - val_auc_1: 0.0000e+00 - val_loss: 0.3723
# Epoch 250/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8333 - auc_1: 0.9056 - loss: 0.3737 - val_accuracy: 0.8555 - val_auc_1: 0.0000e+00 - val_loss: 0.3689
# Epoch 251/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8299 - auc_1: 0.9025 - loss: 0.3813 - val_accuracy: 0.8528 - val_auc_1: 0.0000e+00 - val_loss: 0.3737
# Epoch 252/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8318 - auc_1: 0.9040 - loss: 0.3769 - val_accuracy: 0.8568 - val_auc_1: 0.0000e+00 - val_loss: 0.3666
# Epoch 253/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8307 - auc_1: 0.9049 - loss: 0.3764 - val_accuracy: 0.8523 - val_auc_1: 0.0000e+00 - val_loss: 0.3762
# Epoch 254/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8291 - auc_1: 0.9041 - loss: 0.3765 - val_accuracy: 0.8547 - val_auc_1: 0.0000e+00 - val_loss: 0.3692
# Epoch 255/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8304 - auc_1: 0.9051 - loss: 0.3756 - val_accuracy: 0.8498 - val_auc_1: 0.0000e+00 - val_loss: 0.3724
# Epoch 256/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8313 - auc_1: 0.9052 - loss: 0.3752 - val_accuracy: 0.8530 - val_auc_1: 0.0000e+00 - val_loss: 0.3712
# Epoch 257/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8331 - auc_1: 0.9063 - loss: 0.3737 - val_accuracy: 0.8499 - val_auc_1: 0.0000e+00 - val_loss: 0.3754
# Epoch 258/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8344 - auc_1: 0.9066 - loss: 0.3733 - val_accuracy: 0.8554 - val_auc_1: 0.0000e+00 - val_loss: 0.3661
# Epoch 259/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8339 - auc_1: 0.9064 - loss: 0.3737 - val_accuracy: 0.8543 - val_auc_1: 0.0000e+00 - val_loss: 0.3711
# Epoch 260/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8328 - auc_1: 0.9064 - loss: 0.3739 - val_accuracy: 0.8567 - val_auc_1: 0.0000e+00 - val_loss: 0.3659
# Epoch 261/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8300 - auc_1: 0.9032 - loss: 0.3794 - val_accuracy: 0.8543 - val_auc_1: 0.0000e+00 - val_loss: 0.3733
# Epoch 262/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8329 - auc_1: 0.9058 - loss: 0.3738 - val_accuracy: 0.8624 - val_auc_1: 0.0000e+00 - val_loss: 0.3599
# Epoch 263/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8328 - auc_1: 0.9062 - loss: 0.3740 - val_accuracy: 0.8577 - val_auc_1: 0.0000e+00 - val_loss: 0.3697
# Epoch 264/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8310 - auc_1: 0.9053 - loss: 0.3752 - val_accuracy: 0.8595 - val_auc_1: 0.0000e+00 - val_loss: 0.3665
# Epoch 265/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8314 - auc_1: 0.9048 - loss: 0.3765 - val_accuracy: 0.8587 - val_auc_1: 0.0000e+00 - val_loss: 0.3621
# Epoch 266/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8309 - auc_1: 0.9067 - loss: 0.3724 - val_accuracy: 0.8549 - val_auc_1: 0.0000e+00 - val_loss: 0.3689
# Epoch 267/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8311 - auc_1: 0.9064 - loss: 0.3736 - val_accuracy: 0.8536 - val_auc_1: 0.0000e+00 - val_loss: 0.3738
# Epoch 268/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8340 - auc_1: 0.9055 - loss: 0.3735 - val_accuracy: 0.8631 - val_auc_1: 0.0000e+00 - val_loss: 0.3560
# Epoch 269/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8332 - auc_1: 0.9055 - loss: 0.3742 - val_accuracy: 0.8558 - val_auc_1: 0.0000e+00 - val_loss: 0.3678
# Epoch 270/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8318 - auc_1: 0.9062 - loss: 0.3740 - val_accuracy: 0.8580 - val_auc_1: 0.0000e+00 - val_loss: 0.3654
# Epoch 271/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8316 - auc_1: 0.9053 - loss: 0.3754 - val_accuracy: 0.8587 - val_auc_1: 0.0000e+00 - val_loss: 0.3655
# Epoch 272/800
# ...
# Epoch 708/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8409 - auc_1: 0.9161 - loss: 0.3540 - val_accuracy: 0.8734 - val_auc_1: 0.0000e+00 - val_loss: 0.3273
# Epoch 709/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8462 - auc_1: 0.9190 - loss: 0.3473 - val_accuracy: 0.8733 - val_auc_1: 0.0000e+00 - val_loss: 0.3280
# Epoch 710/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8445 - auc_1: 0.9193 - loss: 0.3481 - val_accuracy: 0.8722 - val_auc_1: 0.0000e+00 - val_loss: 0.3308
# Epoch 711/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8460 - auc_1: 0.9188 - loss: 0.3484 - val_accuracy: 0.8709 - val_auc_1: 0.0000e+00 - val_loss: 0.3283
# Epoch 712/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8474 - auc_1: 0.9206 - loss: 0.3439 - val_accuracy: 0.8725 - val_auc_1: 0.0000e+00 - val_loss: 0.3262
# Epoch 713/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8464 - auc_1: 0.9179 - loss: 0.3489 - val_accuracy: 0.8717 - val_auc_1: 0.0000e+00 - val_loss: 0.3254
# Epoch 714/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8439 - auc_1: 0.9184 - loss: 0.3489 - val_accuracy: 0.8714 - val_auc_1: 0.0000e+00 - val_loss: 0.3277
# Epoch 715/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8407 - auc_1: 0.9166 - loss: 0.3536 - val_accuracy: 0.8775 - val_auc_1: 0.0000e+00 - val_loss: 0.3242
# Epoch 716/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8454 - auc_1: 0.9191 - loss: 0.3474 - val_accuracy: 0.8769 - val_auc_1: 0.0000e+00 - val_loss: 0.3213
# Epoch 717/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8452 - auc_1: 0.9184 - loss: 0.3488 - val_accuracy: 0.8685 - val_auc_1: 0.0000e+00 - val_loss: 0.3313
# Epoch 718/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8417 - auc_1: 0.9163 - loss: 0.3531 - val_accuracy: 0.8760 - val_auc_1: 0.0000e+00 - val_loss: 0.3233
# Epoch 719/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8456 - auc_1: 0.9181 - loss: 0.3494 - val_accuracy: 0.8716 - val_auc_1: 0.0000e+00 - val_loss: 0.3297
# Epoch 720/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8477 - auc_1: 0.9193 - loss: 0.3470 - val_accuracy: 0.8735 - val_auc_1: 0.0000e+00 - val_loss: 0.3309
# Epoch 721/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8462 - auc_1: 0.9208 - loss: 0.3438 - val_accuracy: 0.8740 - val_auc_1: 0.0000e+00 - val_loss: 0.3264
# Epoch 722/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8454 - auc_1: 0.9190 - loss: 0.3486 - val_accuracy: 0.8690 - val_auc_1: 0.0000e+00 - val_loss: 0.3309
# Epoch 723/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8441 - auc_1: 0.9184 - loss: 0.3486 - val_accuracy: 0.8710 - val_auc_1: 0.0000e+00 - val_loss: 0.3270
# Epoch 724/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8447 - auc_1: 0.9185 - loss: 0.3491 - val_accuracy: 0.8748 - val_auc_1: 0.0000e+00 - val_loss: 0.3272
# Epoch 725/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8448 - auc_1: 0.9199 - loss: 0.3466 - val_accuracy: 0.8748 - val_auc_1: 0.0000e+00 - val_loss: 0.3284
# Epoch 726/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8433 - auc_1: 0.9190 - loss: 0.3479 - val_accuracy: 0.8743 - val_auc_1: 0.0000e+00 - val_loss: 0.3290
# Epoch 727/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8427 - auc_1: 0.9177 - loss: 0.3504 - val_accuracy: 0.8696 - val_auc_1: 0.0000e+00 - val_loss: 0.3287
# Epoch 728/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8463 - auc_1: 0.9189 - loss: 0.3482 - val_accuracy: 0.8683 - val_auc_1: 0.0000e+00 - val_loss: 0.3277
# Epoch 729/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8453 - auc_1: 0.9202 - loss: 0.3461 - val_accuracy: 0.8586 - val_auc_1: 0.0000e+00 - val_loss: 0.3359
# Epoch 730/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8448 - auc_1: 0.9182 - loss: 0.3497 - val_accuracy: 0.8712 - val_auc_1: 0.0000e+00 - val_loss: 0.3206
# Epoch 731/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8445 - auc_1: 0.9183 - loss: 0.3493 - val_accuracy: 0.8693 - val_auc_1: 0.0000e+00 - val_loss: 0.3300
# Epoch 732/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8466 - auc_1: 0.9193 - loss: 0.3466 - val_accuracy: 0.8643 - val_auc_1: 0.0000e+00 - val_loss: 0.3319
# Epoch 733/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8469 - auc_1: 0.9202 - loss: 0.3446 - val_accuracy: 0.8732 - val_auc_1: 0.0000e+00 - val_loss: 0.3192
# Epoch 734/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8433 - auc_1: 0.9173 - loss: 0.3511 - val_accuracy: 0.8652 - val_auc_1: 0.0000e+00 - val_loss: 0.3308
# Epoch 735/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8456 - auc_1: 0.9174 - loss: 0.3508 - val_accuracy: 0.8694 - val_auc_1: 0.0000e+00 - val_loss: 0.3233
# Epoch 736/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8437 - auc_1: 0.9181 - loss: 0.3497 - val_accuracy: 0.8626 - val_auc_1: 0.0000e+00 - val_loss: 0.3343
# Epoch 737/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8425 - auc_1: 0.9176 - loss: 0.3510 - val_accuracy: 0.8741 - val_auc_1: 0.0000e+00 - val_loss: 0.3215
# Epoch 738/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8442 - auc_1: 0.9181 - loss: 0.3497 - val_accuracy: 0.8632 - val_auc_1: 0.0000e+00 - val_loss: 0.3348
# Epoch 739/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8412 - auc_1: 0.9175 - loss: 0.3501 - val_accuracy: 0.8690 - val_auc_1: 0.0000e+00 - val_loss: 0.3279
# Epoch 740/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8456 - auc_1: 0.9179 - loss: 0.3493 - val_accuracy: 0.8726 - val_auc_1: 0.0000e+00 - val_loss: 0.3260
# Epoch 741/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8464 - auc_1: 0.9194 - loss: 0.3481 - val_accuracy: 0.8680 - val_auc_1: 0.0000e+00 - val_loss: 0.3311
# Epoch 742/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8455 - auc_1: 0.9189 - loss: 0.3484 - val_accuracy: 0.8716 - val_auc_1: 0.0000e+00 - val_loss: 0.3246
# Epoch 743/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8436 - auc_1: 0.9175 - loss: 0.3514 - val_accuracy: 0.8651 - val_auc_1: 0.0000e+00 - val_loss: 0.3307
# Epoch 744/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8401 - auc_1: 0.9166 - loss: 0.3522 - val_accuracy: 0.8715 - val_auc_1: 0.0000e+00 - val_loss: 0.3219
# Epoch 745/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8437 - auc_1: 0.9179 - loss: 0.3502 - val_accuracy: 0.8664 - val_auc_1: 0.0000e+00 - val_loss: 0.3280
# Epoch 746/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8459 - auc_1: 0.9196 - loss: 0.3455 - val_accuracy: 0.8725 - val_auc_1: 0.0000e+00 - val_loss: 0.3206
# Epoch 747/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8427 - auc_1: 0.9173 - loss: 0.3518 - val_accuracy: 0.8670 - val_auc_1: 0.0000e+00 - val_loss: 0.3295
# Epoch 748/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8448 - auc_1: 0.9193 - loss: 0.3473 - val_accuracy: 0.8623 - val_auc_1: 0.0000e+00 - val_loss: 0.3311
# Epoch 749/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8418 - auc_1: 0.9188 - loss: 0.3498 - val_accuracy: 0.8627 - val_auc_1: 0.0000e+00 - val_loss: 0.3338
# Epoch 750/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8431 - auc_1: 0.9178 - loss: 0.3503 - val_accuracy: 0.8685 - val_auc_1: 0.0000e+00 - val_loss: 0.3271
# Epoch 751/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8484 - auc_1: 0.9215 - loss: 0.3424 - val_accuracy: 0.8689 - val_auc_1: 0.0000e+00 - val_loss: 0.3268
# Epoch 752/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8446 - auc_1: 0.9198 - loss: 0.3464 - val_accuracy: 0.8672 - val_auc_1: 0.0000e+00 - val_loss: 0.3317
# Epoch 753/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8481 - auc_1: 0.9211 - loss: 0.3446 - val_accuracy: 0.8689 - val_auc_1: 0.0000e+00 - val_loss: 0.3295
# Epoch 754/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8459 - auc_1: 0.9184 - loss: 0.3489 - val_accuracy: 0.8746 - val_auc_1: 0.0000e+00 - val_loss: 0.3240
# Epoch 755/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8463 - auc_1: 0.9186 - loss: 0.3490 - val_accuracy: 0.8680 - val_auc_1: 0.0000e+00 - val_loss: 0.3286
# Epoch 756/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8465 - auc_1: 0.9207 - loss: 0.3443 - val_accuracy: 0.8646 - val_auc_1: 0.0000e+00 - val_loss: 0.3351
# Epoch 757/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8452 - auc_1: 0.9183 - loss: 0.3494 - val_accuracy: 0.8685 - val_auc_1: 0.0000e+00 - val_loss: 0.3291
# Epoch 758/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8467 - auc_1: 0.9210 - loss: 0.3433 - val_accuracy: 0.8656 - val_auc_1: 0.0000e+00 - val_loss: 0.3298
# Epoch 759/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8449 - auc_1: 0.9180 - loss: 0.3494 - val_accuracy: 0.8702 - val_auc_1: 0.0000e+00 - val_loss: 0.3251
# Epoch 760/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8484 - auc_1: 0.9200 - loss: 0.3454 - val_accuracy: 0.8703 - val_auc_1: 0.0000e+00 - val_loss: 0.3281
# Epoch 761/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8465 - auc_1: 0.9186 - loss: 0.3483 - val_accuracy: 0.8765 - val_auc_1: 0.0000e+00 - val_loss: 0.3210
# Epoch 762/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8459 - auc_1: 0.9200 - loss: 0.3458 - val_accuracy: 0.8777 - val_auc_1: 0.0000e+00 - val_loss: 0.3214
# Epoch 763/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8444 - auc_1: 0.9189 - loss: 0.3474 - val_accuracy: 0.8704 - val_auc_1: 0.0000e+00 - val_loss: 0.3309
# Epoch 764/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8484 - auc_1: 0.9197 - loss: 0.3464 - val_accuracy: 0.8709 - val_auc_1: 0.0000e+00 - val_loss: 0.3298
# Epoch 765/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8454 - auc_1: 0.9199 - loss: 0.3466 - val_accuracy: 0.8716 - val_auc_1: 0.0000e+00 - val_loss: 0.3297
# Epoch 766/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8443 - auc_1: 0.9189 - loss: 0.3478 - val_accuracy: 0.8796 - val_auc_1: 0.0000e+00 - val_loss: 0.3208
# Epoch 767/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8452 - auc_1: 0.9187 - loss: 0.3476 - val_accuracy: 0.8699 - val_auc_1: 0.0000e+00 - val_loss: 0.3275
# Epoch 768/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8454 - auc_1: 0.9199 - loss: 0.3458 - val_accuracy: 0.8753 - val_auc_1: 0.0000e+00 - val_loss: 0.3250
# Epoch 769/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8461 - auc_1: 0.9191 - loss: 0.3483 - val_accuracy: 0.8718 - val_auc_1: 0.0000e+00 - val_loss: 0.3281
# Epoch 770/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8461 - auc_1: 0.9205 - loss: 0.3439 - val_accuracy: 0.8682 - val_auc_1: 0.0000e+00 - val_loss: 0.3304
# Epoch 771/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8433 - auc_1: 0.9187 - loss: 0.3483 - val_accuracy: 0.8722 - val_auc_1: 0.0000e+00 - val_loss: 0.3251
# Epoch 772/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8460 - auc_1: 0.9194 - loss: 0.3467 - val_accuracy: 0.8722 - val_auc_1: 0.0000e+00 - val_loss: 0.3246
# Epoch 773/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8443 - auc_1: 0.9198 - loss: 0.3465 - val_accuracy: 0.8757 - val_auc_1: 0.0000e+00 - val_loss: 0.3248
# Epoch 774/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8456 - auc_1: 0.9208 - loss: 0.3443 - val_accuracy: 0.8706 - val_auc_1: 0.0000e+00 - val_loss: 0.3304
# Epoch 775/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8475 - auc_1: 0.9211 - loss: 0.3427 - val_accuracy: 0.8800 - val_auc_1: 0.0000e+00 - val_loss: 0.3212
# Epoch 776/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8463 - auc_1: 0.9187 - loss: 0.3479 - val_accuracy: 0.8758 - val_auc_1: 0.0000e+00 - val_loss: 0.3253
# Epoch 777/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8452 - auc_1: 0.9189 - loss: 0.3490 - val_accuracy: 0.8751 - val_auc_1: 0.0000e+00 - val_loss: 0.3281
# Epoch 778/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8457 - auc_1: 0.9183 - loss: 0.3503 - val_accuracy: 0.8792 - val_auc_1: 0.0000e+00 - val_loss: 0.3231
# Epoch 779/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8451 - auc_1: 0.9171 - loss: 0.3519 - val_accuracy: 0.8769 - val_auc_1: 0.0000e+00 - val_loss: 0.3228
# Epoch 780/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8451 - auc_1: 0.9182 - loss: 0.3493 - val_accuracy: 0.8663 - val_auc_1: 0.0000e+00 - val_loss: 0.3337
# Epoch 781/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8440 - auc_1: 0.9196 - loss: 0.3471 - val_accuracy: 0.8819 - val_auc_1: 0.0000e+00 - val_loss: 0.3188
# Epoch 782/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8458 - auc_1: 0.9173 - loss: 0.3502 - val_accuracy: 0.8778 - val_auc_1: 0.0000e+00 - val_loss: 0.3203
# Epoch 783/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8427 - auc_1: 0.9170 - loss: 0.3516 - val_accuracy: 0.8709 - val_auc_1: 0.0000e+00 - val_loss: 0.3293
# Epoch 784/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8499 - auc_1: 0.9224 - loss: 0.3412 - val_accuracy: 0.8784 - val_auc_1: 0.0000e+00 - val_loss: 0.3193
# Epoch 785/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8450 - auc_1: 0.9193 - loss: 0.3464 - val_accuracy: 0.8758 - val_auc_1: 0.0000e+00 - val_loss: 0.3277
# Epoch 786/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8468 - auc_1: 0.9214 - loss: 0.3436 - val_accuracy: 0.8810 - val_auc_1: 0.0000e+00 - val_loss: 0.3171
# Epoch 787/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8461 - auc_1: 0.9201 - loss: 0.3462 - val_accuracy: 0.8722 - val_auc_1: 0.0000e+00 - val_loss: 0.3276
# Epoch 788/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8438 - auc_1: 0.9194 - loss: 0.3463 - val_accuracy: 0.8779 - val_auc_1: 0.0000e+00 - val_loss: 0.3190
# Epoch 789/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8457 - auc_1: 0.9187 - loss: 0.3484 - val_accuracy: 0.8783 - val_auc_1: 0.0000e+00 - val_loss: 0.3178
# Epoch 790/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8479 - auc_1: 0.9205 - loss: 0.3448 - val_accuracy: 0.8722 - val_auc_1: 0.0000e+00 - val_loss: 0.3246
# Epoch 791/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8462 - auc_1: 0.9198 - loss: 0.3469 - val_accuracy: 0.8693 - val_auc_1: 0.0000e+00 - val_loss: 0.3291
# Epoch 792/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8480 - auc_1: 0.9200 - loss: 0.3449 - val_accuracy: 0.8784 - val_auc_1: 0.0000e+00 - val_loss: 0.3155
# Epoch 793/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8464 - auc_1: 0.9200 - loss: 0.3460 - val_accuracy: 0.8698 - val_auc_1: 0.0000e+00 - val_loss: 0.3268
# Epoch 794/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8450 - auc_1: 0.9193 - loss: 0.3472 - val_accuracy: 0.8727 - val_auc_1: 0.0000e+00 - val_loss: 0.3263
# Epoch 795/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8468 - auc_1: 0.9208 - loss: 0.3444 - val_accuracy: 0.8691 - val_auc_1: 0.0000e+00 - val_loss: 0.3262
# Epoch 796/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8485 - auc_1: 0.9218 - loss: 0.3418 - val_accuracy: 0.8732 - val_auc_1: 0.0000e+00 - val_loss: 0.3214
# Epoch 797/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8470 - auc_1: 0.9193 - loss: 0.3469 - val_accuracy: 0.8782 - val_auc_1: 0.0000e+00 - val_loss: 0.3216
# Epoch 798/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8455 - auc_1: 0.9206 - loss: 0.3442 - val_accuracy: 0.8727 - val_auc_1: 0.0000e+00 - val_loss: 0.3274
# Epoch 799/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8479 - auc_1: 0.9201 - loss: 0.3455 - val_accuracy: 0.8798 - val_auc_1: 0.0000e+00 - val_loss: 0.3158
# Epoch 800/800
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8460 - auc_1: 0.9208 - loss: 0.3450 - val_accuracy: 0.8736 - val_auc_1: 0.0000e+00 - val_loss: 0.3261
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# AUC: 0.9247485444473765
# AMS: 0.3528631634623696
# AMS total: 2.4951193571517876

# %%
#model.save('the25model.keras')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model.save('the25model.keras')
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:367, in _get_class_or_fn_config(obj)
#     365 # All classes:
#     366 if hasattr(obj, "get_config"):
# --> 367     config = obj.get_config()
#     368     if not isinstance(config, dict):
#     369         raise TypeError(
#     370             f"The `get_config()` method of {obj} should return "
#     371             f"a dict. It returned: {config}"
#     372         )
#
# TypeError: AUC.get_config() missing 1 required positional argument: 'self'

# %%
yhat = model.predict(x_val)
yhat = yhat.reshape((yhat.shape[0],))

ergebnis = find_best_ams_score(y_val, yhat, w_val)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
