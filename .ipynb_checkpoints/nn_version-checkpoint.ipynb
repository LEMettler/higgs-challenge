# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# # Data preparation

# %%
#import uproot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


import ROOT;
#import lumiere as lm
#lm.loadstyle(True);

from sklearn.metrics import roc_auc_score, roc_curve

def ams_score(x, y, w, cut):
# Calculate Average Mean Significane as defined in ATLAS paper
#    -  approximative formula for large statistics with regularisation
# x: array of truth values (1 if signal)
# y: array of classifier result
# w: array of event weights
# cut
    t = y > cut 
    s = np.sum((x[t] == 1)*w[t])
    b = np.sum((x[t] == 0)*w[t])
    return s/np.sqrt(b+10.0)

def find_best_ams_score(x, y, w):
# find best value of AMS by scanning cut values; 
# x: array of truth values (1 if signal)
# y: array of classifier results
# w: array of event weights
#  returns 
#   ntuple of best value of AMS and the corresponding cut value
#   list with corresponding pairs (ams, cut) 
# ----------------------------------------------------------
    ymin=min(y) # classifiers may not be in range [0.,1.]
    ymax=max(y)
    nprobe=200    # number of (equally spaced) scan points to probe classifier 
    amsvec= [(ams_score(x, y, w, cut), cut) for cut in np.linspace(ymin, ymax, nprobe)] 
    maxams=sorted(amsvec, key=lambda lst: lst[0] )[-1]
    return maxams, amsvec




def printScore(model):

    try:
        pred_clf = model.predict_proba(x_val)[:, 1]
    except:
        pred_clf = model.predict(x_val)
        pred_clf = pred_clf.reshape((pred_clf.shape[0],))

    auc = roc_auc_score(y_val, pred_clf, sample_weight=w_val)
    print('AUC:', auc)
    bs = find_best_ams_score(y_val, pred_clf, w_val)
    print('AMS:', bs[0][0])
    print('AMS total:', bs[0][0]*np.sqrt(50))



def plotLossAccuracy(history):
    # Get training and validation loss/accuracy values from history
    loss_training = history.history['loss']
    loss_validation = history.history['val_loss']
    accuracy_training = history.history['accuracy']
    accuracy_validation = history.history['val_accuracy']


    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 8))
    
    ax1.plot(loss_training, 'o--', label='training')
    ax1.plot(loss_validation, 'o--', label='validation')
    ax1.legend(title='loss')
    ax1.set_xlabel('epoch')
    
    ax2.plot(accuracy_training, 'o--', label='training')
    ax2.plot(accuracy_validation, 'o--', label='validation')
    ax2.legend(title='accuracy')
    ax2.set_xlabel('epoch')

    plt.show()


def plotAMS(history):
    # Get training and validation loss/accuracy values from history
    ams_training = history.history['ams_metric']
    ams_validation = history.history['val_ams_metric']
    

    fig, ax1 = plt.subplots(1,1, figsize=(10, 8))
    
    #ax1.plot(ams_training, 'o--', label='training')
    ax1.plot(ams_validation, '-', label='validation')
    ax1.legend(title='AMS')
    ax1.set_xlabel('epoch')
    
    plt.show()

# %% [markdown]
# ## Read-in & to Pandas

# %%
input_columns = ['DER_deltaeta_jet_jet', 'DER_deltar_tau_lep', 'DER_lep_eta_centrality', 'DER_mass_MMC', 'DER_mass_jet_jet', 
                 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_met_phi_centrality', 'DER_prodeta_jet_jet', 'DER_pt_h', 
                 'DER_pt_ratio_lep_tau', 'DER_pt_tot', 'DER_sum_pt', 'PRI_jet_all_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 
                 'PRI_jet_leading_pt', 'PRI_jet_num', 'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_subleading_pt', 
                 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_lep_pt', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_tau_eta', 'PRI_tau_phi', 
                 'PRI_tau_pt', 'transverse_lepton_jet_mass']


'''

input_columns = [ 'transverse_lepton_jet_mass',
                'DER_mass_MMC', 
                'DER_mass_vis', 
                'DER_mass_transverse_met_lep',
                'DER_pt_ratio_lep_tau', 
                'DER_sum_pt',
                'DER_deltar_tau_lep', 
                'DER_pt_h',
                'DER_sum_pt',  
                'PRI_met_sumet', 
                'PRI_tau_pt',
                ]

'''
print(len(input_columns))
# Out:
# 31

# %%
RDF = ROOT.ROOT.RDataFrame

signal_tree_name = 'signal'
background_tree_name = 'background'
test_tree_name = 'validation'
file_name = 'atlas-higgs-challenge-2014-v2_part.root'

rdf_signal = RDF(signal_tree_name, file_name)
rdf_bkg = RDF(background_tree_name, file_name)
rdf_test = RDF(test_tree_name, file_name)

reconstruct_transverse_lepton_jet_mass = '''

float lep_px = PRI_lep_pt * TMath::Cos(PRI_lep_phi);
float lep_py = PRI_lep_pt * TMath::Sin(PRI_lep_phi);
float jet_px = PRI_jet_leading_pt * TMath::Cos(PRI_jet_leading_phi);
float jet_py = PRI_jet_leading_pt * TMath::Sin(PRI_jet_leading_phi);

//calculate angle between jet and lepton
float cos_theta = (lep_px*jet_px + lep_py*jet_py) / PRI_lep_pt / PRI_jet_leading_pt;

return PRI_lep_pt * PRI_jet_leading_pt * (1 - cos_theta);
'''

#insertion
rdf_signal = rdf_signal.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)
rdf_bkg = rdf_bkg.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)
rdf_test = rdf_test.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)

# label classification to int values
rdf_test = rdf_test.Define('IntLabel', '''
const char ch = Label[0];
const char s = 's';
if(ch == s){
    return 1;
}
else{
    return 0;
}
''')


df_signal = pd.DataFrame(rdf_signal.AsNumpy())
df_bg = pd.DataFrame(rdf_bkg.AsNumpy())
df_test = pd.DataFrame(rdf_test.AsNumpy())

# %% [markdown]
# ## concatination, shuffle and split

# %%
from sklearn.utils import shuffle;
from sklearn.model_selection import train_test_split;

#input feature arrays
vars_signal = df_signal[input_columns].to_numpy()
vars_bg = df_bg[input_columns].to_numpy()
vars_test = df_test[input_columns].to_numpy()

inputs = np.concatenate([vars_signal, vars_bg])

#weights
weight_signal = df_signal['Weight'].to_numpy()
weight_bg = df_bg['Weight'].to_numpy()
weights = np.concatenate([weight_signal, weight_bg])
weights = weights.reshape((weights.shape[0],))

weights_test = df_test['Weight'].to_numpy()


# target classifictionation (1:signal / 0: background)
y_signal = np.ones((vars_signal.shape[0], ))
y_bg = np.zeros((vars_bg.shape[0], ))

targets = np.concatenate([y_signal, y_bg])

# for test dataset there is already a classification; convert to int
truths_test = df_test.IntLabel.to_numpy()


# shuffle 
inputs, targets, weights = shuffle(inputs, targets, weights)


# not for gridcv

# training and validation split  (80, 20)
x_train, x_val, y_train, y_val, w_train, w_val = train_test_split(inputs, targets, weights, test_size=0.2)
#x_train, y_train = inputs, targets

# %% [markdown]
# ## StandardScaling

# %%
from sklearn.preprocessing import StandardScaler;
 
scaler = StandardScaler()
scaler.fit(x_train) #set up only on train data
 
# tranformation applied to all
x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(vars_test)

# %% [markdown]
# ### SMOTE

# %%
#%pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE


# Apply SMOTE to the training data
smote = SMOTE()
x_train, y_train = smote.fit_resample(x_train, y_train)

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

#x_train_pre = x_train

#pca = PCA(n_components=22)
#pca.fit(x_train)

#x_train = pca.transform(x_train)
#x_val = pca.transform(x_val)
#x_test = pca.transform(x_test)

# %% [markdown]
# ## DNN

# %% [markdown]
# $$
# AMS = \sqrt{2((s+b+b_r) \log(1+\frac{s}{s+b_r})-s)}
# $$
#
# Here:
# - $s, b$: unnormalised true positive and false positive rates, respectively
# - $b_r = 10$ is the constant regularisation term

# %%
from tensorflow.keras.metrics import Metric
from tensorflow.keras.metrics import AUC


def ams_metric(y_true, y_pred):
    
    s = tf.reduce_sum(y_true * tf.round(y_pred))
    b = tf.reduce_sum((1 - y_true) * tf.round(y_pred))
    b_r = 10.0
    ams = tf.math.sqrt(2 * ((s + b + b_r) * tf.math.log(1 + s / (b + b_r)) - s))
    return ams.numpy()

# %% [markdown]
# #### training function

# %%
# Training function
def train(model, epochs=10, batch_size=128, learning_rate=1e-3, verbose="auto"):
    '''
    - x: features
    - y: labels
    - w: sample weights
    '''
    
    # Define loss function, optimizer algorithm and validation metrics
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy']
    )
        #metrics=['accuracy', AUC]
    
    # Print summary of the model
    model.summary()
    
    # Train model
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                         verbose=verbose,  validation_split=0.2)
    #history = model.fit(x_train, y_train, sample_weight=w_train, batch_size=batch_size, epochs=epochs,
    #                     verbose=verbose,  validation_split=0.2)
        
    
    return history

# %% [markdown]
# ### model

# %%
import tensorflow as tf;
from tensorflow.keras import layers, models, optimizers;
from tensorflow.keras.optimizers import Adam

# Define the DNN model
def buildModel():
    model = models.Sequential()
    
    # input
    model.add(layers.Input(shape=(x_train.shape[1],)))
    
    # hidden
    model.add(layers.Dense(2*128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(2*128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(2*128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(32, activation='relu', kernel_initializer='glorot_normal'))
    
    # output
    model.add(layers.Dense(1, activation='sigmoid', kernel_initializer='glorot_normal'))
    
    return model

# %% [markdown]
# ## execution

# %%
model = buildModel()

callbacks = [ModelCheckpoint(filepath='model.keras', save_best_only=True),
            CSVLogger('training.log'),
            EarlyStopping(patience=10)] 

history = train(model, epochs=800, batch_size=4*1024, learning_rate=2.2e-4)
#history = train(model, epochs=400, batch_size=2*1024, learning_rate=2e-3)

printScore(model)
plotLossAccuracy(history)
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_54 (Dense)                │ (None, 256)            │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_38 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_39 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_40 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_41 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_42 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193,345 (755.25 KB)
#  Trainable params: 193,345 (755.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - accuracy: 0.4430 - loss: 0.7345 - val_accuracy: 0.0000e+00 - val_loss: 0.7919
# Epoch 2/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.5969 - loss: 0.6716 - val_accuracy: 0.0000e+00 - val_loss: 0.8683
# Epoch 3/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.6238 - loss: 0.6533 - val_accuracy: 0.0000e+00 - val_loss: 0.8696
# Epoch 4/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.6264 - loss: 0.6353 - val_accuracy: 0.0019 - val_loss: 0.8610
# Epoch 5/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.6300 - loss: 0.6210 - val_accuracy: 0.1462 - val_loss: 0.8595
# Epoch 6/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.6447 - loss: 0.6021 - val_accuracy: 0.4299 - val_loss: 0.8409
# Epoch 7/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.6584 - loss: 0.5870 - val_accuracy: 0.6462 - val_loss: 0.8182
# Epoch 8/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.6847 - loss: 0.5713 - val_accuracy: 0.7263 - val_loss: 0.8059
# Epoch 9/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7051 - loss: 0.5588 - val_accuracy: 0.7613 - val_loss: 0.7655
# Epoch 10/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7206 - loss: 0.5529 - val_accuracy: 0.7598 - val_loss: 0.7348
# Epoch 11/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7254 - loss: 0.5416 - val_accuracy: 0.7564 - val_loss: 0.7046
# Epoch 12/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7380 - loss: 0.5308 - val_accuracy: 0.7599 - val_loss: 0.6711
# Epoch 13/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.7427 - loss: 0.5270 - val_accuracy: 0.7583 - val_loss: 0.6449
# Epoch 14/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7450 - loss: 0.5189 - val_accuracy: 0.7666 - val_loss: 0.6199
# Epoch 15/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.7538 - loss: 0.5092 - val_accuracy: 0.7668 - val_loss: 0.6046
# Epoch 16/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7537 - loss: 0.5061 - val_accuracy: 0.7685 - val_loss: 0.5893
# Epoch 17/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7593 - loss: 0.4988 - val_accuracy: 0.7780 - val_loss: 0.5649
# Epoch 18/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7605 - loss: 0.4960 - val_accuracy: 0.7866 - val_loss: 0.5480
# Epoch 19/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.7671 - loss: 0.4882 - val_accuracy: 0.7872 - val_loss: 0.5427
# Epoch 20/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7702 - loss: 0.4809 - val_accuracy: 0.7875 - val_loss: 0.5352
# Epoch 21/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7725 - loss: 0.4782 - val_accuracy: 0.7888 - val_loss: 0.5270
# Epoch 22/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7766 - loss: 0.4752 - val_accuracy: 0.7887 - val_loss: 0.5266
# Epoch 23/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.7762 - loss: 0.4729 - val_accuracy: 0.7931 - val_loss: 0.5174
# Epoch 24/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7750 - loss: 0.4721 - val_accuracy: 0.7882 - val_loss: 0.5180
# Epoch 25/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7862 - loss: 0.4626 - val_accuracy: 0.7889 - val_loss: 0.5083
# Epoch 26/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7847 - loss: 0.4631 - val_accuracy: 0.7905 - val_loss: 0.4978
# Epoch 27/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7869 - loss: 0.4614 - val_accuracy: 0.7856 - val_loss: 0.5037
# Epoch 28/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7850 - loss: 0.4590 - val_accuracy: 0.7904 - val_loss: 0.4983
# Epoch 29/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7858 - loss: 0.4585 - val_accuracy: 0.7967 - val_loss: 0.4866
# Epoch 30/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7915 - loss: 0.4513 - val_accuracy: 0.7885 - val_loss: 0.4939
# Epoch 31/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7908 - loss: 0.4518 - val_accuracy: 0.7939 - val_loss: 0.4781
# Epoch 32/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7943 - loss: 0.4476 - val_accuracy: 0.7870 - val_loss: 0.4880
# Epoch 33/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7951 - loss: 0.4450 - val_accuracy: 0.7883 - val_loss: 0.4781
# Epoch 34/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7944 - loss: 0.4454 - val_accuracy: 0.7856 - val_loss: 0.4807
# Epoch 35/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7979 - loss: 0.4402 - val_accuracy: 0.7887 - val_loss: 0.4703
# Epoch 36/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7955 - loss: 0.4429 - val_accuracy: 0.7825 - val_loss: 0.4736
# Epoch 37/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.7977 - loss: 0.4388 - val_accuracy: 0.7794 - val_loss: 0.4791
# Epoch 38/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8003 - loss: 0.4358 - val_accuracy: 0.7917 - val_loss: 0.4597
# Epoch 39/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7955 - loss: 0.4433 - val_accuracy: 0.7834 - val_loss: 0.4740
# Epoch 40/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.8002 - loss: 0.4365 - val_accuracy: 0.7883 - val_loss: 0.4611
# Epoch 41/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8029 - loss: 0.4290 - val_accuracy: 0.7848 - val_loss: 0.4657
# Epoch 42/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8019 - loss: 0.4353 - val_accuracy: 0.7927 - val_loss: 0.4513
# Epoch 43/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8035 - loss: 0.4340 - val_accuracy: 0.7850 - val_loss: 0.4611
# Epoch 44/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8010 - loss: 0.4377 - val_accuracy: 0.7913 - val_loss: 0.4538
# Epoch 45/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8044 - loss: 0.4310 - val_accuracy: 0.7892 - val_loss: 0.4496
# Epoch 46/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8045 - loss: 0.4286 - val_accuracy: 0.7909 - val_loss: 0.4497
# Epoch 47/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8064 - loss: 0.4285 - val_accuracy: 0.7874 - val_loss: 0.4543
# Epoch 48/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8051 - loss: 0.4291 - val_accuracy: 0.7930 - val_loss: 0.4467
# Epoch 49/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8058 - loss: 0.4275 - val_accuracy: 0.7881 - val_loss: 0.4528
# Epoch 50/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8069 - loss: 0.4304 - val_accuracy: 0.7934 - val_loss: 0.4419
# Epoch 51/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8070 - loss: 0.4285 - val_accuracy: 0.7826 - val_loss: 0.4526
# Epoch 52/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8101 - loss: 0.4198 - val_accuracy: 0.7886 - val_loss: 0.4460
# Epoch 53/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8067 - loss: 0.4235 - val_accuracy: 0.7910 - val_loss: 0.4426
# Epoch 54/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8069 - loss: 0.4213 - val_accuracy: 0.7931 - val_loss: 0.4424
# Epoch 55/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8100 - loss: 0.4192 - val_accuracy: 0.7917 - val_loss: 0.4377
# Epoch 56/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8121 - loss: 0.4195 - val_accuracy: 0.7859 - val_loss: 0.4443
# Epoch 57/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8082 - loss: 0.4210 - val_accuracy: 0.7962 - val_loss: 0.4309
# Epoch 58/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8094 - loss: 0.4221 - val_accuracy: 0.7941 - val_loss: 0.4359
# Epoch 59/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8109 - loss: 0.4173 - val_accuracy: 0.7967 - val_loss: 0.4353
# Epoch 60/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8120 - loss: 0.4165 - val_accuracy: 0.7951 - val_loss: 0.4342
# Epoch 61/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8134 - loss: 0.4170 - val_accuracy: 0.7960 - val_loss: 0.4285
# Epoch 62/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8113 - loss: 0.4203 - val_accuracy: 0.7927 - val_loss: 0.4301
# Epoch 63/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8130 - loss: 0.4166 - val_accuracy: 0.7968 - val_loss: 0.4291
# Epoch 64/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8111 - loss: 0.4181 - val_accuracy: 0.7992 - val_loss: 0.4300
# Epoch 65/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8128 - loss: 0.4174 - val_accuracy: 0.8023 - val_loss: 0.4251
# Epoch 66/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8120 - loss: 0.4130 - val_accuracy: 0.8025 - val_loss: 0.4236
# Epoch 67/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8106 - loss: 0.4159 - val_accuracy: 0.7998 - val_loss: 0.4307
# Epoch 68/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8140 - loss: 0.4121 - val_accuracy: 0.8029 - val_loss: 0.4283
# Epoch 69/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8126 - loss: 0.4152 - val_accuracy: 0.8025 - val_loss: 0.4249
# Epoch 70/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.8127 - loss: 0.4132 - val_accuracy: 0.8043 - val_loss: 0.4181
# Epoch 71/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8122 - loss: 0.4150 - val_accuracy: 0.8020 - val_loss: 0.4228
# Epoch 72/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8137 - loss: 0.4132 - val_accuracy: 0.8068 - val_loss: 0.4182
# Epoch 73/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8142 - loss: 0.4137 - val_accuracy: 0.8097 - val_loss: 0.4146
# Epoch 74/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8173 - loss: 0.4067 - val_accuracy: 0.8040 - val_loss: 0.4192
# Epoch 75/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8158 - loss: 0.4107 - val_accuracy: 0.8029 - val_loss: 0.4166
# Epoch 76/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8153 - loss: 0.4096 - val_accuracy: 0.8020 - val_loss: 0.4147
# Epoch 77/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8155 - loss: 0.4060 - val_accuracy: 0.8077 - val_loss: 0.4133
# Epoch 78/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8166 - loss: 0.4094 - val_accuracy: 0.8087 - val_loss: 0.4087
# Epoch 79/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8180 - loss: 0.4050 - val_accuracy: 0.8034 - val_loss: 0.4185
# Epoch 80/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8173 - loss: 0.4092 - val_accuracy: 0.8085 - val_loss: 0.4112
# Epoch 81/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8190 - loss: 0.4046 - val_accuracy: 0.8122 - val_loss: 0.4098
# Epoch 82/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8200 - loss: 0.4091 - val_accuracy: 0.8142 - val_loss: 0.4089
# Epoch 83/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8162 - loss: 0.4091 - val_accuracy: 0.8142 - val_loss: 0.4127
# Epoch 84/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8191 - loss: 0.4021 - val_accuracy: 0.8219 - val_loss: 0.4033
# Epoch 85/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8161 - loss: 0.4044 - val_accuracy: 0.8188 - val_loss: 0.4089
# Epoch 86/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8187 - loss: 0.4036 - val_accuracy: 0.8140 - val_loss: 0.4134
# Epoch 87/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8207 - loss: 0.3991 - val_accuracy: 0.8211 - val_loss: 0.3989
# Epoch 88/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8186 - loss: 0.4052 - val_accuracy: 0.8178 - val_loss: 0.4031
# Epoch 89/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8198 - loss: 0.4054 - val_accuracy: 0.8179 - val_loss: 0.4038
# Epoch 90/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8239 - loss: 0.3992 - val_accuracy: 0.8178 - val_loss: 0.4054
# Epoch 91/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8202 - loss: 0.4041 - val_accuracy: 0.8147 - val_loss: 0.4066
# Epoch 92/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8222 - loss: 0.3993 - val_accuracy: 0.8224 - val_loss: 0.3961
# Epoch 93/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8178 - loss: 0.4032 - val_accuracy: 0.8237 - val_loss: 0.4000
# Epoch 94/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8215 - loss: 0.3992 - val_accuracy: 0.8213 - val_loss: 0.4042
# Epoch 95/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8201 - loss: 0.4008 - val_accuracy: 0.8245 - val_loss: 0.3961
# Epoch 96/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8186 - loss: 0.4027 - val_accuracy: 0.8235 - val_loss: 0.3987
# Epoch 97/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8209 - loss: 0.3997 - val_accuracy: 0.8262 - val_loss: 0.3980
# Epoch 98/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8191 - loss: 0.4029 - val_accuracy: 0.8267 - val_loss: 0.3970
# Epoch 99/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8223 - loss: 0.3992 - val_accuracy: 0.8253 - val_loss: 0.3966
# Epoch 100/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8181 - loss: 0.4030 - val_accuracy: 0.8268 - val_loss: 0.3962
# Epoch 101/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8214 - loss: 0.4013 - val_accuracy: 0.8270 - val_loss: 0.3933
# Epoch 102/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8203 - loss: 0.3999 - val_accuracy: 0.8250 - val_loss: 0.3967
# Epoch 103/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8201 - loss: 0.3987 - val_accuracy: 0.8335 - val_loss: 0.3877
# Epoch 104/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8205 - loss: 0.3982 - val_accuracy: 0.8275 - val_loss: 0.3935
# Epoch 105/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8205 - loss: 0.4002 - val_accuracy: 0.8301 - val_loss: 0.3898
# Epoch 106/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8217 - loss: 0.3965 - val_accuracy: 0.8320 - val_loss: 0.3913
# Epoch 107/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8223 - loss: 0.3984 - val_accuracy: 0.8293 - val_loss: 0.3955
# Epoch 108/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8200 - loss: 0.3976 - val_accuracy: 0.8327 - val_loss: 0.3905
# Epoch 109/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8238 - loss: 0.3956 - val_accuracy: 0.8308 - val_loss: 0.3948
# Epoch 110/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8226 - loss: 0.3973 - val_accuracy: 0.8311 - val_loss: 0.3928
# Epoch 111/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8210 - loss: 0.3991 - val_accuracy: 0.8337 - val_loss: 0.3884
# Epoch 112/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8232 - loss: 0.3961 - val_accuracy: 0.8336 - val_loss: 0.3841
# Epoch 113/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8212 - loss: 0.3973 - val_accuracy: 0.8327 - val_loss: 0.3930
# Epoch 114/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8241 - loss: 0.3970 - val_accuracy: 0.8359 - val_loss: 0.3846
# Epoch 115/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8241 - loss: 0.3968 - val_accuracy: 0.8364 - val_loss: 0.3895
# Epoch 116/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8243 - loss: 0.3946 - val_accuracy: 0.8354 - val_loss: 0.3894
# Epoch 117/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8245 - loss: 0.3970 - val_accuracy: 0.8365 - val_loss: 0.3843
# Epoch 118/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8283 - loss: 0.3914 - val_accuracy: 0.8396 - val_loss: 0.3826
# Epoch 119/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8263 - loss: 0.3910 - val_accuracy: 0.8413 - val_loss: 0.3851
# Epoch 120/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8235 - loss: 0.3983 - val_accuracy: 0.8389 - val_loss: 0.3880
# Epoch 121/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8221 - loss: 0.3951 - val_accuracy: 0.8409 - val_loss: 0.3829
# Epoch 122/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8268 - loss: 0.3901 - val_accuracy: 0.8422 - val_loss: 0.3820
# Epoch 123/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8267 - loss: 0.3908 - val_accuracy: 0.8350 - val_loss: 0.3902
# Epoch 124/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8225 - loss: 0.3961 - val_accuracy: 0.8407 - val_loss: 0.3820
# Epoch 125/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8245 - loss: 0.3926 - val_accuracy: 0.8427 - val_loss: 0.3830
# Epoch 126/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8253 - loss: 0.3913 - val_accuracy: 0.8449 - val_loss: 0.3789
# Epoch 127/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8259 - loss: 0.3893 - val_accuracy: 0.8392 - val_loss: 0.3901
# Epoch 128/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8269 - loss: 0.3918 - val_accuracy: 0.8465 - val_loss: 0.3763
# Epoch 129/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8249 - loss: 0.3913 - val_accuracy: 0.8437 - val_loss: 0.3873
# Epoch 130/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8250 - loss: 0.3925 - val_accuracy: 0.8503 - val_loss: 0.3764
# Epoch 131/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8253 - loss: 0.3925 - val_accuracy: 0.8450 - val_loss: 0.3866
# Epoch 132/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8239 - loss: 0.3922 - val_accuracy: 0.8505 - val_loss: 0.3806
# Epoch 133/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8264 - loss: 0.3917 - val_accuracy: 0.8450 - val_loss: 0.3832
# Epoch 134/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8263 - loss: 0.3869 - val_accuracy: 0.8465 - val_loss: 0.3783
# Epoch 135/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8285 - loss: 0.3868 - val_accuracy: 0.8472 - val_loss: 0.3817
# Epoch 136/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8210 - loss: 0.3912 - val_accuracy: 0.8475 - val_loss: 0.3845
# Epoch 137/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8280 - loss: 0.3884 - val_accuracy: 0.8509 - val_loss: 0.3728
# Epoch 138/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8253 - loss: 0.3920 - val_accuracy: 0.8464 - val_loss: 0.3830
# Epoch 139/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8270 - loss: 0.3869 - val_accuracy: 0.8508 - val_loss: 0.3748
# Epoch 140/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8262 - loss: 0.3894 - val_accuracy: 0.8498 - val_loss: 0.3843
# Epoch 141/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8280 - loss: 0.3891 - val_accuracy: 0.8522 - val_loss: 0.3757
# Epoch 142/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8262 - loss: 0.3874 - val_accuracy: 0.8482 - val_loss: 0.3826
# Epoch 143/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8242 - loss: 0.3894 - val_accuracy: 0.8507 - val_loss: 0.3781
# Epoch 144/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8221 - loss: 0.3912 - val_accuracy: 0.8477 - val_loss: 0.3821
# Epoch 145/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8280 - loss: 0.3856 - val_accuracy: 0.8557 - val_loss: 0.3739
# Epoch 146/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8287 - loss: 0.3841 - val_accuracy: 0.8543 - val_loss: 0.3804
# Epoch 147/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8281 - loss: 0.3843 - val_accuracy: 0.8551 - val_loss: 0.3726
# Epoch 148/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8249 - loss: 0.3881 - val_accuracy: 0.8529 - val_loss: 0.3806
# Epoch 149/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8278 - loss: 0.3850 - val_accuracy: 0.8534 - val_loss: 0.3743
# Epoch 150/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8272 - loss: 0.3858 - val_accuracy: 0.8526 - val_loss: 0.3743
# Epoch 151/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8273 - loss: 0.3884 - val_accuracy: 0.8526 - val_loss: 0.3768
# Epoch 152/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8262 - loss: 0.3880 - val_accuracy: 0.8523 - val_loss: 0.3702
# Epoch 153/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8281 - loss: 0.3912 - val_accuracy: 0.8515 - val_loss: 0.3764
# Epoch 154/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8265 - loss: 0.3874 - val_accuracy: 0.8585 - val_loss: 0.3718
# Epoch 155/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8257 - loss: 0.3883 - val_accuracy: 0.8577 - val_loss: 0.3722
# Epoch 156/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8293 - loss: 0.3861 - val_accuracy: 0.8581 - val_loss: 0.3703
# Epoch 157/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8268 - loss: 0.3866 - val_accuracy: 0.8582 - val_loss: 0.3710
# Epoch 158/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8300 - loss: 0.3836 - val_accuracy: 0.8564 - val_loss: 0.3751
# Epoch 159/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8280 - loss: 0.3870 - val_accuracy: 0.8550 - val_loss: 0.3717
# Epoch 160/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8263 - loss: 0.3897 - val_accuracy: 0.8533 - val_loss: 0.3773
# Epoch 161/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8285 - loss: 0.3883 - val_accuracy: 0.8547 - val_loss: 0.3749
# Epoch 162/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8289 - loss: 0.3866 - val_accuracy: 0.8569 - val_loss: 0.3729
# Epoch 163/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8274 - loss: 0.3834 - val_accuracy: 0.8598 - val_loss: 0.3674
# Epoch 164/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8269 - loss: 0.3853 - val_accuracy: 0.8556 - val_loss: 0.3767
# Epoch 165/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8258 - loss: 0.3887 - val_accuracy: 0.8571 - val_loss: 0.3680
# Epoch 166/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8280 - loss: 0.3849 - val_accuracy: 0.8572 - val_loss: 0.3694
# Epoch 167/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8321 - loss: 0.3785 - val_accuracy: 0.8551 - val_loss: 0.3686
# Epoch 168/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8306 - loss: 0.3796 - val_accuracy: 0.8554 - val_loss: 0.3727
# Epoch 169/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8307 - loss: 0.3821 - val_accuracy: 0.8591 - val_loss: 0.3684
# Epoch 170/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8292 - loss: 0.3827 - val_accuracy: 0.8571 - val_loss: 0.3721
# Epoch 171/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8235 - loss: 0.3919 - val_accuracy: 0.8615 - val_loss: 0.3693
# Epoch 172/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8285 - loss: 0.3842 - val_accuracy: 0.8568 - val_loss: 0.3733
# Epoch 173/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8310 - loss: 0.3800 - val_accuracy: 0.8561 - val_loss: 0.3651
# Epoch 174/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8288 - loss: 0.3833 - val_accuracy: 0.8609 - val_loss: 0.3687
# Epoch 175/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8291 - loss: 0.3824 - val_accuracy: 0.8606 - val_loss: 0.3699
# Epoch 176/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8293 - loss: 0.3841 - val_accuracy: 0.8603 - val_loss: 0.3642
# Epoch 177/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8319 - loss: 0.3807 - val_accuracy: 0.8558 - val_loss: 0.3725
# Epoch 178/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8305 - loss: 0.3806 - val_accuracy: 0.8577 - val_loss: 0.3652
# Epoch 179/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8303 - loss: 0.3794 - val_accuracy: 0.8572 - val_loss: 0.3704
# Epoch 180/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8290 - loss: 0.3834 - val_accuracy: 0.8636 - val_loss: 0.3647
# Epoch 181/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8311 - loss: 0.3796 - val_accuracy: 0.8605 - val_loss: 0.3659
# Epoch 182/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8280 - loss: 0.3844 - val_accuracy: 0.8596 - val_loss: 0.3669
# Epoch 183/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8301 - loss: 0.3796 - val_accuracy: 0.8555 - val_loss: 0.3675
# Epoch 184/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8302 - loss: 0.3801 - val_accuracy: 0.8588 - val_loss: 0.3615
# Epoch 185/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8290 - loss: 0.3788 - val_accuracy: 0.8628 - val_loss: 0.3645
# Epoch 186/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8305 - loss: 0.3800 - val_accuracy: 0.8573 - val_loss: 0.3687
# Epoch 187/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8286 - loss: 0.3827 - val_accuracy: 0.8570 - val_loss: 0.3668
# Epoch 188/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8320 - loss: 0.3794 - val_accuracy: 0.8591 - val_loss: 0.3619
# Epoch 189/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8311 - loss: 0.3777 - val_accuracy: 0.8587 - val_loss: 0.3664
# Epoch 190/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8311 - loss: 0.3786 - val_accuracy: 0.8615 - val_loss: 0.3603
# Epoch 191/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8298 - loss: 0.3815 - val_accuracy: 0.8568 - val_loss: 0.3691
# Epoch 192/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8305 - loss: 0.3823 - val_accuracy: 0.8616 - val_loss: 0.3632
# Epoch 193/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8297 - loss: 0.3778 - val_accuracy: 0.8620 - val_loss: 0.3584
# Epoch 194/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8273 - loss: 0.3814 - val_accuracy: 0.8608 - val_loss: 0.3624
# Epoch 195/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8305 - loss: 0.3781 - val_accuracy: 0.8588 - val_loss: 0.3645
# Epoch 196/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8315 - loss: 0.3795 - val_accuracy: 0.8639 - val_loss: 0.3626
# Epoch 197/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8303 - loss: 0.3774 - val_accuracy: 0.8628 - val_loss: 0.3643
# Epoch 198/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8292 - loss: 0.3797 - val_accuracy: 0.8680 - val_loss: 0.3559
# Epoch 199/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8297 - loss: 0.3771 - val_accuracy: 0.8622 - val_loss: 0.3609
# Epoch 200/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8320 - loss: 0.3763 - val_accuracy: 0.8622 - val_loss: 0.3580
# Epoch 201/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8293 - loss: 0.3823 - val_accuracy: 0.8636 - val_loss: 0.3598
# Epoch 202/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8318 - loss: 0.3757 - val_accuracy: 0.8608 - val_loss: 0.3616
# Epoch 203/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8327 - loss: 0.3765 - val_accuracy: 0.8644 - val_loss: 0.3561
# Epoch 204/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8290 - loss: 0.3810 - val_accuracy: 0.8594 - val_loss: 0.3649
# Epoch 205/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8328 - loss: 0.3763 - val_accuracy: 0.8646 - val_loss: 0.3512
# Epoch 206/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8316 - loss: 0.3760 - val_accuracy: 0.8564 - val_loss: 0.3655
# Epoch 207/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8318 - loss: 0.3792 - val_accuracy: 0.8583 - val_loss: 0.3601
# Epoch 208/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8331 - loss: 0.3775 - val_accuracy: 0.8612 - val_loss: 0.3525
# Epoch 209/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8311 - loss: 0.3783 - val_accuracy: 0.8591 - val_loss: 0.3574
# Epoch 210/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8303 - loss: 0.3792 - val_accuracy: 0.8554 - val_loss: 0.3682
# Epoch 211/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8308 - loss: 0.3802 - val_accuracy: 0.8647 - val_loss: 0.3517
# Epoch 212/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8302 - loss: 0.3780 - val_accuracy: 0.8615 - val_loss: 0.3557
# Epoch 213/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8322 - loss: 0.3775 - val_accuracy: 0.8620 - val_loss: 0.3559
# Epoch 214/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8322 - loss: 0.3757 - val_accuracy: 0.8593 - val_loss: 0.3589
# Epoch 215/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8324 - loss: 0.3761 - val_accuracy: 0.8614 - val_loss: 0.3544
# Epoch 216/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8325 - loss: 0.3750 - val_accuracy: 0.8597 - val_loss: 0.3548
# Epoch 217/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8343 - loss: 0.3722 - val_accuracy: 0.8607 - val_loss: 0.3561
# Epoch 218/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8315 - loss: 0.3759 - val_accuracy: 0.8604 - val_loss: 0.3563
# Epoch 219/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8332 - loss: 0.3731 - val_accuracy: 0.8575 - val_loss: 0.3611
# Epoch 220/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8318 - loss: 0.3773 - val_accuracy: 0.8640 - val_loss: 0.3504
# Epoch 221/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8329 - loss: 0.3779 - val_accuracy: 0.8602 - val_loss: 0.3614
# Epoch 222/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8318 - loss: 0.3728 - val_accuracy: 0.8672 - val_loss: 0.3455
# Epoch 223/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8334 - loss: 0.3737 - val_accuracy: 0.8571 - val_loss: 0.3593
# Epoch 224/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8327 - loss: 0.3754 - val_accuracy: 0.8586 - val_loss: 0.3566
# Epoch 225/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8309 - loss: 0.3793 - val_accuracy: 0.8609 - val_loss: 0.3519
# Epoch 226/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8333 - loss: 0.3740 - val_accuracy: 0.8629 - val_loss: 0.3531
# Epoch 227/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8325 - loss: 0.3742 - val_accuracy: 0.8591 - val_loss: 0.3582
# Epoch 228/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8320 - loss: 0.3734 - val_accuracy: 0.8642 - val_loss: 0.3506
# Epoch 229/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8326 - loss: 0.3748 - val_accuracy: 0.8591 - val_loss: 0.3625
# Epoch 230/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8348 - loss: 0.3740 - val_accuracy: 0.8607 - val_loss: 0.3569
# Epoch 231/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8356 - loss: 0.3715 - val_accuracy: 0.8595 - val_loss: 0.3533
# Epoch 232/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8324 - loss: 0.3747 - val_accuracy: 0.8561 - val_loss: 0.3548
# Epoch 233/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8368 - loss: 0.3710 - val_accuracy: 0.8578 - val_loss: 0.3548
# Epoch 234/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8334 - loss: 0.3753 - val_accuracy: 0.8593 - val_loss: 0.3528
# Epoch 235/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8338 - loss: 0.3742 - val_accuracy: 0.8510 - val_loss: 0.3610
# Epoch 236/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8343 - loss: 0.3729 - val_accuracy: 0.8553 - val_loss: 0.3548
# Epoch 237/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8333 - loss: 0.3726 - val_accuracy: 0.8623 - val_loss: 0.3503
# Epoch 238/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8350 - loss: 0.3740 - val_accuracy: 0.8575 - val_loss: 0.3521
# Epoch 239/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8357 - loss: 0.3701 - val_accuracy: 0.8555 - val_loss: 0.3506
# Epoch 240/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8357 - loss: 0.3702 - val_accuracy: 0.8553 - val_loss: 0.3535
# Epoch 241/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8358 - loss: 0.3744 - val_accuracy: 0.8589 - val_loss: 0.3552
# Epoch 242/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8315 - loss: 0.3746 - val_accuracy: 0.8558 - val_loss: 0.3575
# Epoch 243/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8367 - loss: 0.3700 - val_accuracy: 0.8560 - val_loss: 0.3556
# Epoch 244/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8354 - loss: 0.3700 - val_accuracy: 0.8615 - val_loss: 0.3488
# Epoch 245/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8336 - loss: 0.3737 - val_accuracy: 0.8588 - val_loss: 0.3532
# Epoch 246/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8331 - loss: 0.3721 - val_accuracy: 0.8593 - val_loss: 0.3528
# Epoch 247/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8322 - loss: 0.3729 - val_accuracy: 0.8596 - val_loss: 0.3520
# Epoch 248/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8328 - loss: 0.3716 - val_accuracy: 0.8592 - val_loss: 0.3551
# Epoch 249/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8330 - loss: 0.3752 - val_accuracy: 0.8601 - val_loss: 0.3554
# Epoch 250/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8332 - loss: 0.3720 - val_accuracy: 0.8591 - val_loss: 0.3518
# Epoch 251/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8343 - loss: 0.3728 - val_accuracy: 0.8525 - val_loss: 0.3563
# Epoch 252/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8364 - loss: 0.3667 - val_accuracy: 0.8576 - val_loss: 0.3519
# Epoch 253/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8354 - loss: 0.3671 - val_accuracy: 0.8584 - val_loss: 0.3546
# Epoch 254/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8351 - loss: 0.3696 - val_accuracy: 0.8604 - val_loss: 0.3528
# Epoch 255/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.8346 - loss: 0.3701 - val_accuracy: 0.8627 - val_loss: 0.3488
# Epoch 256/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8342 - loss: 0.3731 - val_accuracy: 0.8580 - val_loss: 0.3544
# Epoch 257/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8351 - loss: 0.3679 - val_accuracy: 0.8606 - val_loss: 0.3527
# Epoch 258/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8366 - loss: 0.3684 - val_accuracy: 0.8630 - val_loss: 0.3499
# Epoch 259/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8330 - loss: 0.3736 - val_accuracy: 0.8584 - val_loss: 0.3544
# Epoch 260/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8351 - loss: 0.3695 - val_accuracy: 0.8551 - val_loss: 0.3551
# Epoch 261/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8357 - loss: 0.3720 - val_accuracy: 0.8537 - val_loss: 0.3564
# Epoch 262/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8321 - loss: 0.3713 - val_accuracy: 0.8550 - val_loss: 0.3537
# Epoch 263/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8358 - loss: 0.3706 - val_accuracy: 0.8588 - val_loss: 0.3451
# Epoch 264/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8384 - loss: 0.3660 - val_accuracy: 0.8567 - val_loss: 0.3518
# Epoch 265/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8343 - loss: 0.3717 - val_accuracy: 0.8562 - val_loss: 0.3506
# Epoch 266/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8387 - loss: 0.3684 - val_accuracy: 0.8586 - val_loss: 0.3513
# Epoch 267/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8373 - loss: 0.3679 - val_accuracy: 0.8603 - val_loss: 0.3524
# Epoch 268/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8348 - loss: 0.3702 - val_accuracy: 0.8633 - val_loss: 0.3484
# Epoch 269/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8334 - loss: 0.3709 - val_accuracy: 0.8602 - val_loss: 0.3504
# Epoch 270/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8375 - loss: 0.3673 - val_accuracy: 0.8644 - val_loss: 0.3469
# Epoch 271/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8344 - loss: 0.3675 - val_accuracy: 0.8633 - val_loss: 0.3520
# Epoch 272/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8366 - loss: 0.3691 - val_accuracy: 0.8635 - val_loss: 0.3509
# Epoch 273/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8357 - loss: 0.3688 - val_accuracy: 0.8642 - val_loss: 0.3451
# Epoch 274/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8368 - loss: 0.3660 - val_accuracy: 0.8615 - val_loss: 0.3476
# Epoch 275/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8371 - loss: 0.3690 - val_accuracy: 0.8576 - val_loss: 0.3499
# Epoch 276/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.8372 - loss: 0.3655 - val_accuracy: 0.8639 - val_loss: 0.3442
# Epoch 277/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8367 - loss: 0.3682 - val_accuracy: 0.8632 - val_loss: 0.3478
# Epoch 278/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8367 - loss: 0.3661 - val_accuracy: 0.8618 - val_loss: 0.3479
# Epoch 279/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8364 - loss: 0.3657 - val_accuracy: 0.8661 - val_loss: 0.3414
# Epoch 280/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8352 - loss: 0.3703 - val_accuracy: 0.8596 - val_loss: 0.3528
# Epoch 281/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8370 - loss: 0.3669 - val_accuracy: 0.8626 - val_loss: 0.3457
# Epoch 282/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8358 - loss: 0.3684 - val_accuracy: 0.8616 - val_loss: 0.3469
# Epoch 283/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8349 - loss: 0.3661 - val_accuracy: 0.8562 - val_loss: 0.3496
# Epoch 284/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8367 - loss: 0.3662 - val_accuracy: 0.8596 - val_loss: 0.3451
# Epoch 285/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8346 - loss: 0.3696 - val_accuracy: 0.8581 - val_loss: 0.3487
# Epoch 286/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8330 - loss: 0.3706 - val_accuracy: 0.8594 - val_loss: 0.3470
# Epoch 287/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8352 - loss: 0.3729 - val_accuracy: 0.8567 - val_loss: 0.3489
# Epoch 288/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8361 - loss: 0.3697 - val_accuracy: 0.8590 - val_loss: 0.3482
# Epoch 289/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8333 - loss: 0.3664 - val_accuracy: 0.8615 - val_loss: 0.3470
# Epoch 290/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8380 - loss: 0.3659 - val_accuracy: 0.8604 - val_loss: 0.3453
# Epoch 291/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8345 - loss: 0.3684 - val_accuracy: 0.8529 - val_loss: 0.3504
# Epoch 292/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8367 - loss: 0.3674 - val_accuracy: 0.8592 - val_loss: 0.3442
# Epoch 293/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8380 - loss: 0.3625 - val_accuracy: 0.8536 - val_loss: 0.3540
# Epoch 294/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8384 - loss: 0.3655 - val_accuracy: 0.8632 - val_loss: 0.3418
# Epoch 295/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.8387 - loss: 0.3644 - val_accuracy: 0.8571 - val_loss: 0.3515
# Epoch 296/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8380 - loss: 0.3634 - val_accuracy: 0.8640 - val_loss: 0.3411
# Epoch 297/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8350 - loss: 0.3668 - val_accuracy: 0.8604 - val_loss: 0.3444
# Epoch 298/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8356 - loss: 0.3645 - val_accuracy: 0.8574 - val_loss: 0.3482
# Epoch 299/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8330 - loss: 0.3713 - val_accuracy: 0.8587 - val_loss: 0.3491
# Epoch 300/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8371 - loss: 0.3642 - val_accuracy: 0.8577 - val_loss: 0.3486
# Epoch 301/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8374 - loss: 0.3698 - val_accuracy: 0.8628 - val_loss: 0.3394
# Epoch 302/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8373 - loss: 0.3651 - val_accuracy: 0.8569 - val_loss: 0.3495
# Epoch 303/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8370 - loss: 0.3652 - val_accuracy: 0.8608 - val_loss: 0.3452
# Epoch 304/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8368 - loss: 0.3677 - val_accuracy: 0.8603 - val_loss: 0.3466
# Epoch 305/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8380 - loss: 0.3622 - val_accuracy: 0.8585 - val_loss: 0.3484
# Epoch 306/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8360 - loss: 0.3690 - val_accuracy: 0.8623 - val_loss: 0.3434
# Epoch 307/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8333 - loss: 0.3664 - val_accuracy: 0.8588 - val_loss: 0.3424
# Epoch 308/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8383 - loss: 0.3645 - val_accuracy: 0.8609 - val_loss: 0.3461
# Epoch 309/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8385 - loss: 0.3601 - val_accuracy: 0.8590 - val_loss: 0.3475
# Epoch 310/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8350 - loss: 0.3643 - val_accuracy: 0.8557 - val_loss: 0.3531
# Epoch 311/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8366 - loss: 0.3662 - val_accuracy: 0.8613 - val_loss: 0.3427
# Epoch 312/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8359 - loss: 0.3667 - val_accuracy: 0.8574 - val_loss: 0.3455
# Epoch 313/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8378 - loss: 0.3640 - val_accuracy: 0.8595 - val_loss: 0.3430
# Epoch 314/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8389 - loss: 0.3653 - val_accuracy: 0.8575 - val_loss: 0.3493
# Epoch 315/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8375 - loss: 0.3657 - val_accuracy: 0.8621 - val_loss: 0.3429
# Epoch 316/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8350 - loss: 0.3675 - val_accuracy: 0.8571 - val_loss: 0.3499
# Epoch 317/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8361 - loss: 0.3629 - val_accuracy: 0.8573 - val_loss: 0.3480
# Epoch 318/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8390 - loss: 0.3625 - val_accuracy: 0.8574 - val_loss: 0.3505
# Epoch 319/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8364 - loss: 0.3633 - val_accuracy: 0.8620 - val_loss: 0.3424
# Epoch 320/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8393 - loss: 0.3618 - val_accuracy: 0.8561 - val_loss: 0.3502
# Epoch 321/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8405 - loss: 0.3635 - val_accuracy: 0.8612 - val_loss: 0.3455
# Epoch 322/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8338 - loss: 0.3675 - val_accuracy: 0.8577 - val_loss: 0.3511
# Epoch 323/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8380 - loss: 0.3636 - val_accuracy: 0.8559 - val_loss: 0.3482
# Epoch 324/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8388 - loss: 0.3638 - val_accuracy: 0.8573 - val_loss: 0.3458
# Epoch 325/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8396 - loss: 0.3617 - val_accuracy: 0.8524 - val_loss: 0.3545
# Epoch 326/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8404 - loss: 0.3619 - val_accuracy: 0.8615 - val_loss: 0.3445
# Epoch 327/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8380 - loss: 0.3626 - val_accuracy: 0.8595 - val_loss: 0.3416
# Epoch 328/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8375 - loss: 0.3629 - val_accuracy: 0.8560 - val_loss: 0.3516
# Epoch 329/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8382 - loss: 0.3637 - val_accuracy: 0.8583 - val_loss: 0.3492
# Epoch 330/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8386 - loss: 0.3595 - val_accuracy: 0.8628 - val_loss: 0.3419
# Epoch 331/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8370 - loss: 0.3633 - val_accuracy: 0.8608 - val_loss: 0.3446
# Epoch 332/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8375 - loss: 0.3647 - val_accuracy: 0.8580 - val_loss: 0.3466
# Epoch 333/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8365 - loss: 0.3641 - val_accuracy: 0.8641 - val_loss: 0.3401
# Epoch 334/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8404 - loss: 0.3601 - val_accuracy: 0.8625 - val_loss: 0.3451
# Epoch 335/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8397 - loss: 0.3627 - val_accuracy: 0.8598 - val_loss: 0.3457
# Epoch 336/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8406 - loss: 0.3577 - val_accuracy: 0.8649 - val_loss: 0.3445
# Epoch 337/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8393 - loss: 0.3607 - val_accuracy: 0.8620 - val_loss: 0.3442
# Epoch 338/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8387 - loss: 0.3629 - val_accuracy: 0.8578 - val_loss: 0.3473
# Epoch 339/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8388 - loss: 0.3595 - val_accuracy: 0.8612 - val_loss: 0.3444
# Epoch 340/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8389 - loss: 0.3631 - val_accuracy: 0.8618 - val_loss: 0.3444
# Epoch 341/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8379 - loss: 0.3625 - val_accuracy: 0.8618 - val_loss: 0.3461
# Epoch 342/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8384 - loss: 0.3633 - val_accuracy: 0.8627 - val_loss: 0.3455
# Epoch 343/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8379 - loss: 0.3672 - val_accuracy: 0.8626 - val_loss: 0.3412
# Epoch 344/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8395 - loss: 0.3594 - val_accuracy: 0.8590 - val_loss: 0.3459
# Epoch 345/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8375 - loss: 0.3618 - val_accuracy: 0.8612 - val_loss: 0.3412
# Epoch 346/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8349 - loss: 0.3655 - val_accuracy: 0.8569 - val_loss: 0.3453
# Epoch 347/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8396 - loss: 0.3653 - val_accuracy: 0.8596 - val_loss: 0.3433
# Epoch 348/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8437 - loss: 0.3589 - val_accuracy: 0.8664 - val_loss: 0.3378
# Epoch 349/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8378 - loss: 0.3621 - val_accuracy: 0.8681 - val_loss: 0.3428
# Epoch 350/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8400 - loss: 0.3599 - val_accuracy: 0.8645 - val_loss: 0.3455
# Epoch 351/600
# ...
# Epoch 480/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8457 - loss: 0.3481 - val_accuracy: 0.8689 - val_loss: 0.3301
# Epoch 481/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8446 - loss: 0.3535 - val_accuracy: 0.8646 - val_loss: 0.3323
# Epoch 482/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8426 - loss: 0.3527 - val_accuracy: 0.8661 - val_loss: 0.3258
# Epoch 483/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8442 - loss: 0.3522 - val_accuracy: 0.8664 - val_loss: 0.3330
# Epoch 484/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8450 - loss: 0.3505 - val_accuracy: 0.8713 - val_loss: 0.3272
# Epoch 485/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8450 - loss: 0.3507 - val_accuracy: 0.8627 - val_loss: 0.3338
# Epoch 486/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8457 - loss: 0.3509 - val_accuracy: 0.8612 - val_loss: 0.3337
# Epoch 487/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8411 - loss: 0.3532 - val_accuracy: 0.8628 - val_loss: 0.3361
# Epoch 488/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8454 - loss: 0.3503 - val_accuracy: 0.8688 - val_loss: 0.3268
# Epoch 489/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8451 - loss: 0.3510 - val_accuracy: 0.8659 - val_loss: 0.3347
# Epoch 490/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8475 - loss: 0.3471 - val_accuracy: 0.8712 - val_loss: 0.3244
# Epoch 491/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8440 - loss: 0.3526 - val_accuracy: 0.8698 - val_loss: 0.3316
# Epoch 492/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8446 - loss: 0.3485 - val_accuracy: 0.8715 - val_loss: 0.3238
# Epoch 493/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8447 - loss: 0.3491 - val_accuracy: 0.8669 - val_loss: 0.3319
# Epoch 494/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8422 - loss: 0.3510 - val_accuracy: 0.8707 - val_loss: 0.3291
# Epoch 495/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8460 - loss: 0.3508 - val_accuracy: 0.8676 - val_loss: 0.3288
# Epoch 496/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8481 - loss: 0.3456 - val_accuracy: 0.8645 - val_loss: 0.3306
# Epoch 497/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8460 - loss: 0.3501 - val_accuracy: 0.8660 - val_loss: 0.3295
# Epoch 498/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8433 - loss: 0.3504 - val_accuracy: 0.8688 - val_loss: 0.3260
# Epoch 499/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8463 - loss: 0.3481 - val_accuracy: 0.8674 - val_loss: 0.3282
# Epoch 500/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8456 - loss: 0.3487 - val_accuracy: 0.8717 - val_loss: 0.3232
# Epoch 501/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8470 - loss: 0.3467 - val_accuracy: 0.8645 - val_loss: 0.3373
# Epoch 502/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8444 - loss: 0.3524 - val_accuracy: 0.8740 - val_loss: 0.3206
# Epoch 503/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8458 - loss: 0.3499 - val_accuracy: 0.8674 - val_loss: 0.3301
# Epoch 504/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8475 - loss: 0.3452 - val_accuracy: 0.8688 - val_loss: 0.3279
# Epoch 505/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8456 - loss: 0.3503 - val_accuracy: 0.8674 - val_loss: 0.3326
# Epoch 506/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8451 - loss: 0.3494 - val_accuracy: 0.8698 - val_loss: 0.3251
# Epoch 507/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8446 - loss: 0.3478 - val_accuracy: 0.8645 - val_loss: 0.3315
# Epoch 508/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8416 - loss: 0.3542 - val_accuracy: 0.8654 - val_loss: 0.3287
# Epoch 509/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8437 - loss: 0.3499 - val_accuracy: 0.8654 - val_loss: 0.3319
# Epoch 510/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8459 - loss: 0.3481 - val_accuracy: 0.8692 - val_loss: 0.3280
# Epoch 511/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8443 - loss: 0.3511 - val_accuracy: 0.8666 - val_loss: 0.3281
# Epoch 512/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8473 - loss: 0.3494 - val_accuracy: 0.8678 - val_loss: 0.3294
# Epoch 513/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8458 - loss: 0.3480 - val_accuracy: 0.8708 - val_loss: 0.3273
# Epoch 514/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8466 - loss: 0.3473 - val_accuracy: 0.8687 - val_loss: 0.3293
# Epoch 515/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8450 - loss: 0.3528 - val_accuracy: 0.8680 - val_loss: 0.3294
# Epoch 516/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8447 - loss: 0.3481 - val_accuracy: 0.8710 - val_loss: 0.3272
# Epoch 517/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8473 - loss: 0.3486 - val_accuracy: 0.8771 - val_loss: 0.3207
# Epoch 518/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8451 - loss: 0.3507 - val_accuracy: 0.8689 - val_loss: 0.3342
# Epoch 519/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8454 - loss: 0.3465 - val_accuracy: 0.8752 - val_loss: 0.3239
# Epoch 520/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8446 - loss: 0.3499 - val_accuracy: 0.8716 - val_loss: 0.3260
# Epoch 521/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8453 - loss: 0.3484 - val_accuracy: 0.8693 - val_loss: 0.3235
# Epoch 522/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8441 - loss: 0.3513 - val_accuracy: 0.8649 - val_loss: 0.3300
# Epoch 523/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8459 - loss: 0.3483 - val_accuracy: 0.8645 - val_loss: 0.3278
# Epoch 524/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8472 - loss: 0.3469 - val_accuracy: 0.8644 - val_loss: 0.3241
# Epoch 525/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8437 - loss: 0.3489 - val_accuracy: 0.8647 - val_loss: 0.3295
# Epoch 526/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8473 - loss: 0.3467 - val_accuracy: 0.8638 - val_loss: 0.3324
# Epoch 527/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8444 - loss: 0.3502 - val_accuracy: 0.8698 - val_loss: 0.3219
# Epoch 528/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8453 - loss: 0.3474 - val_accuracy: 0.8657 - val_loss: 0.3276
# Epoch 529/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8471 - loss: 0.3484 - val_accuracy: 0.8694 - val_loss: 0.3273
# Epoch 530/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8445 - loss: 0.3516 - val_accuracy: 0.8711 - val_loss: 0.3236
# Epoch 531/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8438 - loss: 0.3469 - val_accuracy: 0.8674 - val_loss: 0.3220
# Epoch 532/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8466 - loss: 0.3469 - val_accuracy: 0.8693 - val_loss: 0.3218
# Epoch 533/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8485 - loss: 0.3430 - val_accuracy: 0.8680 - val_loss: 0.3247
# Epoch 534/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8465 - loss: 0.3502 - val_accuracy: 0.8710 - val_loss: 0.3202
# Epoch 535/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8458 - loss: 0.3483 - val_accuracy: 0.8645 - val_loss: 0.3375
# Epoch 536/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8465 - loss: 0.3457 - val_accuracy: 0.8789 - val_loss: 0.3132
# Epoch 537/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8475 - loss: 0.3440 - val_accuracy: 0.8700 - val_loss: 0.3265
# Epoch 538/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8481 - loss: 0.3451 - val_accuracy: 0.8759 - val_loss: 0.3195
# Epoch 539/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8450 - loss: 0.3481 - val_accuracy: 0.8645 - val_loss: 0.3353
# Epoch 540/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8484 - loss: 0.3474 - val_accuracy: 0.8709 - val_loss: 0.3212
# Epoch 541/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8473 - loss: 0.3470 - val_accuracy: 0.8690 - val_loss: 0.3273
# Epoch 542/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8455 - loss: 0.3477 - val_accuracy: 0.8687 - val_loss: 0.3306
# Epoch 543/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8460 - loss: 0.3467 - val_accuracy: 0.8672 - val_loss: 0.3276
# Epoch 544/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8451 - loss: 0.3499 - val_accuracy: 0.8669 - val_loss: 0.3265
# Epoch 545/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8469 - loss: 0.3469 - val_accuracy: 0.8650 - val_loss: 0.3271
# Epoch 546/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8470 - loss: 0.3478 - val_accuracy: 0.8685 - val_loss: 0.3242
# Epoch 547/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8470 - loss: 0.3433 - val_accuracy: 0.8627 - val_loss: 0.3331
# Epoch 548/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8467 - loss: 0.3475 - val_accuracy: 0.8670 - val_loss: 0.3304
# Epoch 549/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8468 - loss: 0.3452 - val_accuracy: 0.8754 - val_loss: 0.3226
# Epoch 550/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8482 - loss: 0.3479 - val_accuracy: 0.8718 - val_loss: 0.3246
# Epoch 551/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8470 - loss: 0.3449 - val_accuracy: 0.8655 - val_loss: 0.3295
# Epoch 552/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8485 - loss: 0.3438 - val_accuracy: 0.8771 - val_loss: 0.3198
# Epoch 553/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8473 - loss: 0.3470 - val_accuracy: 0.8741 - val_loss: 0.3267
# Epoch 554/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8476 - loss: 0.3480 - val_accuracy: 0.8695 - val_loss: 0.3323
# Epoch 555/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8467 - loss: 0.3472 - val_accuracy: 0.8749 - val_loss: 0.3241
# Epoch 556/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8497 - loss: 0.3425 - val_accuracy: 0.8747 - val_loss: 0.3249
# Epoch 557/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8496 - loss: 0.3426 - val_accuracy: 0.8741 - val_loss: 0.3258
# Epoch 558/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8464 - loss: 0.3470 - val_accuracy: 0.8698 - val_loss: 0.3295
# Epoch 559/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8477 - loss: 0.3455 - val_accuracy: 0.8671 - val_loss: 0.3320
# Epoch 560/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8474 - loss: 0.3455 - val_accuracy: 0.8765 - val_loss: 0.3209
# Epoch 561/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8483 - loss: 0.3456 - val_accuracy: 0.8761 - val_loss: 0.3230
# Epoch 562/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8460 - loss: 0.3490 - val_accuracy: 0.8698 - val_loss: 0.3279
# Epoch 563/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8477 - loss: 0.3445 - val_accuracy: 0.8742 - val_loss: 0.3204
# Epoch 564/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8460 - loss: 0.3475 - val_accuracy: 0.8707 - val_loss: 0.3265
# Epoch 565/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8458 - loss: 0.3453 - val_accuracy: 0.8722 - val_loss: 0.3304
# Epoch 566/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8470 - loss: 0.3452 - val_accuracy: 0.8766 - val_loss: 0.3196
# Epoch 567/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8472 - loss: 0.3477 - val_accuracy: 0.8711 - val_loss: 0.3278
# Epoch 568/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8481 - loss: 0.3437 - val_accuracy: 0.8765 - val_loss: 0.3191
# Epoch 569/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8480 - loss: 0.3418 - val_accuracy: 0.8750 - val_loss: 0.3247
# Epoch 570/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8472 - loss: 0.3453 - val_accuracy: 0.8674 - val_loss: 0.3297
# Epoch 571/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8456 - loss: 0.3469 - val_accuracy: 0.8738 - val_loss: 0.3182
# Epoch 572/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8476 - loss: 0.3440 - val_accuracy: 0.8704 - val_loss: 0.3248
# Epoch 573/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8481 - loss: 0.3425 - val_accuracy: 0.8710 - val_loss: 0.3223
# Epoch 574/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8479 - loss: 0.3472 - val_accuracy: 0.8714 - val_loss: 0.3253
# Epoch 575/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8480 - loss: 0.3437 - val_accuracy: 0.8753 - val_loss: 0.3179
# Epoch 576/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8465 - loss: 0.3481 - val_accuracy: 0.8751 - val_loss: 0.3213
# Epoch 577/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8471 - loss: 0.3435 - val_accuracy: 0.8774 - val_loss: 0.3190
# Epoch 578/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8482 - loss: 0.3447 - val_accuracy: 0.8761 - val_loss: 0.3242
# Epoch 579/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8484 - loss: 0.3425 - val_accuracy: 0.8777 - val_loss: 0.3167
# Epoch 580/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8477 - loss: 0.3469 - val_accuracy: 0.8690 - val_loss: 0.3289
# Epoch 581/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8454 - loss: 0.3450 - val_accuracy: 0.8725 - val_loss: 0.3234
# Epoch 582/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8471 - loss: 0.3438 - val_accuracy: 0.8728 - val_loss: 0.3206
# Epoch 583/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8496 - loss: 0.3415 - val_accuracy: 0.8683 - val_loss: 0.3260
# Epoch 584/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8522 - loss: 0.3392 - val_accuracy: 0.8721 - val_loss: 0.3178
# Epoch 585/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8488 - loss: 0.3439 - val_accuracy: 0.8670 - val_loss: 0.3338
# Epoch 586/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8471 - loss: 0.3460 - val_accuracy: 0.8755 - val_loss: 0.3189
# Epoch 587/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8495 - loss: 0.3430 - val_accuracy: 0.8668 - val_loss: 0.3267
# Epoch 588/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8517 - loss: 0.3420 - val_accuracy: 0.8698 - val_loss: 0.3225
# Epoch 589/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8493 - loss: 0.3422 - val_accuracy: 0.8685 - val_loss: 0.3277
# Epoch 590/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8456 - loss: 0.3437 - val_accuracy: 0.8665 - val_loss: 0.3255
# Epoch 591/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8501 - loss: 0.3423 - val_accuracy: 0.8681 - val_loss: 0.3216
# Epoch 592/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8476 - loss: 0.3457 - val_accuracy: 0.8656 - val_loss: 0.3286
# Epoch 593/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8475 - loss: 0.3459 - val_accuracy: 0.8673 - val_loss: 0.3283
# Epoch 594/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8506 - loss: 0.3417 - val_accuracy: 0.8709 - val_loss: 0.3251
# Epoch 595/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8497 - loss: 0.3422 - val_accuracy: 0.8751 - val_loss: 0.3216
# Epoch 596/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8476 - loss: 0.3436 - val_accuracy: 0.8678 - val_loss: 0.3322
# Epoch 597/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8481 - loss: 0.3444 - val_accuracy: 0.8723 - val_loss: 0.3223
# Epoch 598/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8499 - loss: 0.3417 - val_accuracy: 0.8697 - val_loss: 0.3238
# Epoch 599/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8500 - loss: 0.3403 - val_accuracy: 0.8702 - val_loss: 0.3220
# Epoch 600/600
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.8487 - loss: 0.3438 - val_accuracy: 0.8725 - val_loss: 0.3203
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# AUC: 0.92249783631532
# AMS: 0.37576113322707455
# AMS total: 2.6570324541120613

# %%
model.save_weights('600epoch_weights.weights.h5')

# %%
plotAMS(history)

# %%
yhat = model.predict(x_val)
yhat = yhat.reshape((yhat.shape[0],))

ergebnis = find_best_ams_score(y_val, yhat, w_val)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
ergebnis[0][0]
# Out:
# 0.3289874956757162

# %%
ams_metric(y_val, yhat)
# Out:
# 62.810783

# %%
ops.sum
