# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# # Data preparation

# %%
#import uproot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


import ROOT;
#import lumiere as lm
#lm.loadstyle(True);

from sklearn.metrics import roc_auc_score, roc_curve

def ams_score(x, y, w, cut):
# Calculate Average Mean Significane as defined in ATLAS paper
#    -  approximative formula for large statistics with regularisation
# x: array of truth values (1 if signal)
# y: array of classifier result
# w: array of event weights
# cut
    t = y > cut 
    s = np.sum((x[t] == 1)*w[t])
    b = np.sum((x[t] == 0)*w[t])
    return s/np.sqrt(b+10.0)

def find_best_ams_score(x, y, w):
# find best value of AMS by scanning cut values; 
# x: array of truth values (1 if signal)
# y: array of classifier results
# w: array of event weights
#  returns 
#   ntuple of best value of AMS and the corresponding cut value
#   list with corresponding pairs (ams, cut) 
# ----------------------------------------------------------
    ymin=min(y) # classifiers may not be in range [0.,1.]
    ymax=max(y)
    nprobe=200    # number of (equally spaced) scan points to probe classifier 
    amsvec= [(ams_score(x, y, w, cut), cut) for cut in np.linspace(ymin, ymax, nprobe)] 
    maxams=sorted(amsvec, key=lambda lst: lst[0] )[-1]
    return maxams, amsvec




def printScore(model):

    try:
        pred_clf = model.predict_proba(x_val)[:, 1]
    except:
        pred_clf = model.predict(x_val)
        pred_clf = pred_clf.reshape((pred_clf.shape[0],))

    auc = roc_auc_score(y_val, pred_clf, sample_weight=w_val)
    print('AUC:', auc)
    bs = find_best_ams_score(y_val, pred_clf, w_val)
    print('AMS:', bs[0][0])
    print('AMS total:', bs[0][0]*np.sqrt(50))



def plotLossAccuracy(history):
    # Get training and validation loss/accuracy values from history
    loss_training = history.history['loss']
    loss_validation = history.history['val_loss']
    accuracy_training = history.history['accuracy']
    accuracy_validation = history.history['val_accuracy']


    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 8))
    
    ax1.plot(loss_training, '-', label='training')
    ax1.plot(loss_validation, '-', label='validation')
    ax1.legend(title='loss')
    ax1.set_xlabel('epoch')
    
    ax2.plot(accuracy_training, '-', label='training')
    ax2.plot(accuracy_validation, '-', label='validation')
    ax2.legend(title='accuracy')
    ax2.set_xlabel('epoch')

    plt.show()


def plotAMS(history):
    # Get training and validation loss/accuracy values from history
    ams_training = history.history['ams_metric']
    ams_validation = history.history['val_ams_metric']
    

    fig, ax1 = plt.subplots(1,1, figsize=(10, 8))
    
    #ax1.plot(ams_training, 'o--', label='training')
    ax1.plot(ams_validation, '-', label='validation')
    ax1.legend(title='AMS')
    ax1.set_xlabel('epoch')
    
    plt.show()

# %% [markdown]
# ## Read-in & to Pandas

# %%
input_columns = ['DER_deltaeta_jet_jet', 'DER_deltar_tau_lep', 'DER_lep_eta_centrality', 'DER_mass_MMC', 'DER_mass_jet_jet', 
                 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_met_phi_centrality', 'DER_prodeta_jet_jet', 'DER_pt_h', 
                 'DER_pt_ratio_lep_tau', 'DER_pt_tot', 'DER_sum_pt', 'PRI_jet_all_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 
                 'PRI_jet_leading_pt', 'PRI_jet_num', 'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_subleading_pt', 
                 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_lep_pt', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_tau_eta', 'PRI_tau_phi', 
                 'PRI_tau_pt', 'transverse_lepton_jet_mass']


'''

input_columns = [ 'transverse_lepton_jet_mass',
                'DER_mass_MMC', 
                'DER_mass_vis', 
                'DER_mass_transverse_met_lep',
                'DER_pt_ratio_lep_tau', 
                'DER_sum_pt',
                'DER_deltar_tau_lep', 
                'DER_pt_h',
                'DER_sum_pt',  
                'PRI_met_sumet', 
                'PRI_tau_pt',
                ]

'''
print(len(input_columns))
# Out:
# 31

# %%
RDF = ROOT.ROOT.RDataFrame

signal_tree_name = 'signal'
background_tree_name = 'background'
test_tree_name = 'validation'
file_name = 'atlas-higgs-challenge-2014-v2_part.root'

rdf_signal = RDF(signal_tree_name, file_name)
rdf_bkg = RDF(background_tree_name, file_name)
rdf_test = RDF(test_tree_name, file_name)

reconstruct_transverse_lepton_jet_mass = '''

float lep_px = PRI_lep_pt * TMath::Cos(PRI_lep_phi);
float lep_py = PRI_lep_pt * TMath::Sin(PRI_lep_phi);
float jet_px = PRI_jet_leading_pt * TMath::Cos(PRI_jet_leading_phi);
float jet_py = PRI_jet_leading_pt * TMath::Sin(PRI_jet_leading_phi);

//calculate angle between jet and lepton
float cos_theta = (lep_px*jet_px + lep_py*jet_py) / PRI_lep_pt / PRI_jet_leading_pt;

return PRI_lep_pt * PRI_jet_leading_pt * (1 - cos_theta);
'''

#insertion
rdf_signal = rdf_signal.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)
rdf_bkg = rdf_bkg.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)
rdf_test = rdf_test.Define('transverse_lepton_jet_mass', reconstruct_transverse_lepton_jet_mass)

# label classification to int values
rdf_test = rdf_test.Define('IntLabel', '''
const char ch = Label[0];
const char s = 's';
if(ch == s){
    return 1;
}
else{
    return 0;
}
''')


df_signal = pd.DataFrame(rdf_signal.AsNumpy())
df_bg = pd.DataFrame(rdf_bkg.AsNumpy())
df_test = pd.DataFrame(rdf_test.AsNumpy())

# %%
#df_signal.to_csv('data/signal_df.csv', index=False)
#df_bg.to_csv('data/bg_df.csv', index=False)
#df_test.to_csv('data/test_df.csv', index=False)

# %% [markdown]
# ## concatination, shuffle and split

# %%
from sklearn.utils import shuffle;
from sklearn.model_selection import train_test_split;

#input feature arrays
vars_signal = df_signal[input_columns].to_numpy()
vars_bg = df_bg[input_columns].to_numpy()
vars_test = df_test[input_columns].to_numpy()

inputs = np.concatenate([vars_signal, vars_bg])

#weights
weight_signal = df_signal['Weight'].to_numpy()
weight_bg = df_bg['Weight'].to_numpy()
weights = np.concatenate([weight_signal, weight_bg])
weights = weights.reshape((weights.shape[0],))

weights_test = df_test['Weight'].to_numpy()


# target classifictionation (1:signal / 0: background)
y_signal = np.ones((vars_signal.shape[0], ))
y_bg = np.zeros((vars_bg.shape[0], ))

targets = np.concatenate([y_signal, y_bg])

# for test dataset there is already a classification; convert to int
truths_test = df_test.IntLabel.to_numpy()


# shuffle 
inputs, targets, weights = shuffle(inputs, targets, weights)


# not for gridcv

# training and validation split  (80, 20)
x_train, x_val, y_train, y_val, w_train, w_val = train_test_split(inputs, targets, weights, test_size=0.2)
#x_train, y_train = inputs, targets

# %% [markdown]
# ## StandardScaling

# %%
from sklearn.preprocessing import StandardScaler;
 
scaler = StandardScaler()
scaler.fit(x_train) #set up only on train data
 
# tranformation applied to all
x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(vars_test)

# %% [markdown]
# ### SMOTE

# %%
#%pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_train, y_train = smote.fit_resample(x_train, y_train)

# %%
#from imblearn.over_sampling import ADASYN
#ada = ADASYN(random_state=0)
#x_train, y_train = ada.fit_resample(x_train, y_train)

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

x_train_pre = x_train

#pca = PCA(n_components=22)
#pca.fit(x_train)

#x_train = pca.transform(x_train)
#x_val = pca.transform(x_val)
#x_test = pca.transform(x_test)

# %% [markdown]
# ## DNN

# %% [markdown]
# $$
# AMS = \sqrt{2((s+b+b_r) \log(1+\frac{s}{s+b_r})-s)}
# $$
#
# Here:
# - $s, b$: unnormalised true positive and false positive rates, respectively
# - $b_r = 10$ is the constant regularisation term

# %%
from tensorflow.keras.metrics import Metric
from tensorflow.keras.metrics import AUC


def ams_metric_exact(y_true, y_pred):
    
    s = tf.reduce_sum(y_true * tf.round(y_pred))
    b = tf.reduce_sum((1 - y_true) * tf.round(y_pred))
    b_r = 10.0
    ams = tf.math.sqrt(2 * ((s + b + b_r) * tf.math.log(1 + s / (b + b_r)) - s))
    return ams.numpy()

def ams_scorer_wrapper(w):
    def my_find_best_ams_score(x, y):
        ymax=max(y)
        nprobe=200    # number of (equally spaced) scan points to probe classifier 
        amsvec= [(ams_score(x, y, w, cut), cut) for cut in np.linspace(ymin, ymax, nprobe)] 
        maxams=sorted(amsvec, key=lambda lst: lst[0] )[-1]
        return maxams, amsvec
    return my_find_best_ams_score

# %% [markdown]
# #### training function

# %%
# Training function
def train(model, epochs=10, batch_size=128, learning_rate=1e-3, verbose="auto", callbacks=None):
    
    
    # Define loss function, optimizer algorithm and validation metrics
    model.compile(
        loss='binary_crossentropy',
        #optimizer=Adam(learning_rate=learning_rate, weight_decay=0.1),
        metrics=['accuracy'],
    )
    
    # Print summary of the model
    model.summary()
    
    # Train model

    #currently including the weights th oest the new metric
    #history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
    #                     verbose=verbose, callbacks=callbacks, validation_data=(x_val, y_val))
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                         verbose=verbose,  validation_split=0.2)
        
    
    return history

# %% [markdown]
# ### model

# %%
import tensorflow as tf;
from tensorflow.keras import layers, models, optimizers;
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping


# Define the DNN model
def buildModel():
    model = models.Sequential()
    
    # input
    model.add(layers.Input(shape=(x_train.shape[1],)))
    
    # hidden
    model.add(layers.Dense(2*128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(2*128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(2*128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal'))
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(32, activation='relu', kernel_initializer='glorot_normal'))
    
    
    # output
    model.add(layers.Dense(1, activation='sigmoid', kernel_initializer='glorot_normal'))
    
    return model

# %% [markdown]
# ## execution

# %%
name = 'model_with_my_validation_data'

model = buildModel()

#stopper = EarlyStopping(monitor="val_accuracy",
 #                       patience=20,
  #                      mode="max",
   #                     restore_best_weights=True,
    #                    start_from_epoch=100
     #                  )

#callbacks = [ModelCheckpoint(filepath=f'storage/{name}.keras', save_best_only=True), 
 #            CSVLogger(f'storage/{name}_training.log'),
  #          stopper]
        
#            EarlyStopping(patience=100)
 

history = train(model, epochs=800, batch_size=4*1024, learning_rate=2e-4)
#history = train(model, epochs=400, batch_size=2*1024, learning_rate=2e-3)

printScore(model)
plotLossAccuracy(history)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 256)            │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193,345 (755.25 KB)
#  Trainable params: 193,345 (755.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - accuracy: 0.6046 - loss: 0.6539 - val_accuracy: 0.7042 - val_loss: 0.7598
# Epoch 2/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.6718 - loss: 0.5793 - val_accuracy: 0.7877 - val_loss: 0.6769
# Epoch 3/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.7204 - loss: 0.5445 - val_accuracy: 0.7053 - val_loss: 0.6738
# Epoch 4/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.7435 - loss: 0.5213 - val_accuracy: 0.7643 - val_loss: 0.5445
# Epoch 5/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7576 - loss: 0.5049 - val_accuracy: 0.7912 - val_loss: 0.4821
# Epoch 6/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7613 - loss: 0.4941 - val_accuracy: 0.7334 - val_loss: 0.5554
# Epoch 7/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7749 - loss: 0.4794 - val_accuracy: 0.7245 - val_loss: 0.5623
# Epoch 8/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.7799 - loss: 0.4694 - val_accuracy: 0.7102 - val_loss: 0.5703
# Epoch 9/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7831 - loss: 0.4637 - val_accuracy: 0.7468 - val_loss: 0.5137
# Epoch 10/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7879 - loss: 0.4564 - val_accuracy: 0.7648 - val_loss: 0.4948
# Epoch 11/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7929 - loss: 0.4500 - val_accuracy: 0.7604 - val_loss: 0.5005
# Epoch 12/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7954 - loss: 0.4435 - val_accuracy: 0.7312 - val_loss: 0.5223
# Epoch 13/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7975 - loss: 0.4422 - val_accuracy: 0.7768 - val_loss: 0.4488
# Epoch 14/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.7997 - loss: 0.4362 - val_accuracy: 0.7637 - val_loss: 0.4638
# Epoch 15/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8004 - loss: 0.4347 - val_accuracy: 0.7675 - val_loss: 0.4663
# Epoch 16/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8042 - loss: 0.4312 - val_accuracy: 0.7535 - val_loss: 0.4751
# Epoch 17/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8061 - loss: 0.4301 - val_accuracy: 0.7731 - val_loss: 0.4407
# Epoch 18/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8052 - loss: 0.4275 - val_accuracy: 0.8188 - val_loss: 0.3771
# Epoch 19/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8085 - loss: 0.4238 - val_accuracy: 0.8102 - val_loss: 0.3925
# Epoch 20/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8085 - loss: 0.4212 - val_accuracy: 0.8035 - val_loss: 0.4012
# Epoch 21/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8118 - loss: 0.4181 - val_accuracy: 0.7763 - val_loss: 0.4382
# Epoch 22/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8094 - loss: 0.4204 - val_accuracy: 0.8370 - val_loss: 0.3497
# Epoch 23/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8140 - loss: 0.4126 - val_accuracy: 0.8069 - val_loss: 0.3960
# Epoch 24/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8128 - loss: 0.4135 - val_accuracy: 0.7449 - val_loss: 0.4964
# Epoch 25/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8125 - loss: 0.4169 - val_accuracy: 0.8493 - val_loss: 0.3489
# Epoch 26/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8162 - loss: 0.4090 - val_accuracy: 0.8369 - val_loss: 0.3472
# Epoch 27/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8147 - loss: 0.4136 - val_accuracy: 0.7792 - val_loss: 0.4383
# Epoch 28/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8121 - loss: 0.4103 - val_accuracy: 0.8331 - val_loss: 0.3527
# Epoch 29/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8136 - loss: 0.4101 - val_accuracy: 0.7840 - val_loss: 0.4319
# Epoch 30/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8129 - loss: 0.4093 - val_accuracy: 0.8337 - val_loss: 0.3514
# Epoch 31/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8198 - loss: 0.4044 - val_accuracy: 0.8029 - val_loss: 0.4153
# Epoch 32/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8203 - loss: 0.4066 - val_accuracy: 0.8116 - val_loss: 0.4026
# Epoch 33/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8129 - loss: 0.4108 - val_accuracy: 0.8006 - val_loss: 0.4138
# Epoch 34/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8194 - loss: 0.4017 - val_accuracy: 0.8398 - val_loss: 0.3631
# Epoch 35/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8179 - loss: 0.4062 - val_accuracy: 0.8355 - val_loss: 0.3741
# Epoch 36/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8184 - loss: 0.4043 - val_accuracy: 0.8284 - val_loss: 0.3895
# Epoch 37/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8178 - loss: 0.4012 - val_accuracy: 0.8448 - val_loss: 0.3636
# Epoch 38/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8167 - loss: 0.4012 - val_accuracy: 0.8159 - val_loss: 0.4271
# Epoch 39/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8227 - loss: 0.3995 - val_accuracy: 0.8619 - val_loss: 0.3383
# Epoch 40/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8233 - loss: 0.3984 - val_accuracy: 0.8509 - val_loss: 0.3593
# Epoch 41/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8224 - loss: 0.3988 - val_accuracy: 0.8358 - val_loss: 0.3904
# Epoch 42/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8202 - loss: 0.3988 - val_accuracy: 0.8346 - val_loss: 0.3955
# Epoch 43/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8195 - loss: 0.4000 - val_accuracy: 0.8356 - val_loss: 0.3797
# Epoch 44/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8239 - loss: 0.3946 - val_accuracy: 0.8678 - val_loss: 0.3419
# Epoch 45/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8185 - loss: 0.4024 - val_accuracy: 0.8236 - val_loss: 0.4115
# Epoch 46/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8250 - loss: 0.3922 - val_accuracy: 0.8459 - val_loss: 0.3844
# Epoch 47/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8242 - loss: 0.3947 - val_accuracy: 0.8619 - val_loss: 0.3406
# Epoch 48/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8249 - loss: 0.3942 - val_accuracy: 0.8498 - val_loss: 0.3820
# Epoch 49/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8231 - loss: 0.3936 - val_accuracy: 0.8689 - val_loss: 0.3566
# Epoch 50/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8254 - loss: 0.3909 - val_accuracy: 0.8584 - val_loss: 0.3665
# Epoch 51/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8242 - loss: 0.3909 - val_accuracy: 0.8812 - val_loss: 0.3407
# Epoch 52/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8244 - loss: 0.3929 - val_accuracy: 0.8826 - val_loss: 0.3150
# Epoch 53/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8250 - loss: 0.3899 - val_accuracy: 0.8870 - val_loss: 0.3107
# Epoch 54/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8252 - loss: 0.3935 - val_accuracy: 0.8932 - val_loss: 0.3210
# Epoch 55/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8259 - loss: 0.3898 - val_accuracy: 0.8372 - val_loss: 0.4001
# Epoch 56/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8272 - loss: 0.3873 - val_accuracy: 0.8707 - val_loss: 0.3526
# Epoch 57/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8262 - loss: 0.3909 - val_accuracy: 0.8830 - val_loss: 0.3148
# Epoch 58/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8265 - loss: 0.3907 - val_accuracy: 0.8406 - val_loss: 0.4052
# Epoch 59/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8267 - loss: 0.3877 - val_accuracy: 0.8680 - val_loss: 0.3495
# Epoch 60/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8274 - loss: 0.3894 - val_accuracy: 0.8663 - val_loss: 0.3621
# Epoch 61/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8240 - loss: 0.3902 - val_accuracy: 0.8921 - val_loss: 0.3214
# Epoch 62/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8273 - loss: 0.3878 - val_accuracy: 0.8806 - val_loss: 0.3506
# Epoch 63/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8277 - loss: 0.3852 - val_accuracy: 0.8790 - val_loss: 0.3395
# Epoch 64/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8249 - loss: 0.3907 - val_accuracy: 0.8738 - val_loss: 0.3508
# Epoch 65/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8276 - loss: 0.3813 - val_accuracy: 0.8154 - val_loss: 0.4323
# Epoch 66/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8239 - loss: 0.3932 - val_accuracy: 0.8846 - val_loss: 0.3315
# Epoch 67/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8284 - loss: 0.3878 - val_accuracy: 0.8615 - val_loss: 0.3804
# Epoch 68/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8279 - loss: 0.3840 - val_accuracy: 0.9056 - val_loss: 0.3092
# Epoch 69/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8263 - loss: 0.3875 - val_accuracy: 0.8693 - val_loss: 0.3616
# Epoch 70/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8278 - loss: 0.3850 - val_accuracy: 0.9028 - val_loss: 0.3047
# Epoch 71/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8271 - loss: 0.3838 - val_accuracy: 0.8886 - val_loss: 0.3268
# Epoch 72/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8254 - loss: 0.3852 - val_accuracy: 0.8823 - val_loss: 0.3258
# Epoch 73/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8305 - loss: 0.3808 - val_accuracy: 0.8453 - val_loss: 0.3938
# Epoch 74/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8270 - loss: 0.3862 - val_accuracy: 0.8917 - val_loss: 0.3223
# Epoch 75/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8285 - loss: 0.3864 - val_accuracy: 0.8644 - val_loss: 0.3655
# Epoch 76/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8294 - loss: 0.3823 - val_accuracy: 0.8689 - val_loss: 0.3620
# Epoch 77/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8321 - loss: 0.3814 - val_accuracy: 0.8544 - val_loss: 0.3904
# Epoch 78/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8292 - loss: 0.3827 - val_accuracy: 0.8582 - val_loss: 0.3807
# Epoch 79/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8301 - loss: 0.3804 - val_accuracy: 0.8961 - val_loss: 0.3181
# Epoch 80/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8336 - loss: 0.3767 - val_accuracy: 0.8766 - val_loss: 0.3539
# Epoch 81/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8312 - loss: 0.3811 - val_accuracy: 0.8577 - val_loss: 0.3650
# Epoch 82/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8292 - loss: 0.3792 - val_accuracy: 0.8919 - val_loss: 0.3026
# Epoch 83/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8309 - loss: 0.3836 - val_accuracy: 0.9201 - val_loss: 0.2773
# Epoch 84/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8272 - loss: 0.3835 - val_accuracy: 0.8761 - val_loss: 0.3332
# Epoch 85/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8307 - loss: 0.3770 - val_accuracy: 0.8818 - val_loss: 0.3503
# Epoch 86/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8300 - loss: 0.3771 - val_accuracy: 0.8803 - val_loss: 0.3469
# Epoch 87/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8323 - loss: 0.3789 - val_accuracy: 0.8765 - val_loss: 0.3435
# Epoch 88/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8330 - loss: 0.3785 - val_accuracy: 0.8590 - val_loss: 0.3599
# Epoch 89/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8286 - loss: 0.3815 - val_accuracy: 0.9012 - val_loss: 0.3039
# Epoch 90/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8324 - loss: 0.3762 - val_accuracy: 0.9214 - val_loss: 0.2796
# Epoch 91/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8292 - loss: 0.3824 - val_accuracy: 0.8853 - val_loss: 0.3329
# Epoch 92/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8293 - loss: 0.3796 - val_accuracy: 0.8776 - val_loss: 0.3458
# Epoch 93/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8324 - loss: 0.3787 - val_accuracy: 0.8499 - val_loss: 0.3859
# Epoch 94/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8315 - loss: 0.3752 - val_accuracy: 0.8800 - val_loss: 0.3621
# Epoch 95/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8302 - loss: 0.3783 - val_accuracy: 0.8653 - val_loss: 0.3811
# Epoch 96/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8324 - loss: 0.3760 - val_accuracy: 0.8935 - val_loss: 0.3312
# Epoch 97/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8299 - loss: 0.3799 - val_accuracy: 0.8665 - val_loss: 0.3679
# Epoch 98/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8301 - loss: 0.3800 - val_accuracy: 0.9098 - val_loss: 0.3030
# Epoch 99/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8331 - loss: 0.3763 - val_accuracy: 0.8623 - val_loss: 0.3786
# Epoch 100/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8328 - loss: 0.3754 - val_accuracy: 0.8763 - val_loss: 0.3490
# Epoch 101/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8322 - loss: 0.3746 - val_accuracy: 0.8812 - val_loss: 0.3435
# Epoch 102/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8334 - loss: 0.3721 - val_accuracy: 0.8442 - val_loss: 0.4062
# Epoch 103/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8289 - loss: 0.3785 - val_accuracy: 0.8596 - val_loss: 0.3754
# Epoch 104/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8336 - loss: 0.3761 - val_accuracy: 0.9006 - val_loss: 0.3037
# Epoch 105/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8327 - loss: 0.3763 - val_accuracy: 0.8970 - val_loss: 0.3187
# Epoch 106/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8312 - loss: 0.3763 - val_accuracy: 0.8434 - val_loss: 0.3995
# Epoch 107/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8324 - loss: 0.3741 - val_accuracy: 0.8948 - val_loss: 0.3291
# Epoch 108/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8337 - loss: 0.3736 - val_accuracy: 0.8636 - val_loss: 0.3489
# Epoch 109/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8322 - loss: 0.3727 - val_accuracy: 0.8547 - val_loss: 0.3598
# Epoch 110/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8337 - loss: 0.3721 - val_accuracy: 0.8797 - val_loss: 0.3412
# Epoch 111/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8361 - loss: 0.3732 - val_accuracy: 0.8526 - val_loss: 0.3765
# Epoch 112/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8321 - loss: 0.3709 - val_accuracy: 0.8881 - val_loss: 0.3386
# Epoch 113/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8313 - loss: 0.3748 - val_accuracy: 0.9057 - val_loss: 0.3031
# Epoch 114/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8361 - loss: 0.3692 - val_accuracy: 0.9098 - val_loss: 0.2978
# Epoch 115/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8321 - loss: 0.3727 - val_accuracy: 0.8649 - val_loss: 0.3693
# Epoch 116/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8381 - loss: 0.3696 - val_accuracy: 0.8908 - val_loss: 0.3539
# Epoch 117/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8336 - loss: 0.3711 - val_accuracy: 0.9140 - val_loss: 0.3005
# Epoch 118/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8352 - loss: 0.3686 - val_accuracy: 0.9051 - val_loss: 0.3160
# Epoch 119/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8349 - loss: 0.3694 - val_accuracy: 0.9050 - val_loss: 0.3201
# Epoch 120/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8343 - loss: 0.3708 - val_accuracy: 0.9070 - val_loss: 0.3147
# Epoch 121/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8340 - loss: 0.3723 - val_accuracy: 0.8908 - val_loss: 0.3323
# Epoch 122/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8361 - loss: 0.3719 - val_accuracy: 0.9132 - val_loss: 0.2904
# Epoch 123/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8369 - loss: 0.3673 - val_accuracy: 0.8501 - val_loss: 0.3776
# Epoch 124/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8325 - loss: 0.3731 - val_accuracy: 0.9048 - val_loss: 0.3051
# Epoch 125/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8344 - loss: 0.3676 - val_accuracy: 0.8729 - val_loss: 0.3522
# Epoch 126/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8357 - loss: 0.3685 - val_accuracy: 0.8898 - val_loss: 0.3372
# Epoch 127/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8338 - loss: 0.3721 - val_accuracy: 0.8963 - val_loss: 0.3196
# Epoch 128/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8355 - loss: 0.3677 - val_accuracy: 0.9116 - val_loss: 0.2935
# Epoch 129/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8359 - loss: 0.3688 - val_accuracy: 0.8978 - val_loss: 0.3229
# Epoch 130/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8388 - loss: 0.3639 - val_accuracy: 0.8938 - val_loss: 0.3153
# Epoch 131/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8374 - loss: 0.3663 - val_accuracy: 0.8825 - val_loss: 0.3460
# Epoch 132/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8367 - loss: 0.3680 - val_accuracy: 0.8911 - val_loss: 0.3413
# Epoch 133/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8353 - loss: 0.3700 - val_accuracy: 0.8907 - val_loss: 0.3206
# Epoch 134/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8371 - loss: 0.3683 - val_accuracy: 0.8994 - val_loss: 0.3133
# Epoch 135/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8346 - loss: 0.3698 - val_accuracy: 0.8923 - val_loss: 0.3431
# Epoch 136/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8354 - loss: 0.3686 - val_accuracy: 0.8895 - val_loss: 0.3393
# Epoch 137/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8350 - loss: 0.3673 - val_accuracy: 0.9242 - val_loss: 0.2774
# Epoch 138/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8358 - loss: 0.3646 - val_accuracy: 0.8928 - val_loss: 0.3184
# Epoch 139/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8364 - loss: 0.3661 - val_accuracy: 0.8869 - val_loss: 0.3282
# Epoch 140/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8348 - loss: 0.3711 - val_accuracy: 0.8974 - val_loss: 0.3299
# Epoch 141/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8358 - loss: 0.3661 - val_accuracy: 0.9109 - val_loss: 0.2972
# Epoch 142/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8387 - loss: 0.3633 - val_accuracy: 0.9101 - val_loss: 0.2914
# Epoch 143/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8360 - loss: 0.3689 - val_accuracy: 0.8776 - val_loss: 0.3437
# Epoch 144/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8352 - loss: 0.3670 - val_accuracy: 0.8735 - val_loss: 0.3498
# Epoch 145/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8359 - loss: 0.3678 - val_accuracy: 0.9236 - val_loss: 0.2636
# Epoch 146/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8359 - loss: 0.3687 - val_accuracy: 0.9044 - val_loss: 0.2989
# Epoch 147/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8355 - loss: 0.3654 - val_accuracy: 0.8877 - val_loss: 0.3367
# Epoch 148/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8364 - loss: 0.3628 - val_accuracy: 0.8781 - val_loss: 0.3466
# Epoch 149/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8337 - loss: 0.3704 - val_accuracy: 0.8997 - val_loss: 0.3090
# Epoch 150/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8381 - loss: 0.3637 - val_accuracy: 0.8798 - val_loss: 0.3305
# Epoch 151/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8379 - loss: 0.3660 - val_accuracy: 0.8980 - val_loss: 0.3201
# Epoch 152/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8388 - loss: 0.3630 - val_accuracy: 0.9251 - val_loss: 0.2743
# Epoch 153/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8361 - loss: 0.3662 - val_accuracy: 0.8903 - val_loss: 0.3235
# Epoch 154/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8356 - loss: 0.3661 - val_accuracy: 0.8941 - val_loss: 0.3111
# Epoch 155/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8386 - loss: 0.3607 - val_accuracy: 0.8815 - val_loss: 0.3398
# Epoch 156/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8390 - loss: 0.3635 - val_accuracy: 0.8683 - val_loss: 0.3524
# Epoch 157/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8361 - loss: 0.3626 - val_accuracy: 0.9038 - val_loss: 0.2956
# Epoch 158/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8356 - loss: 0.3688 - val_accuracy: 0.8900 - val_loss: 0.3149
# Epoch 159/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8412 - loss: 0.3609 - val_accuracy: 0.8545 - val_loss: 0.3629
# Epoch 160/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8383 - loss: 0.3618 - val_accuracy: 0.8677 - val_loss: 0.3370
# Epoch 161/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8360 - loss: 0.3645 - val_accuracy: 0.8711 - val_loss: 0.3368
# Epoch 162/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8376 - loss: 0.3629 - val_accuracy: 0.8563 - val_loss: 0.3643
# Epoch 163/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8326 - loss: 0.3653 - val_accuracy: 0.8899 - val_loss: 0.3088
# Epoch 164/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8396 - loss: 0.3618 - val_accuracy: 0.9012 - val_loss: 0.3088
# Epoch 165/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8391 - loss: 0.3604 - val_accuracy: 0.9168 - val_loss: 0.2762
# Epoch 166/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8358 - loss: 0.3659 - val_accuracy: 0.9085 - val_loss: 0.2875
# Epoch 167/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8387 - loss: 0.3629 - val_accuracy: 0.8789 - val_loss: 0.3296
# Epoch 168/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8398 - loss: 0.3614 - val_accuracy: 0.8729 - val_loss: 0.3499
# Epoch 169/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8397 - loss: 0.3626 - val_accuracy: 0.9040 - val_loss: 0.3011
# Epoch 170/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8376 - loss: 0.3609 - val_accuracy: 0.8937 - val_loss: 0.3269
# Epoch 171/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8402 - loss: 0.3596 - val_accuracy: 0.9231 - val_loss: 0.2660
# Epoch 172/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8361 - loss: 0.3630 - val_accuracy: 0.8439 - val_loss: 0.3887
# Epoch 173/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8351 - loss: 0.3659 - val_accuracy: 0.8757 - val_loss: 0.3315
# Epoch 174/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8385 - loss: 0.3660 - val_accuracy: 0.8992 - val_loss: 0.2994
# Epoch 175/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8363 - loss: 0.3618 - val_accuracy: 0.8635 - val_loss: 0.3416
# Epoch 176/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8400 - loss: 0.3567 - val_accuracy: 0.8743 - val_loss: 0.3521
# Epoch 177/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8387 - loss: 0.3590 - val_accuracy: 0.8699 - val_loss: 0.3394
# Epoch 178/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8391 - loss: 0.3620 - val_accuracy: 0.8927 - val_loss: 0.3336
# Epoch 179/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8429 - loss: 0.3590 - val_accuracy: 0.9102 - val_loss: 0.2814
# Epoch 180/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8426 - loss: 0.3550 - val_accuracy: 0.8635 - val_loss: 0.3578
# Epoch 181/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8363 - loss: 0.3622 - val_accuracy: 0.9085 - val_loss: 0.2828
# Epoch 182/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8381 - loss: 0.3611 - val_accuracy: 0.9030 - val_loss: 0.3002
# Epoch 183/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8426 - loss: 0.3571 - val_accuracy: 0.8768 - val_loss: 0.3423
# Epoch 184/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8401 - loss: 0.3584 - val_accuracy: 0.8672 - val_loss: 0.3440
# Epoch 185/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8397 - loss: 0.3595 - val_accuracy: 0.8420 - val_loss: 0.3756
# Epoch 186/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8382 - loss: 0.3606 - val_accuracy: 0.8788 - val_loss: 0.3313
# Epoch 187/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8407 - loss: 0.3576 - val_accuracy: 0.8813 - val_loss: 0.3260
# Epoch 188/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8407 - loss: 0.3585 - val_accuracy: 0.8942 - val_loss: 0.3151
# Epoch 189/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8409 - loss: 0.3577 - val_accuracy: 0.9019 - val_loss: 0.2973
# Epoch 190/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8400 - loss: 0.3581 - val_accuracy: 0.8975 - val_loss: 0.3157
# Epoch 191/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8426 - loss: 0.3544 - val_accuracy: 0.9199 - val_loss: 0.2742
# Epoch 192/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8409 - loss: 0.3575 - val_accuracy: 0.9097 - val_loss: 0.3042
# Epoch 193/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8398 - loss: 0.3581 - val_accuracy: 0.9026 - val_loss: 0.3011
# Epoch 194/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8416 - loss: 0.3561 - val_accuracy: 0.9257 - val_loss: 0.2607
# Epoch 195/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8398 - loss: 0.3595 - val_accuracy: 0.9228 - val_loss: 0.2809
# Epoch 196/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8374 - loss: 0.3617 - val_accuracy: 0.9179 - val_loss: 0.2851
# Epoch 197/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8388 - loss: 0.3590 - val_accuracy: 0.9176 - val_loss: 0.2744
# Epoch 198/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8383 - loss: 0.3613 - val_accuracy: 0.9103 - val_loss: 0.2891
# Epoch 199/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8394 - loss: 0.3575 - val_accuracy: 0.8718 - val_loss: 0.3452
# Epoch 200/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8403 - loss: 0.3556 - val_accuracy: 0.8931 - val_loss: 0.2961
# Epoch 201/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8437 - loss: 0.3549 - val_accuracy: 0.8792 - val_loss: 0.3309
# Epoch 202/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8452 - loss: 0.3542 - val_accuracy: 0.9057 - val_loss: 0.2882
# Epoch 203/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8430 - loss: 0.3584 - val_accuracy: 0.8737 - val_loss: 0.3468
# Epoch 204/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8413 - loss: 0.3599 - val_accuracy: 0.8891 - val_loss: 0.3149
# Epoch 205/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8414 - loss: 0.3586 - val_accuracy: 0.8977 - val_loss: 0.3119
# Epoch 206/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8425 - loss: 0.3555 - val_accuracy: 0.8700 - val_loss: 0.3390
# Epoch 207/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8416 - loss: 0.3558 - val_accuracy: 0.9014 - val_loss: 0.3025
# Epoch 208/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8417 - loss: 0.3538 - val_accuracy: 0.9163 - val_loss: 0.2824
# Epoch 209/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8446 - loss: 0.3531 - val_accuracy: 0.9266 - val_loss: 0.2535
# Epoch 210/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8408 - loss: 0.3555 - val_accuracy: 0.8884 - val_loss: 0.3222
# Epoch 211/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8423 - loss: 0.3535 - val_accuracy: 0.8626 - val_loss: 0.3700
# Epoch 212/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8429 - loss: 0.3544 - val_accuracy: 0.9148 - val_loss: 0.2869
# Epoch 213/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8432 - loss: 0.3547 - val_accuracy: 0.9038 - val_loss: 0.3071
# Epoch 214/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8407 - loss: 0.3546 - val_accuracy: 0.8779 - val_loss: 0.3170
# Epoch 215/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8426 - loss: 0.3557 - val_accuracy: 0.8768 - val_loss: 0.3406
# Epoch 216/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8380 - loss: 0.3578 - val_accuracy: 0.8942 - val_loss: 0.3110
# Epoch 217/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8421 - loss: 0.3543 - val_accuracy: 0.8986 - val_loss: 0.3075
# Epoch 218/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8418 - loss: 0.3550 - val_accuracy: 0.8997 - val_loss: 0.2927
# Epoch 219/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8429 - loss: 0.3519 - val_accuracy: 0.9236 - val_loss: 0.2652
# Epoch 220/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8425 - loss: 0.3533 - val_accuracy: 0.9003 - val_loss: 0.3082
# Epoch 221/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8423 - loss: 0.3520 - val_accuracy: 0.8915 - val_loss: 0.3084
# Epoch 222/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8465 - loss: 0.3518 - val_accuracy: 0.9090 - val_loss: 0.2861
# Epoch 223/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8430 - loss: 0.3564 - val_accuracy: 0.8935 - val_loss: 0.3023
# Epoch 224/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8430 - loss: 0.3529 - val_accuracy: 0.8871 - val_loss: 0.3001
# Epoch 225/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8424 - loss: 0.3550 - val_accuracy: 0.8718 - val_loss: 0.3330
# Epoch 226/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8421 - loss: 0.3546 - val_accuracy: 0.9180 - val_loss: 0.2853
# Epoch 227/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8442 - loss: 0.3532 - val_accuracy: 0.9061 - val_loss: 0.2885
# Epoch 228/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8420 - loss: 0.3511 - val_accuracy: 0.8967 - val_loss: 0.2918
# Epoch 229/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8409 - loss: 0.3546 - val_accuracy: 0.9307 - val_loss: 0.2510
# Epoch 230/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8425 - loss: 0.3586 - val_accuracy: 0.9128 - val_loss: 0.2839
# Epoch 231/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8466 - loss: 0.3501 - val_accuracy: 0.9071 - val_loss: 0.2873
# Epoch 232/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8457 - loss: 0.3533 - val_accuracy: 0.9050 - val_loss: 0.2794
# Epoch 233/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8445 - loss: 0.3502 - val_accuracy: 0.9163 - val_loss: 0.2558
# Epoch 234/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8444 - loss: 0.3496 - val_accuracy: 0.9269 - val_loss: 0.2469
# Epoch 235/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8436 - loss: 0.3518 - val_accuracy: 0.9212 - val_loss: 0.2872
# Epoch 236/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8425 - loss: 0.3517 - val_accuracy: 0.8722 - val_loss: 0.3254
# Epoch 237/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8453 - loss: 0.3503 - val_accuracy: 0.9109 - val_loss: 0.2826
# Epoch 238/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8459 - loss: 0.3496 - val_accuracy: 0.9183 - val_loss: 0.2558
# Epoch 239/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8438 - loss: 0.3513 - val_accuracy: 0.8810 - val_loss: 0.3191
# Epoch 240/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8434 - loss: 0.3500 - val_accuracy: 0.9180 - val_loss: 0.2705
# Epoch 241/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8435 - loss: 0.3464 - val_accuracy: 0.9250 - val_loss: 0.2530
# Epoch 242/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8456 - loss: 0.3510 - val_accuracy: 0.8888 - val_loss: 0.3063
# Epoch 243/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8461 - loss: 0.3495 - val_accuracy: 0.9133 - val_loss: 0.2691
# Epoch 244/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8467 - loss: 0.3488 - val_accuracy: 0.9137 - val_loss: 0.2719
# Epoch 245/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8442 - loss: 0.3502 - val_accuracy: 0.8898 - val_loss: 0.3071
# Epoch 246/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8437 - loss: 0.3527 - val_accuracy: 0.8941 - val_loss: 0.3085
# Epoch 247/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8441 - loss: 0.3484 - val_accuracy: 0.9090 - val_loss: 0.2979
# Epoch 248/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8469 - loss: 0.3479 - val_accuracy: 0.8920 - val_loss: 0.3175
# Epoch 249/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8445 - loss: 0.3520 - val_accuracy: 0.8816 - val_loss: 0.3087
# Epoch 250/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8446 - loss: 0.3484 - val_accuracy: 0.8728 - val_loss: 0.3313
# Epoch 251/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8435 - loss: 0.3481 - val_accuracy: 0.9046 - val_loss: 0.2909
# Epoch 252/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8468 - loss: 0.3483 - val_accuracy: 0.9124 - val_loss: 0.2796
# Epoch 253/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8457 - loss: 0.3484 - val_accuracy: 0.8918 - val_loss: 0.3159
# Epoch 254/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8456 - loss: 0.3501 - val_accuracy: 0.9195 - val_loss: 0.2619
# Epoch 255/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8451 - loss: 0.3502 - val_accuracy: 0.9196 - val_loss: 0.2669
# Epoch 256/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8437 - loss: 0.3501 - val_accuracy: 0.8983 - val_loss: 0.2893
# Epoch 257/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8472 - loss: 0.3454 - val_accuracy: 0.8761 - val_loss: 0.3337
# Epoch 258/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8455 - loss: 0.3509 - val_accuracy: 0.9078 - val_loss: 0.2815
# Epoch 259/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8470 - loss: 0.3448 - val_accuracy: 0.9195 - val_loss: 0.2620
# Epoch 260/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8463 - loss: 0.3476 - val_accuracy: 0.8821 - val_loss: 0.3136
# Epoch 261/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8466 - loss: 0.3488 - val_accuracy: 0.8870 - val_loss: 0.3004
# Epoch 262/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8456 - loss: 0.3487 - val_accuracy: 0.8794 - val_loss: 0.3129
# Epoch 263/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8442 - loss: 0.3499 - val_accuracy: 0.8902 - val_loss: 0.3079
# Epoch 264/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8476 - loss: 0.3452 - val_accuracy: 0.9180 - val_loss: 0.2668
# Epoch 265/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8463 - loss: 0.3468 - val_accuracy: 0.9053 - val_loss: 0.2776
# Epoch 266/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8459 - loss: 0.3468 - val_accuracy: 0.8288 - val_loss: 0.3832
# Epoch 267/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8451 - loss: 0.3490 - val_accuracy: 0.8942 - val_loss: 0.3016
# Epoch 268/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8468 - loss: 0.3449 - val_accuracy: 0.9010 - val_loss: 0.2949
# Epoch 269/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8453 - loss: 0.3493 - val_accuracy: 0.8906 - val_loss: 0.2855
# Epoch 270/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8455 - loss: 0.3462 - val_accuracy: 0.8906 - val_loss: 0.2943
# Epoch 271/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8449 - loss: 0.3471 - val_accuracy: 0.8633 - val_loss: 0.3318
# Epoch 272/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8472 - loss: 0.3455 - val_accuracy: 0.8902 - val_loss: 0.3068
# Epoch 273/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8470 - loss: 0.3452 - val_accuracy: 0.8880 - val_loss: 0.2990
# Epoch 274/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8461 - loss: 0.3473 - val_accuracy: 0.9032 - val_loss: 0.2829
# Epoch 275/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8478 - loss: 0.3455 - val_accuracy: 0.8815 - val_loss: 0.3064
# Epoch 276/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8478 - loss: 0.3436 - val_accuracy: 0.8656 - val_loss: 0.3364
# Epoch 277/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8499 - loss: 0.3425 - val_accuracy: 0.8939 - val_loss: 0.2904
# Epoch 278/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8474 - loss: 0.3443 - val_accuracy: 0.9271 - val_loss: 0.2868
# Epoch 279/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8479 - loss: 0.3448 - val_accuracy: 0.8981 - val_loss: 0.2910
# Epoch 280/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8436 - loss: 0.3498 - val_accuracy: 0.8968 - val_loss: 0.2896
# Epoch 281/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8469 - loss: 0.3459 - val_accuracy: 0.8964 - val_loss: 0.2915
# Epoch 282/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8479 - loss: 0.3452 - val_accuracy: 0.8930 - val_loss: 0.2926
# Epoch 283/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8477 - loss: 0.3449 - val_accuracy: 0.9066 - val_loss: 0.2793
# Epoch 284/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8505 - loss: 0.3439 - val_accuracy: 0.9129 - val_loss: 0.2691
# Epoch 285/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8497 - loss: 0.3438 - val_accuracy: 0.8974 - val_loss: 0.2961
# Epoch 286/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8479 - loss: 0.3465 - val_accuracy: 0.9085 - val_loss: 0.2695
# Epoch 287/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8469 - loss: 0.3444 - val_accuracy: 0.8968 - val_loss: 0.2970
# Epoch 288/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8487 - loss: 0.3464 - val_accuracy: 0.8779 - val_loss: 0.3206
# Epoch 289/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8444 - loss: 0.3471 - val_accuracy: 0.8945 - val_loss: 0.2917
# Epoch 290/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8446 - loss: 0.3460 - val_accuracy: 0.8999 - val_loss: 0.2790
# Epoch 291/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8467 - loss: 0.3465 - val_accuracy: 0.8761 - val_loss: 0.3177
# Epoch 292/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8502 - loss: 0.3419 - val_accuracy: 0.9114 - val_loss: 0.2629
# Epoch 293/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8463 - loss: 0.3453 - val_accuracy: 0.8901 - val_loss: 0.2907
# Epoch 294/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8469 - loss: 0.3453 - val_accuracy: 0.8879 - val_loss: 0.2894
# Epoch 295/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8514 - loss: 0.3393 - val_accuracy: 0.8840 - val_loss: 0.3109
# Epoch 296/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8492 - loss: 0.3432 - val_accuracy: 0.9100 - val_loss: 0.2771
# Epoch 297/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8469 - loss: 0.3474 - val_accuracy: 0.8635 - val_loss: 0.3224
# Epoch 298/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8481 - loss: 0.3453 - val_accuracy: 0.9017 - val_loss: 0.2987
# Epoch 299/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8474 - loss: 0.3421 - val_accuracy: 0.8941 - val_loss: 0.2857
# Epoch 300/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8482 - loss: 0.3433 - val_accuracy: 0.9302 - val_loss: 0.2428
# Epoch 301/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8476 - loss: 0.3469 - val_accuracy: 0.8965 - val_loss: 0.3045
# Epoch 302/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8484 - loss: 0.3431 - val_accuracy: 0.9059 - val_loss: 0.2684
# Epoch 303/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8469 - loss: 0.3471 - val_accuracy: 0.8962 - val_loss: 0.3049
# Epoch 304/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8487 - loss: 0.3431 - val_accuracy: 0.8955 - val_loss: 0.3024
# Epoch 305/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8475 - loss: 0.3447 - val_accuracy: 0.8944 - val_loss: 0.2905
# Epoch 306/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8470 - loss: 0.3466 - val_accuracy: 0.8640 - val_loss: 0.3272
# Epoch 307/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8462 - loss: 0.3427 - val_accuracy: 0.8838 - val_loss: 0.3016
# Epoch 308/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8469 - loss: 0.3445 - val_accuracy: 0.8923 - val_loss: 0.3165
# Epoch 309/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8476 - loss: 0.3443 - val_accuracy: 0.9275 - val_loss: 0.2592
# Epoch 310/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8451 - loss: 0.3450 - val_accuracy: 0.8597 - val_loss: 0.3370
# Epoch 311/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8478 - loss: 0.3446 - val_accuracy: 0.8786 - val_loss: 0.2999
# Epoch 312/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8498 - loss: 0.3400 - val_accuracy: 0.9303 - val_loss: 0.2461
# Epoch 313/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8458 - loss: 0.3479 - val_accuracy: 0.8930 - val_loss: 0.2999
# Epoch 314/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8503 - loss: 0.3409 - val_accuracy: 0.8928 - val_loss: 0.2992
# Epoch 315/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8485 - loss: 0.3470 - val_accuracy: 0.9023 - val_loss: 0.2889
# Epoch 316/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8513 - loss: 0.3360 - val_accuracy: 0.9075 - val_loss: 0.3087
# Epoch 317/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8495 - loss: 0.3396 - val_accuracy: 0.8850 - val_loss: 0.3024
# Epoch 318/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8513 - loss: 0.3389 - val_accuracy: 0.8940 - val_loss: 0.2998
# Epoch 319/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8529 - loss: 0.3413 - val_accuracy: 0.8857 - val_loss: 0.3090
# Epoch 320/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8497 - loss: 0.3420 - val_accuracy: 0.8945 - val_loss: 0.2926
# Epoch 321/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8497 - loss: 0.3366 - val_accuracy: 0.9077 - val_loss: 0.2948
# Epoch 322/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8482 - loss: 0.3427 - val_accuracy: 0.9235 - val_loss: 0.2497
# Epoch 323/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8518 - loss: 0.3399 - val_accuracy: 0.8894 - val_loss: 0.3018
# Epoch 324/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8512 - loss: 0.3386 - val_accuracy: 0.9141 - val_loss: 0.2659
# Epoch 325/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8512 - loss: 0.3398 - val_accuracy: 0.8701 - val_loss: 0.3218
# Epoch 326/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8490 - loss: 0.3393 - val_accuracy: 0.8807 - val_loss: 0.3218
# Epoch 327/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8486 - loss: 0.3428 - val_accuracy: 0.9011 - val_loss: 0.2932
# Epoch 328/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8505 - loss: 0.3409 - val_accuracy: 0.8767 - val_loss: 0.3312
# Epoch 329/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8531 - loss: 0.3393 - val_accuracy: 0.9029 - val_loss: 0.2701
# Epoch 330/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8501 - loss: 0.3408 - val_accuracy: 0.8904 - val_loss: 0.2886
# Epoch 331/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8528 - loss: 0.3356 - val_accuracy: 0.8908 - val_loss: 0.2984
# Epoch 332/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8482 - loss: 0.3423 - val_accuracy: 0.9062 - val_loss: 0.2777
# Epoch 333/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8511 - loss: 0.3377 - val_accuracy: 0.8811 - val_loss: 0.3125
# Epoch 334/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8502 - loss: 0.3408 - val_accuracy: 0.9002 - val_loss: 0.2731
# Epoch 335/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8501 - loss: 0.3391 - val_accuracy: 0.9332 - val_loss: 0.2323
# Epoch 336/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8480 - loss: 0.3400 - val_accuracy: 0.9198 - val_loss: 0.2480
# Epoch 337/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8517 - loss: 0.3388 - val_accuracy: 0.8911 - val_loss: 0.2981
# Epoch 338/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8502 - loss: 0.3401 - val_accuracy: 0.8994 - val_loss: 0.3039
# Epoch 339/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8518 - loss: 0.3380 - val_accuracy: 0.9047 - val_loss: 0.2746
# Epoch 340/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8503 - loss: 0.3406 - val_accuracy: 0.9054 - val_loss: 0.2632
# Epoch 341/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8503 - loss: 0.3398 - val_accuracy: 0.8977 - val_loss: 0.2915
# Epoch 342/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8502 - loss: 0.3390 - val_accuracy: 0.9044 - val_loss: 0.2725
# Epoch 343/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8498 - loss: 0.3459 - val_accuracy: 0.9201 - val_loss: 0.2585
# Epoch 344/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8520 - loss: 0.3375 - val_accuracy: 0.8951 - val_loss: 0.2933
# Epoch 345/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8517 - loss: 0.3365 - val_accuracy: 0.9129 - val_loss: 0.2554
# Epoch 346/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8494 - loss: 0.3421 - val_accuracy: 0.9275 - val_loss: 0.2473
# Epoch 347/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8501 - loss: 0.3397 - val_accuracy: 0.8979 - val_loss: 0.2700
# Epoch 348/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8501 - loss: 0.3419 - val_accuracy: 0.8785 - val_loss: 0.3160
# Epoch 349/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8484 - loss: 0.3416 - val_accuracy: 0.8851 - val_loss: 0.3013
# Epoch 350/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8486 - loss: 0.3407 - val_accuracy: 0.9063 - val_loss: 0.2799
# Epoch 351/800
# ...
# Epoch 680/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8653 - loss: 0.3111 - val_accuracy: 0.9231 - val_loss: 0.2360
# Epoch 681/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8640 - loss: 0.3111 - val_accuracy: 0.9219 - val_loss: 0.2312
# Epoch 682/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8669 - loss: 0.3087 - val_accuracy: 0.9283 - val_loss: 0.2308
# Epoch 683/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8667 - loss: 0.3083 - val_accuracy: 0.8998 - val_loss: 0.2558
# Epoch 684/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8656 - loss: 0.3099 - val_accuracy: 0.9277 - val_loss: 0.2223
# Epoch 685/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8647 - loss: 0.3135 - val_accuracy: 0.8992 - val_loss: 0.2744
# Epoch 686/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8628 - loss: 0.3108 - val_accuracy: 0.9126 - val_loss: 0.2537
# Epoch 687/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8640 - loss: 0.3107 - val_accuracy: 0.9145 - val_loss: 0.2474
# Epoch 688/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8626 - loss: 0.3132 - val_accuracy: 0.9322 - val_loss: 0.2146
# Epoch 689/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8647 - loss: 0.3118 - val_accuracy: 0.9106 - val_loss: 0.2388
# Epoch 690/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8659 - loss: 0.3054 - val_accuracy: 0.9116 - val_loss: 0.2450
# Epoch 691/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8667 - loss: 0.3063 - val_accuracy: 0.9277 - val_loss: 0.2297
# Epoch 692/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8669 - loss: 0.3076 - val_accuracy: 0.9342 - val_loss: 0.2370
# Epoch 693/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8636 - loss: 0.3121 - val_accuracy: 0.9430 - val_loss: 0.2044
# Epoch 694/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8657 - loss: 0.3120 - val_accuracy: 0.9228 - val_loss: 0.2243
# Epoch 695/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8659 - loss: 0.3108 - val_accuracy: 0.9032 - val_loss: 0.2731
# Epoch 696/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8670 - loss: 0.3088 - val_accuracy: 0.9198 - val_loss: 0.2179
# Epoch 697/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8645 - loss: 0.3120 - val_accuracy: 0.8893 - val_loss: 0.2728
# Epoch 698/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8638 - loss: 0.3132 - val_accuracy: 0.8924 - val_loss: 0.2683
# Epoch 699/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8637 - loss: 0.3108 - val_accuracy: 0.9141 - val_loss: 0.2527
# Epoch 700/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8636 - loss: 0.3122 - val_accuracy: 0.8982 - val_loss: 0.2759
# Epoch 701/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8638 - loss: 0.3098 - val_accuracy: 0.9069 - val_loss: 0.2798
# Epoch 702/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8649 - loss: 0.3099 - val_accuracy: 0.9154 - val_loss: 0.2311
# Epoch 703/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8665 - loss: 0.3097 - val_accuracy: 0.9126 - val_loss: 0.2468
# Epoch 704/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8671 - loss: 0.3075 - val_accuracy: 0.9263 - val_loss: 0.2232
# Epoch 705/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8655 - loss: 0.3116 - val_accuracy: 0.9311 - val_loss: 0.2106
# Epoch 706/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8687 - loss: 0.3059 - val_accuracy: 0.9402 - val_loss: 0.2168
# Epoch 707/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8652 - loss: 0.3094 - val_accuracy: 0.9081 - val_loss: 0.2708
# Epoch 708/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8664 - loss: 0.3108 - val_accuracy: 0.9087 - val_loss: 0.2543
# Epoch 709/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8659 - loss: 0.3079 - val_accuracy: 0.9051 - val_loss: 0.2669
# Epoch 710/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8666 - loss: 0.3073 - val_accuracy: 0.9238 - val_loss: 0.2242
# Epoch 711/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8667 - loss: 0.3062 - val_accuracy: 0.9380 - val_loss: 0.2154
# Epoch 712/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8656 - loss: 0.3092 - val_accuracy: 0.9297 - val_loss: 0.2240
# Epoch 713/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8664 - loss: 0.3106 - val_accuracy: 0.9041 - val_loss: 0.2428
# Epoch 714/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8652 - loss: 0.3079 - val_accuracy: 0.9096 - val_loss: 0.2571
# Epoch 715/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8650 - loss: 0.3086 - val_accuracy: 0.9253 - val_loss: 0.2134
# Epoch 716/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8659 - loss: 0.3070 - val_accuracy: 0.9207 - val_loss: 0.2156
# Epoch 717/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8650 - loss: 0.3096 - val_accuracy: 0.9104 - val_loss: 0.2526
# Epoch 718/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8669 - loss: 0.3056 - val_accuracy: 0.9092 - val_loss: 0.2644
# Epoch 719/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8669 - loss: 0.3076 - val_accuracy: 0.9352 - val_loss: 0.2076
# Epoch 720/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8667 - loss: 0.3067 - val_accuracy: 0.9322 - val_loss: 0.2143
# Epoch 721/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8658 - loss: 0.3101 - val_accuracy: 0.9258 - val_loss: 0.2376
# Epoch 722/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8678 - loss: 0.3102 - val_accuracy: 0.9308 - val_loss: 0.2286
# Epoch 723/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8664 - loss: 0.3064 - val_accuracy: 0.9350 - val_loss: 0.2025
# Epoch 724/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8663 - loss: 0.3093 - val_accuracy: 0.9216 - val_loss: 0.2329
# Epoch 725/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8655 - loss: 0.3091 - val_accuracy: 0.9219 - val_loss: 0.2279
# Epoch 726/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.8650 - loss: 0.3091 - val_accuracy: 0.9075 - val_loss: 0.2496
# Epoch 727/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8694 - loss: 0.3045 - val_accuracy: 0.9387 - val_loss: 0.2067
# Epoch 728/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8666 - loss: 0.3086 - val_accuracy: 0.9356 - val_loss: 0.1997
# Epoch 729/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8680 - loss: 0.3073 - val_accuracy: 0.9064 - val_loss: 0.2654
# Epoch 730/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8679 - loss: 0.3072 - val_accuracy: 0.9330 - val_loss: 0.2199
# Epoch 731/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8668 - loss: 0.3076 - val_accuracy: 0.9288 - val_loss: 0.2200
# Epoch 732/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8666 - loss: 0.3087 - val_accuracy: 0.9277 - val_loss: 0.2170
# Epoch 733/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8663 - loss: 0.3085 - val_accuracy: 0.8969 - val_loss: 0.2749
# Epoch 734/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8660 - loss: 0.3065 - val_accuracy: 0.9189 - val_loss: 0.2340
# Epoch 735/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8668 - loss: 0.3065 - val_accuracy: 0.9086 - val_loss: 0.2732
# Epoch 736/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8651 - loss: 0.3094 - val_accuracy: 0.9087 - val_loss: 0.2367
# Epoch 737/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8679 - loss: 0.3046 - val_accuracy: 0.9338 - val_loss: 0.2015
# Epoch 738/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8656 - loss: 0.3085 - val_accuracy: 0.9187 - val_loss: 0.2485
# Epoch 739/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8681 - loss: 0.3074 - val_accuracy: 0.9225 - val_loss: 0.2442
# Epoch 740/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8665 - loss: 0.3105 - val_accuracy: 0.8894 - val_loss: 0.2713
# Epoch 741/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8667 - loss: 0.3064 - val_accuracy: 0.9036 - val_loss: 0.2684
# Epoch 742/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8638 - loss: 0.3104 - val_accuracy: 0.9326 - val_loss: 0.2358
# Epoch 743/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8688 - loss: 0.3052 - val_accuracy: 0.9290 - val_loss: 0.2172
# Epoch 744/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8659 - loss: 0.3076 - val_accuracy: 0.9117 - val_loss: 0.2597
# Epoch 745/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8681 - loss: 0.3056 - val_accuracy: 0.9157 - val_loss: 0.2395
# Epoch 746/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8652 - loss: 0.3085 - val_accuracy: 0.9299 - val_loss: 0.2364
# Epoch 747/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8642 - loss: 0.3091 - val_accuracy: 0.9169 - val_loss: 0.2533
# Epoch 748/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8669 - loss: 0.3066 - val_accuracy: 0.9079 - val_loss: 0.2524
# Epoch 749/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.8680 - loss: 0.3072 - val_accuracy: 0.9242 - val_loss: 0.2338
# Epoch 750/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8646 - loss: 0.3103 - val_accuracy: 0.9244 - val_loss: 0.2158
# Epoch 751/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8673 - loss: 0.3080 - val_accuracy: 0.9362 - val_loss: 0.2032
# Epoch 752/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8670 - loss: 0.3072 - val_accuracy: 0.9195 - val_loss: 0.2445
# Epoch 753/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8685 - loss: 0.3043 - val_accuracy: 0.9052 - val_loss: 0.2738
# Epoch 754/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8682 - loss: 0.3069 - val_accuracy: 0.9286 - val_loss: 0.2242
# Epoch 755/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8666 - loss: 0.3064 - val_accuracy: 0.9214 - val_loss: 0.2415
# Epoch 756/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8692 - loss: 0.3067 - val_accuracy: 0.9222 - val_loss: 0.2299
# Epoch 757/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8674 - loss: 0.3083 - val_accuracy: 0.9138 - val_loss: 0.2369
# Epoch 758/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8675 - loss: 0.3086 - val_accuracy: 0.9429 - val_loss: 0.1911
# Epoch 759/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8678 - loss: 0.3081 - val_accuracy: 0.9265 - val_loss: 0.2315
# Epoch 760/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8676 - loss: 0.3069 - val_accuracy: 0.9352 - val_loss: 0.2145
# Epoch 761/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8664 - loss: 0.3058 - val_accuracy: 0.9253 - val_loss: 0.2371
# Epoch 762/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8667 - loss: 0.3050 - val_accuracy: 0.9241 - val_loss: 0.2222
# Epoch 763/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8678 - loss: 0.3085 - val_accuracy: 0.9246 - val_loss: 0.2137
# Epoch 764/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8715 - loss: 0.3013 - val_accuracy: 0.9124 - val_loss: 0.2517
# Epoch 765/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8683 - loss: 0.3046 - val_accuracy: 0.9339 - val_loss: 0.2130
# Epoch 766/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8690 - loss: 0.3047 - val_accuracy: 0.9324 - val_loss: 0.2353
# Epoch 767/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8673 - loss: 0.3068 - val_accuracy: 0.9185 - val_loss: 0.2405
# Epoch 768/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8658 - loss: 0.3121 - val_accuracy: 0.9426 - val_loss: 0.2105
# Epoch 769/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8665 - loss: 0.3088 - val_accuracy: 0.9186 - val_loss: 0.2500
# Epoch 770/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8671 - loss: 0.3029 - val_accuracy: 0.9218 - val_loss: 0.2228
# Epoch 771/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8682 - loss: 0.3035 - val_accuracy: 0.9067 - val_loss: 0.2565
# Epoch 772/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8650 - loss: 0.3101 - val_accuracy: 0.9174 - val_loss: 0.2604
# Epoch 773/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8706 - loss: 0.3053 - val_accuracy: 0.9388 - val_loss: 0.2099
# Epoch 774/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8705 - loss: 0.3034 - val_accuracy: 0.9382 - val_loss: 0.2150
# Epoch 775/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8694 - loss: 0.3020 - val_accuracy: 0.9102 - val_loss: 0.2354
# Epoch 776/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8685 - loss: 0.3031 - val_accuracy: 0.8994 - val_loss: 0.2631
# Epoch 777/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8655 - loss: 0.3102 - val_accuracy: 0.9335 - val_loss: 0.2055
# Epoch 778/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8671 - loss: 0.3052 - val_accuracy: 0.9213 - val_loss: 0.2367
# Epoch 779/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8696 - loss: 0.3043 - val_accuracy: 0.9340 - val_loss: 0.2029
# Epoch 780/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8669 - loss: 0.3048 - val_accuracy: 0.9344 - val_loss: 0.2130
# Epoch 781/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8678 - loss: 0.3072 - val_accuracy: 0.9405 - val_loss: 0.1966
# Epoch 782/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8659 - loss: 0.3099 - val_accuracy: 0.9155 - val_loss: 0.2197
# Epoch 783/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8677 - loss: 0.3076 - val_accuracy: 0.9322 - val_loss: 0.2256
# Epoch 784/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8691 - loss: 0.3055 - val_accuracy: 0.9239 - val_loss: 0.2382
# Epoch 785/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.8717 - loss: 0.2995 - val_accuracy: 0.9154 - val_loss: 0.2397
# Epoch 786/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8678 - loss: 0.3054 - val_accuracy: 0.9081 - val_loss: 0.2375
# Epoch 787/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8688 - loss: 0.3048 - val_accuracy: 0.9322 - val_loss: 0.2215
# Epoch 788/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.8700 - loss: 0.3029 - val_accuracy: 0.9213 - val_loss: 0.2415
# Epoch 789/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8684 - loss: 0.3046 - val_accuracy: 0.9077 - val_loss: 0.2523
# Epoch 790/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8682 - loss: 0.3055 - val_accuracy: 0.9096 - val_loss: 0.2500
# Epoch 791/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8692 - loss: 0.3019 - val_accuracy: 0.9067 - val_loss: 0.2617
# Epoch 792/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8692 - loss: 0.3035 - val_accuracy: 0.9500 - val_loss: 0.1901
# Epoch 793/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8713 - loss: 0.3021 - val_accuracy: 0.9434 - val_loss: 0.2081
# Epoch 794/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8651 - loss: 0.3074 - val_accuracy: 0.9272 - val_loss: 0.2228
# Epoch 795/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8695 - loss: 0.3050 - val_accuracy: 0.9187 - val_loss: 0.2286
# Epoch 796/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8701 - loss: 0.3060 - val_accuracy: 0.9336 - val_loss: 0.2311
# Epoch 797/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8673 - loss: 0.3057 - val_accuracy: 0.9040 - val_loss: 0.2644
# Epoch 798/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.8674 - loss: 0.3055 - val_accuracy: 0.9245 - val_loss: 0.2288
# Epoch 799/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8700 - loss: 0.3004 - val_accuracy: 0.9477 - val_loss: 0.2013
# Epoch 800/800
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8661 - loss: 0.3067 - val_accuracy: 0.9358 - val_loss: 0.2156
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# AUC: 0.9134371954893243
# AMS: 0.3227036720357994
# AMS total: 2.2818595481031343

# %%
#model.save_weights(f'storage/{name}_weights_2.6ams.weights.h5')

# %%
#plotAMS(history)

# %%
yhat = model.predict(x_val)
yhat = yhat.reshape((yhat.shape[0],))

ergebnis = find_best_ams_score(y_val, yhat, w_val)

# %%
ergebnis[0][0]

# %%
ams_metric(y_val, yhat)

# %%
plotLossAccuracy(history)
